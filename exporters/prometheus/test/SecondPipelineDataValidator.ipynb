# %%
import requests
from datetime import datetime
from collections import defaultdict

# %%
PROMETHEUS_HOST = "localhost:9090"
COUNTER_DEBUG = False

COUNTER_COUNT = 0
GAUGE_COUNT = 0
HISTOGRAM_COUNT = 0
SUMMARY_COUNT = 0

COUNTER_PASS = 0
GAUGE_PASS = 0
HISTOGRAM_PASS = 0
SUMMARY_PASS = 0

expected_metrics = defaultdict()
entries = []

# read and parse the answer file
expected_answers = open("PrometheusAnswersSecond.csv", "r")
lines = expected_answers.readlines()


def parse_label(label_str):
    label_arr = label_str.replace("{", "").replace("}", "").replace('\n', "").split(":")
    labels = {label_arr[0]: label_arr[1]}
    return labels


def parse_buckets(buckets_str):
    buckets_arr = buckets_str.replace("[", "").replace("]", "") \
        .replace("(", "").replace(")", "").split(",")
    buckets = defaultdict()
    i = 0
    cumulative_count = 0
    while i + 1 < len(buckets_arr):
        cumulative_count += int(buckets_arr[i + 1])
        if buckets_arr[i] == "inf":
            buckets_arr[i] = "+Inf"
        buckets[buckets_arr[i]] = cumulative_count
        i = i + 2
    return buckets


def parse_quantiles(quantiles_str):
    quantile_arr = quantiles_str.replace("[", "").replace("]", "") \
        .replace("(", "").replace(")", "").split(",")
    quantiles = defaultdict()
    i = 0
    while i + 1 < len(quantile_arr):
        quantiles[float(quantile_arr[i])] = int(quantile_arr[i + 1])
        i = i + 2
    return quantiles


def request_and_check_single_value(metric_name, type):
    URL = "http://" + PROMETHEUS_HOST + "/api/v1/query?query=" + metric_name
    r = requests.get(URL)
    result = r.json()['data']['result']

    if result:
        actual_metric = result[0]['metric']
        actual_value = result[0]['value'][1]

        if type == "counter":
            actual_name = actual_metric['__name__']
            return expected_metrics[actual_name]['value'] == actual_value
        elif type == "histogram" or type == "summary":
            names = actual_metric['__name__'].split("_")
            actual_name = names[0] + "_" + names[1]
            metric = names[2]
            expected_value = int(expected_metrics[actual_name][metric])
            actual_value = int(actual_value)
            return expected_value == actual_value
    return False


def request_and_check_label(metric_name, type):
    # send http request to Prometheus server
    if type == "histogram" or type == "summary":
        metric_name += "_count"

    URL = "http://" + PROMETHEUS_HOST + "/api/v1/query?query=" + metric_name
    r = requests.get(URL)
    result = r.json()['data']['result']
    if result:
        actual_metric = result[0]['metric']
        actual_name = actual_metric['__name__']
        if type == "histogram" or type == "summary":
            names = actual_name.split("_")
            actual_name = names[0] + "_" + names[1]
        key = "key" + actual_name.split('_')[0][4:]
        actual_label = result[0]['metric'][key]
        return expected_metrics[actual_name]['labels'][key] == actual_label
    return False


def request_and_check_bucket(metric_name):
    names = metric_name.split("_")
    actual_name = names[0] + "_" + names[1]
    URL = "http://" + PROMETHEUS_HOST + "/api/v1/query?query=" + metric_name
    r = requests.get(URL)
    result = r.json()['data']['result']
    if result:
        all_match = True
        for bucket in result:
            le = bucket['metric']['le']
            if le != "+Inf":
                le = str(int(float(bucket['metric']['le'])))
            if le in expected_metrics[actual_name]['buckets']:
                actual_value = int(bucket['value'][1])
                match = actual_value == expected_metrics[actual_name]['buckets'][le]
                all_match = all_match and match
                # print(le)
                # print(actual_value)
                # print(expected_metrics[actual_name]['buckets'][le])
                # print(match)
                # print(all_match)
        if not all_match:
            print(result)
        return all_match
    return False


def request_and_check_quantile(metric_name):
    actual_name = metric_name
    URL = "http://" + PROMETHEUS_HOST + "/api/v1/query?query=" + metric_name
    r = requests.get(URL)
    result = r.json()['data']['result']
    valid_quantiles = [0, 0.5, 0.9, 0.95, 0.99, 1]
    if result:
        all_match = True
        for quantile in result:
            q = float(quantile['metric']['quantile'])
            if q in valid_quantiles and q in expected_metrics[actual_name]['quantiles']:
                actual_value = int(quantile['value'][1])
                expected_value = expected_metrics[actual_name]['quantiles'][q]
                match = actual_value == expected_value
                all_match = all_match and match
        if not all_match:
            print(result)
        return all_match
    return False

# %%
for line in lines:
    split_result = line.split("|")
    metric_type = split_result[0]
    others = split_result[-1].replace(" ", "")
    other_split = others.split(",")
    name = other_split[0]
    desc = other_split[1]
    labels_str = other_split[-1]

    metric_entry = {name: metric_type}
    entries.append(metric_entry)

    expected_metrics[name] = defaultdict()
    expected_metrics[name]['type'] = metric_type
    if metric_type == "counter":
        COUNTER_COUNT += 1
        val = split_result[1]
        expected_metrics[name]['value'] = val
        expected_metrics[name]['labels'] = parse_label(labels_str)
    elif metric_type == "gauge":
        GAUGE_COUNT += 1
        val = split_result[1]
        expected_metrics[name]['value'] = val
        expected_metrics[name]['labels'] = parse_label(labels_str)
    elif metric_type == "histogram":
        HISTOGRAM_COUNT += 1
        sum = int(split_result[1])
        count = int(split_result[2])
        buckets = parse_buckets(split_result[3])
        expected_metrics[name]['sum'] = sum
        expected_metrics[name]['count'] = count
        expected_metrics[name]['buckets'] = buckets
        expected_metrics[name]['labels'] = parse_label(labels_str)
    elif metric_type == "summary":
        SUMMARY_COUNT += 1
        sum = split_result[1]
        count = split_result[2]
        quantiles = parse_quantiles(split_result[3])
        expected_metrics[name]['sum'] = sum
        expected_metrics[name]['count'] = count
        expected_metrics[name]['quantiles'] = quantiles
        expected_metrics[name]['labels'] = parse_label(labels_str)
        print(expected_metrics[name])
    else:
        print("Unknown metric type")
# Out:
# defaultdict(None, {'type': 'summary', 'sum': '-5', 'count': '1', 'quantiles': defaultdict(None, {0.0: -5, 0.5: -5, 0.9: -5, 0.95: -5, 0.99: -5, 1.0: -5}), 'labels': {'key1': 'value1'}})
# defaultdict(None, {'type': 'summary', 'sum': '-64', 'count': '4', 'quantiles': defaultdict(None, {0.0: -46, 0.5: -43, 0.9: 38, 0.95: 38, 0.99: 38, 1.0: 38}), 'labels': {'key3': 'value3'}})
# defaultdict(None, {'type': 'summary', 'sum': '-9', 'count': '2', 'quantiles': defaultdict(None, {0.32: -35, 0.42: -35, 0.49: -35, 0.68: -35, 0.94: -35}), 'labels': {'key8': 'value8'}})
# defaultdict(None, {'type': 'summary', 'sum': '-36', 'count': '1', 'quantiles': defaultdict(None, {0.0: -36, 0.5: -36, 0.9: -36, 0.95: -36, 0.99: -36, 1.0: -36}), 'labels': {'key12': 'value12'}})
# defaultdict(None, {'type': 'summary', 'sum': '-34', 'count': '4', 'quantiles': defaultdict(None, {0.4: -22, 0.52: -22, 0.75: 12, 0.81: 12, 0.92: 12}), 'labels': {'key13': 'value13'}})
# defaultdict(None, {'type': 'summary', 'sum': '50', 'count': '4', 'quantiles': defaultdict(None, {0.0: 34, 0.5: -10, 0.9: 31, 0.95: 31, 0.99: 31, 1.0: 31}), 'labels': {'key15': 'value15'}})
# defaultdict(None, {'type': 'summary', 'sum': '21', 'count': '3', 'quantiles': defaultdict(None, {0.07: 30, 0.41: 30, 0.43: 30, 0.63: -9, 0.96: -9}), 'labels': {'key21': 'value21'}})
# defaultdict(None, {'type': 'summary', 'sum': '45', 'count': '3', 'quantiles': defaultdict(None, {0.0: 9, 0.5: 3, 0.9: 33, 0.95: 33, 0.99: 33, 1.0: 33}), 'labels': {'key22': 'value22'}})
# defaultdict(None, {'type': 'summary', 'sum': '-22', 'count': '3', 'quantiles': defaultdict(None, {0.0: 1, 0.57: -19, 0.58: -19, 0.83: -19, 0.99: -19}), 'labels': {'key26': 'value26'}})
# defaultdict(None, {'type': 'summary', 'sum': '44', 'count': '1', 'quantiles': defaultdict(None, {0.0: 44, 0.5: 44, 0.9: 44, 0.95: 44, 0.99: 44, 1.0: 44}), 'labels': {'key27': 'value27'}})
# defaultdict(None, {'type': 'summary', 'sum': '21', 'count': '3', 'quantiles': defaultdict(None, {0.4: 24, 0.45: 24, 0.61: -19, 0.73: -19, 0.81: -19}), 'labels': {'key28': 'value28'}})
# defaultdict(None, {'type': 'summary', 'sum': '-10', 'count': '3', 'quantiles': defaultdict(None, {0.0: -44, 0.5: -2, 0.9: 36, 0.95: 36, 0.99: 36, 1.0: 36}), 'labels': {'key29': 'value29'}})
# defaultdict(None, {'type': 'summary', 'sum': '-19', 'count': '1', 'quantiles': defaultdict(None, {0.04: -19, 0.27: -19, 0.32: -19, 0.36: -19, 0.94: -19}), 'labels': {'key32': 'value32'}})
# defaultdict(None, {'type': 'summary', 'sum': '21', 'count': '1', 'quantiles': defaultdict(None, {0.0: 21, 0.5: 21, 0.9: 21, 0.95: 21, 0.99: 21, 1.0: 21}), 'labels': {'key33': 'value33'}})
# defaultdict(None, {'type': 'summary', 'sum': '-58', 'count': '4', 'quantiles': defaultdict(None, {0.0: 1, 0.5: -3, 0.9: -9, 0.95: -9, 0.99: -9, 1.0: -9}), 'labels': {'key36': 'value36'}})
# defaultdict(None, {'type': 'summary', 'sum': '-46', 'count': '2', 'quantiles': defaultdict(None, {0.0: 3, 0.5: -49, 0.9: -49, 0.95: -49, 0.99: -49, 1.0: -49}), 'labels': {'key38': 'value38'}})
# defaultdict(None, {'type': 'summary', 'sum': '28', 'count': '2', 'quantiles': defaultdict(None, {0.0: 30, 0.5: -2, 0.9: -2, 0.95: -2, 0.99: -2, 1.0: -2}), 'labels': {'key39': 'value39'}})
# defaultdict(None, {'type': 'summary', 'sum': '-17', 'count': '5', 'quantiles': defaultdict(None, {0.0: 39, 0.5: -20, 0.9: -38, 0.95: -38, 0.99: -38, 1.0: -38}), 'labels': {'key40': 'value40'}})
# defaultdict(None, {'type': 'summary', 'sum': '68', 'count': '4', 'quantiles': defaultdict(None, {0.47: 45, 0.59: 45, 0.65: 45, 0.77: 31, 0.88: 31}), 'labels': {'key41': 'value41'}})
# defaultdict(None, {'type': 'summary', 'sum': '58', 'count': '4', 'quantiles': defaultdict(None, {0.0: 48, 0.5: -21, 0.9: 5, 0.95: 5, 0.99: 5, 1.0: 5}), 'labels': {'key42': 'value42'}})
# defaultdict(None, {'type': 'summary', 'sum': '-57', 'count': '2', 'quantiles': defaultdict(None, {0.14: -10, 0.46: -10, 0.68: -10, 0.83: -10, 0.9: -10}), 'labels': {'key43': 'value43'}})
# defaultdict(None, {'type': 'summary', 'sum': '1', 'count': '1', 'quantiles': defaultdict(None, {0.0: 1, 0.5: 1, 0.9: 1, 0.95: 1, 0.99: 1, 1.0: 1}), 'labels': {'key44': 'value44'}})
# defaultdict(None, {'type': 'summary', 'sum': '-10', 'count': '2', 'quantiles': defaultdict(None, {0.0: -8, 0.5: -2, 0.9: -2, 0.95: -2, 0.99: -2, 1.0: -2}), 'labels': {'key45': 'value45'}})
# defaultdict(None, {'type': 'summary', 'sum': '-108', 'count': '5', 'quantiles': defaultdict(None, {0.0: -25, 0.33: 21, 0.46: 21, 0.89: -42, 0.95: -42}), 'labels': {'key47': 'value47'}})
# defaultdict(None, {'type': 'summary', 'sum': '-89', 'count': '3', 'quantiles': defaultdict(None, {0.0: -40, 0.5: -45, 0.9: -4, 0.95: -4, 0.99: -4, 1.0: -4}), 'labels': {'key49': 'value49'}})
# defaultdict(None, {'type': 'summary', 'sum': '-47', 'count': '1', 'quantiles': defaultdict(None, {0.21: -47, 0.52: -47, 0.63: -47, 0.68: -47, 0.99: -47}), 'labels': {'key51': 'value51'}})
# defaultdict(None, {'type': 'summary', 'sum': '38', 'count': '4', 'quantiles': defaultdict(None, {0.15: 26, 0.27: 26, 0.45: -27, 0.52: -27, 0.94: 7}), 'labels': {'key53': 'value53'}})
# defaultdict(None, {'type': 'summary', 'sum': '-49', 'count': '1', 'quantiles': defaultdict(None, {0.08: -49, 0.32: -49, 0.76: -49, 0.81: -49, 0.98: -49}), 'labels': {'key55': 'value55'}})
# defaultdict(None, {'type': 'summary', 'sum': '54', 'count': '4', 'quantiles': defaultdict(None, {0.0: 26, 0.5: 36, 0.9: -35, 0.95: -35, 0.99: -35, 1.0: -35}), 'labels': {'key59': 'value59'}})
# defaultdict(None, {'type': 'summary', 'sum': '-50', 'count': '2', 'quantiles': defaultdict(None, {0.46: -49, 0.57: -49, 0.6: -49, 0.75: -49, 0.95: -49}), 'labels': {'key61': 'value61'}})
# defaultdict(None, {'type': 'summary', 'sum': '12', 'count': '2', 'quantiles': defaultdict(None, {0.17: 31, 0.25: 31, 0.61: 31, 0.77: 31, 0.81: 31}), 'labels': {'key62': 'value62'}})
# defaultdict(None, {'type': 'summary', 'sum': '65', 'count': '4', 'quantiles': defaultdict(None, {0.01: 20, 0.36: 37, 0.6: 37, 0.69: -25, 0.7: -25}), 'labels': {'key63': 'value63'}})
# defaultdict(None, {'type': 'summary', 'sum': '5', 'count': '2', 'quantiles': defaultdict(None, {0.24: -44, 0.4: -44, 0.76: -44, 0.87: -44, 0.98: -44}), 'labels': {'key68': 'value68'}})
# defaultdict(None, {'type': 'summary', 'sum': '4', 'count': '1', 'quantiles': defaultdict(None, {0.0: 4, 0.5: 4, 0.9: 4, 0.95: 4, 0.99: 4, 1.0: 4}), 'labels': {'key71': 'value71'}})
# defaultdict(None, {'type': 'summary', 'sum': '12', 'count': '1', 'quantiles': defaultdict(None, {0.0: 12, 0.5: 12, 0.9: 12, 0.95: 12, 0.99: 12, 1.0: 12}), 'labels': {'key72': 'value72'}})
# defaultdict(None, {'type': 'summary', 'sum': '68', 'count': '5', 'quantiles': defaultdict(None, {0.22: 38, 0.28: 40, 0.64: 9, 0.66: 9, 0.67: 9}), 'labels': {'key74': 'value74'}})
# defaultdict(None, {'type': 'summary', 'sum': '-43', 'count': '5', 'quantiles': defaultdict(None, {0.02: -43, 0.1: -43, 0.13: -43, 0.46: -10, 0.73: -8}), 'labels': {'key76': 'value76'}})
# defaultdict(None, {'type': 'summary', 'sum': '9', 'count': '1', 'quantiles': defaultdict(None, {0.0: 9, 0.5: 9, 0.9: 9, 0.95: 9, 0.99: 9, 1.0: 9}), 'labels': {'key79': 'value79'}})
# defaultdict(None, {'type': 'summary', 'sum': '-26', 'count': '5', 'quantiles': defaultdict(None, {0.0: 32, 0.5: -39, 0.9: 29, 0.95: 29, 0.99: 29, 1.0: 29}), 'labels': {'key80': 'value80'}})
# defaultdict(None, {'type': 'summary', 'sum': '71', 'count': '5', 'quantiles': defaultdict(None, {0.0: -31, 0.5: 48, 0.9: 26, 0.95: 26, 0.99: 26, 1.0: 26}), 'labels': {'key82': 'value82'}})
# defaultdict(None, {'type': 'summary', 'sum': '-118', 'count': '3', 'quantiles': defaultdict(None, {0.03: -30, 0.13: -30, 0.36: -30, 0.56: -49, 0.95: -49}), 'labels': {'key83': 'value83'}})
# defaultdict(None, {'type': 'summary', 'sum': '-14', 'count': '3', 'quantiles': defaultdict(None, {0.0: -43, 0.5: 14, 0.9: 15, 0.95: 15, 0.99: 15, 1.0: 15}), 'labels': {'key84': 'value84'}})
# defaultdict(None, {'type': 'summary', 'sum': '-84', 'count': '3', 'quantiles': defaultdict(None, {0.0: -29, 0.5: -50, 0.9: -5, 0.95: -5, 0.99: -5, 1.0: -5}), 'labels': {'key87': 'value87'}})
# defaultdict(None, {'type': 'summary', 'sum': '93', 'count': '5', 'quantiles': defaultdict(None, {0.02: 7, 0.86: 29, 0.91: 29, 0.96: 29}), 'labels': {'key89': 'value89'}})
# defaultdict(None, {'type': 'summary', 'sum': '69', 'count': '3', 'quantiles': defaultdict(None, {0.0: 40, 0.5: 49, 0.9: -20, 0.95: -20, 0.99: -20, 1.0: -20}), 'labels': {'key90': 'value90'}})
# defaultdict(None, {'type': 'summary', 'sum': '-27', 'count': '1', 'quantiles': defaultdict(None, {0.0: -27, 0.5: -27, 0.9: -27, 0.95: -27, 0.99: -27, 1.0: -27}), 'labels': {'key91': 'value91'}})
# defaultdict(None, {'type': 'summary', 'sum': '26', 'count': '1', 'quantiles': defaultdict(None, {0.0: 26, 0.5: 26, 0.9: 26, 0.95: 26, 0.99: 26, 1.0: 26}), 'labels': {'key98': 'value98'}})
# defaultdict(None, {'type': 'summary', 'sum': '-80', 'count': '3', 'quantiles': defaultdict(None, {0.42: -30, 0.43: -30, 0.59: -3, 0.75: -3, 0.81: -3}), 'labels': {'key100': 'value100'}})
# defaultdict(None, {'type': 'summary', 'sum': '-96', 'count': '4', 'quantiles': defaultdict(None, {0.0: 0, 0.5: -41, 0.9: -25, 0.95: -25, 0.99: -25, 1.0: -25}), 'labels': {'key102': 'value102'}})
# defaultdict(None, {'type': 'summary', 'sum': '-10', 'count': '5', 'quantiles': defaultdict(None, {0.45: -14, 0.52: -38, 0.56: -38, 0.72: -38, 0.94: -3}), 'labels': {'key104': 'value104'}})
# defaultdict(None, {'type': 'summary', 'sum': '20', 'count': '2', 'quantiles': defaultdict(None, {0.0: -15, 0.5: 35, 0.9: 35, 0.95: 35, 0.99: 35, 1.0: 35}), 'labels': {'key106': 'value106'}})
# defaultdict(None, {'type': 'summary', 'sum': '-62', 'count': '2', 'quantiles': defaultdict(None, {0.0: -27, 0.04: -35, 0.25: -35, 0.34: -35}), 'labels': {'key115': 'value115'}})
# defaultdict(None, {'type': 'summary', 'sum': '25', 'count': '2', 'quantiles': defaultdict(None, {0.24: 22, 0.53: 22, 0.55: 22, 0.76: 22, 0.9: 22}), 'labels': {'key116': 'value116'}})
# defaultdict(None, {'type': 'summary', 'sum': '-51', 'count': '4', 'quantiles': defaultdict(None, {0.09: 26, 0.27: 26, 0.37: -29, 0.41: -29, 0.52: -29}), 'labels': {'key118': 'value118'}})
# defaultdict(None, {'type': 'summary', 'sum': '-9', 'count': '1', 'quantiles': defaultdict(None, {0.0: -9, 0.5: -9, 0.9: -9, 0.95: -9, 0.99: -9, 1.0: -9}), 'labels': {'key120': 'value120'}})
# defaultdict(None, {'type': 'summary', 'sum': '121', 'count': '5', 'quantiles': defaultdict(None, {0.33: 24, 0.74: 25, 0.88: 30, 0.93: 30, 0.97: 30}), 'labels': {'key123': 'value123'}})
# defaultdict(None, {'type': 'summary', 'sum': '-36', 'count': '1', 'quantiles': defaultdict(None, {0.0: -36, 0.15: -36, 0.17: -36, 0.54: -36, 0.89: -36}), 'labels': {'key124': 'value124'}})
# defaultdict(None, {'type': 'summary', 'sum': '-14', 'count': '3', 'quantiles': defaultdict(None, {0.11: -13, 0.13: -13, 0.44: -13, 0.46: -13, 0.54: -27}), 'labels': {'key128': 'value128'}})
# defaultdict(None, {'type': 'summary', 'sum': '-90', 'count': '4', 'quantiles': defaultdict(None, {0.18: -37, 0.46: -3, 0.48: -3, 0.58: -3, 0.85: -2}), 'labels': {'key129': 'value129'}})
# defaultdict(None, {'type': 'summary', 'sum': '-8', 'count': '2', 'quantiles': defaultdict(None, {0.0: 19, 0.5: -27, 0.9: -27, 0.95: -27, 0.99: -27, 1.0: -27}), 'labels': {'key130': 'value130'}})
# defaultdict(None, {'type': 'summary', 'sum': '59', 'count': '3', 'quantiles': defaultdict(None, {0.08: 33, 0.1: 33, 0.55: -6, 0.63: -6, 0.96: -6}), 'labels': {'key131': 'value131'}})
# defaultdict(None, {'type': 'summary', 'sum': '39', 'count': '2', 'quantiles': defaultdict(None, {0.17: -10, 0.26: -10, 0.56: -10, 0.72: -10, 0.81: -10}), 'labels': {'key133': 'value133'}})
# defaultdict(None, {'type': 'summary', 'sum': '26', 'count': '3', 'quantiles': defaultdict(None, {0.24: 14, 0.31: 14, 0.32: 14, 0.5: 14, 0.79: -26}), 'labels': {'key134': 'value134'}})
# defaultdict(None, {'type': 'summary', 'sum': '-74', 'count': '3', 'quantiles': defaultdict(None, {0.07: -22, 0.32: -22, 0.46: -22, 0.7: -5, 0.77: -5}), 'labels': {'key135': 'value135'}})
# defaultdict(None, {'type': 'summary', 'sum': '10', 'count': '3', 'quantiles': defaultdict(None, {0.0: -22, 0.5: -12, 0.9: 44, 0.95: 44, 0.99: 44, 1.0: 44}), 'labels': {'key136': 'value136'}})
# defaultdict(None, {'type': 'summary', 'sum': '-91', 'count': '3', 'quantiles': defaultdict(None, {0.0: -35, 0.5: -37, 0.9: -19, 0.95: -19, 0.99: -19, 1.0: -19}), 'labels': {'key137': 'value137'}})
# defaultdict(None, {'type': 'summary', 'sum': '-81', 'count': '4', 'quantiles': defaultdict(None, {0.24: -23, 0.37: -30, 0.47: -30, 0.77: 4, 0.82: 4}), 'labels': {'key138': 'value138'}})
# defaultdict(None, {'type': 'summary', 'sum': '47', 'count': '4', 'quantiles': defaultdict(None, {0.12: 50, 0.31: 50, 0.42: 22, 0.48: 22, 0.87: -25}), 'labels': {'key139': 'value139'}})
# defaultdict(None, {'type': 'summary', 'sum': '-42', 'count': '4', 'quantiles': defaultdict(None, {0.0: 48, 0.5: -36, 0.9: -11, 0.95: -11, 0.99: -11, 1.0: -11}), 'labels': {'key142': 'value142'}})
# defaultdict(None, {'type': 'summary', 'sum': '41', 'count': '1', 'quantiles': defaultdict(None, {0.33: 41, 0.42: 41, 0.57: 41, 0.68: 41, 0.77: 41}), 'labels': {'key143': 'value143'}})
# defaultdict(None, {'type': 'summary', 'sum': '25', 'count': '2', 'quantiles': defaultdict(None, {0.01: 47, 0.06: 47, 0.16: 47, 0.44: 47, 0.76: 47}), 'labels': {'key145': 'value145'}})
# defaultdict(None, {'type': 'summary', 'sum': '53', 'count': '3', 'quantiles': defaultdict(None, {0.06: -20, 0.12: -20, 0.23: -20, 0.44: -20, 0.81: 39}), 'labels': {'key147': 'value147'}})
# defaultdict(None, {'type': 'summary', 'sum': '-81', 'count': '3', 'quantiles': defaultdict(None, {0.01: -35, 0.05: -35, 0.6: -1, 0.83: -1, 0.97: -1}), 'labels': {'key149': 'value149'}})
# defaultdict(None, {'type': 'summary', 'sum': '-8', 'count': '3', 'quantiles': defaultdict(None, {0.0: -8, 0.5: -6, 0.9: 6, 0.95: 6, 0.99: 6, 1.0: 6}), 'labels': {'key152': 'value152'}})
# defaultdict(None, {'type': 'summary', 'sum': '-3', 'count': '2', 'quantiles': defaultdict(None, {0.02: 3, 0.24: 3, 0.29: 3, 0.56: 3, 0.76: 3}), 'labels': {'key157': 'value157'}})
# defaultdict(None, {'type': 'summary', 'sum': '-68', 'count': '4', 'quantiles': defaultdict(None, {0.05: -30, 0.22: -30, 0.29: -30, 0.75: -18, 0.88: -18}), 'labels': {'key158': 'value158'}})
# defaultdict(None, {'type': 'summary', 'sum': '14', 'count': '4', 'quantiles': defaultdict(None, {0.01: -39, 0.07: -39, 0.44: 38, 0.45: 38, 0.58: 38}), 'labels': {'key159': 'value159'}})
# defaultdict(None, {'type': 'summary', 'sum': '-29', 'count': '1', 'quantiles': defaultdict(None, {0.0: -29, 0.5: -29, 0.9: -29, 0.95: -29, 0.99: -29, 1.0: -29}), 'labels': {'key160': 'value160'}})
# defaultdict(None, {'type': 'summary', 'sum': '-128', 'count': '4', 'quantiles': defaultdict(None, {0.06: -45, 0.1: -45, 0.58: -10, 0.64: -10, 0.83: -49}), 'labels': {'key163': 'value163'}})
# defaultdict(None, {'type': 'summary', 'sum': '38', 'count': '3', 'quantiles': defaultdict(None, {0.0: 9, 0.5: 2, 0.9: 27, 0.95: 27, 0.99: 27, 1.0: 27}), 'labels': {'key164': 'value164'}})
# defaultdict(None, {'type': 'summary', 'sum': '-73', 'count': '2', 'quantiles': defaultdict(None, {0.0: -38, 0.5: -35, 0.9: -35, 0.95: -35, 0.99: -35, 1.0: -35}), 'labels': {'key166': 'value166'}})
# defaultdict(None, {'type': 'summary', 'sum': '-48', 'count': '1', 'quantiles': defaultdict(None, {0.13: -48, 0.56: -48, 0.58: -48, 0.68: -48, 0.9: -48}), 'labels': {'key168': 'value168'}})
# defaultdict(None, {'type': 'summary', 'sum': '10', 'count': '1', 'quantiles': defaultdict(None, {0.0: 10, 0.5: 10, 0.9: 10, 0.95: 10, 0.99: 10, 1.0: 10}), 'labels': {'key170': 'value170'}})
# defaultdict(None, {'type': 'summary', 'sum': '-83', 'count': '5', 'quantiles': defaultdict(None, {0.0: 0, 0.16: 12, 0.29: -18, 0.87: -35, 1.0: -35}), 'labels': {'key171': 'value171'}})
# defaultdict(None, {'type': 'summary', 'sum': '-32', 'count': '1', 'quantiles': defaultdict(None, {0.19: -32, 0.53: -32, 0.62: -32, 0.67: -32, 0.85: -32}), 'labels': {'key178': 'value178'}})
# defaultdict(None, {'type': 'summary', 'sum': '13', 'count': '4', 'quantiles': defaultdict(None, {0.0: -8, 0.5: 45, 0.9: -41, 0.95: -41, 0.99: -41, 1.0: -41}), 'labels': {'key180': 'value180'}})
# defaultdict(None, {'type': 'summary', 'sum': '-7', 'count': '1', 'quantiles': defaultdict(None, {0.0: -7, 0.5: -7, 0.9: -7, 0.95: -7, 0.99: -7, 1.0: -7}), 'labels': {'key182': 'value182'}})
# defaultdict(None, {'type': 'summary', 'sum': '28', 'count': '2', 'quantiles': defaultdict(None, {0.0: -7, 0.5: 35, 0.9: 35, 0.95: 35, 0.99: 35, 1.0: 35}), 'labels': {'key190': 'value190'}})
# defaultdict(None, {'type': 'summary', 'sum': '-46', 'count': '2', 'quantiles': defaultdict(None, {0.0: 0, 0.5: -46, 0.9: -46, 0.95: -46, 0.99: -46, 1.0: -46}), 'labels': {'key192': 'value192'}})
# defaultdict(None, {'type': 'summary', 'sum': '-45', 'count': '1', 'quantiles': defaultdict(None, {0.0: -45, 0.5: -45, 0.9: -45, 0.95: -45, 0.99: -45, 1.0: -45}), 'labels': {'key193': 'value193'}})
# defaultdict(None, {'type': 'summary', 'sum': '94', 'count': '4', 'quantiles': defaultdict(None, {0.0: 45, 0.5: 43, 0.9: -27, 0.95: -27, 0.99: -27, 1.0: -27}), 'labels': {'key196': 'value196'}})
# defaultdict(None, {'type': 'summary', 'sum': '4', 'count': '1', 'quantiles': defaultdict(None, {0.27: 4, 0.36: 4, 0.48: 4, 0.61: 4, 0.73: 4}), 'labels': {'key197': 'value197'}})
# defaultdict(None, {'type': 'summary', 'sum': '29', 'count': '1', 'quantiles': defaultdict(None, {0.0: 29, 0.5: 29, 0.9: 29, 0.95: 29, 0.99: 29, 1.0: 29}), 'labels': {'key199': 'value199'}})
# defaultdict(None, {'type': 'summary', 'sum': '32', 'count': '5', 'quantiles': defaultdict(None, {0.06: 40, 0.7: -49, 0.85: 27, 0.86: 27}), 'labels': {'key204': 'value204'}})
# defaultdict(None, {'type': 'summary', 'sum': '-115', 'count': '4', 'quantiles': defaultdict(None, {0.0: -30, 0.5: -50, 0.9: -33, 0.95: -33, 0.99: -33, 1.0: -33}), 'labels': {'key207': 'value207'}})
# defaultdict(None, {'type': 'summary', 'sum': '-28', 'count': '1', 'quantiles': defaultdict(None, {0.13: -28, 0.19: -28, 0.31: -28, 0.74: -28, 0.84: -28}), 'labels': {'key208': 'value208'}})
# defaultdict(None, {'type': 'summary', 'sum': '-27', 'count': '1', 'quantiles': defaultdict(None, {0.0: -27, 0.5: -27, 0.9: -27, 0.95: -27, 0.99: -27, 1.0: -27}), 'labels': {'key214': 'value214'}})
# defaultdict(None, {'type': 'summary', 'sum': '40', 'count': '3', 'quantiles': defaultdict(None, {0.39: -10, 0.48: -10, 0.56: 49, 0.83: 49, 0.92: 49}), 'labels': {'key216': 'value216'}})
# defaultdict(None, {'type': 'summary', 'sum': '32', 'count': '3', 'quantiles': defaultdict(None, {0.0: -22, 0.5: 15, 0.9: 39, 0.95: 39, 0.99: 39, 1.0: 39}), 'labels': {'key218': 'value218'}})
# defaultdict(None, {'type': 'summary', 'sum': '-46', 'count': '2', 'quantiles': defaultdict(None, {0.0: -24, 0.5: -22, 0.9: -22, 0.95: -22, 0.99: -22, 1.0: -22}), 'labels': {'key219': 'value219'}})
# defaultdict(None, {'type': 'summary', 'sum': '25', 'count': '4', 'quantiles': defaultdict(None, {0.0: 8, 0.5: 3, 0.9: 36, 0.95: 36, 0.99: 36, 1.0: 36}), 'labels': {'key220': 'value220'}})
# defaultdict(None, {'type': 'summary', 'sum': '-41', 'count': '3', 'quantiles': defaultdict(None, {0.2: 21, 0.29: 21, 0.39: 21, 0.74: -42, 0.96: -42}), 'labels': {'key221': 'value221'}})
# defaultdict(None, {'type': 'summary', 'sum': '49', 'count': '1', 'quantiles': defaultdict(None, {0.22: 49, 0.31: 49, 0.42: 49, 0.66: 49, 0.89: 49}), 'labels': {'key225': 'value225'}})
# defaultdict(None, {'type': 'summary', 'sum': '30', 'count': '3', 'quantiles': defaultdict(None, {0.0: 24, 0.5: -1, 0.9: 7, 0.95: 7, 0.99: 7, 1.0: 7}), 'labels': {'key229': 'value229'}})
# defaultdict(None, {'type': 'summary', 'sum': '49', 'count': '4', 'quantiles': defaultdict(None, {0.0: -8, 0.5: -7, 0.9: 23, 0.95: 23, 0.99: 23, 1.0: 23}), 'labels': {'key231': 'value231'}})
# defaultdict(None, {'type': 'summary', 'sum': '-94', 'count': '5', 'quantiles': defaultdict(None, {0.0: -31, 0.5: 14, 0.9: -3, 0.95: -3, 0.99: -3, 1.0: -3}), 'labels': {'key234': 'value234'}})
# defaultdict(None, {'type': 'summary', 'sum': '28', 'count': '4', 'quantiles': defaultdict(None, {0.0: 19, 0.5: -1, 0.9: -10, 0.95: -10, 0.99: -10, 1.0: -10}), 'labels': {'key235': 'value235'}})
# defaultdict(None, {'type': 'summary', 'sum': '-102', 'count': '5', 'quantiles': defaultdict(None, {0.0: -31, 0.5: -11, 0.9: -5, 0.95: -5, 0.99: -5, 1.0: -5}), 'labels': {'key236': 'value236'}})
# defaultdict(None, {'type': 'summary', 'sum': '-84', 'count': '2', 'quantiles': defaultdict(None, {0.0: -40, 0.5: -44, 0.9: -44, 0.95: -44, 0.99: -44, 1.0: -44}), 'labels': {'key237': 'value237'}})
# defaultdict(None, {'type': 'summary', 'sum': '-42', 'count': '1', 'quantiles': defaultdict(None, {0.06: -42, 0.07: -42, 0.15: -42, 0.9: -42, 0.97: -42}), 'labels': {'key240': 'value240'}})
# defaultdict(None, {'type': 'summary', 'sum': '-47', 'count': '2', 'quantiles': defaultdict(None, {0.05: -33, 0.17: -33, 0.34: -33, 0.87: -33}), 'labels': {'key244': 'value244'}})
# defaultdict(None, {'type': 'summary', 'sum': '43', 'count': '4', 'quantiles': defaultdict(None, {0.0: 38, 0.5: -35, 0.9: 14, 0.95: 14, 0.99: 14, 1.0: 14}), 'labels': {'key248': 'value248'}})
# defaultdict(None, {'type': 'summary', 'sum': '90', 'count': '5', 'quantiles': defaultdict(None, {0.06: 15, 0.09: 15, 0.19: 15, 0.45: 49, 0.91: 30}), 'labels': {'key251': 'value251'}})
# defaultdict(None, {'type': 'summary', 'sum': '-9', 'count': '4', 'quantiles': defaultdict(None, {0.0: -24, 0.5: 3, 0.9: 44, 0.95: 44, 0.99: 44, 1.0: 44}), 'labels': {'key253': 'value253'}})
# defaultdict(None, {'type': 'summary', 'sum': '-41', 'count': '4', 'quantiles': defaultdict(None, {0.0: -24, 0.5: -19, 0.9: 38, 0.95: 38, 0.99: 38, 1.0: 38}), 'labels': {'key256': 'value256'}})
# defaultdict(None, {'type': 'summary', 'sum': '11', 'count': '3', 'quantiles': defaultdict(None, {0.0: -16, 0.5: 21, 0.9: 6, 0.95: 6, 0.99: 6, 1.0: 6}), 'labels': {'key257': 'value257'}})
# defaultdict(None, {'type': 'summary', 'sum': '46', 'count': '3', 'quantiles': defaultdict(None, {0.47: 42, 0.5: 42, 0.7: -14, 0.89: -14, 0.93: -14}), 'labels': {'key258': 'value258'}})
# defaultdict(None, {'type': 'summary', 'sum': '25', 'count': '1', 'quantiles': defaultdict(None, {0.0: 25, 0.5: 25, 0.9: 25, 0.95: 25, 0.99: 25, 1.0: 25}), 'labels': {'key259': 'value259'}})
# defaultdict(None, {'type': 'summary', 'sum': '18', 'count': '2', 'quantiles': defaultdict(None, {0.0: -16, 0.5: 34, 0.9: 34, 0.95: 34, 0.99: 34, 1.0: 34}), 'labels': {'key263': 'value263'}})
# defaultdict(None, {'type': 'summary', 'sum': '27', 'count': '5', 'quantiles': defaultdict(None, {0.0: 37, 0.5: -22, 0.9: 22, 0.95: 22, 0.99: 22, 1.0: 22}), 'labels': {'key268': 'value268'}})
# defaultdict(None, {'type': 'summary', 'sum': '-45', 'count': '4', 'quantiles': defaultdict(None, {0.0: -8, 0.5: -46, 0.9: -40, 0.95: -40, 0.99: -40, 1.0: -40}), 'labels': {'key271': 'value271'}})
# defaultdict(None, {'type': 'summary', 'sum': '28', 'count': '3', 'quantiles': defaultdict(None, {0.2: 44, 0.41: 44, 0.53: 29, 0.61: 29, 0.79: 29}), 'labels': {'key272': 'value272'}})
# defaultdict(None, {'type': 'summary', 'sum': '-64', 'count': '3', 'quantiles': defaultdict(None, {0.02: -14, 0.38: -14, 0.46: -14, 0.85: -50, 0.99: -50}), 'labels': {'key275': 'value275'}})
# defaultdict(None, {'type': 'summary', 'sum': '-56', 'count': '5', 'quantiles': defaultdict(None, {0.08: -46, 0.28: -42, 0.44: -42, 0.53: 23, 0.79: 27}), 'labels': {'key277': 'value277'}})
# defaultdict(None, {'type': 'summary', 'sum': '46', 'count': '4', 'quantiles': defaultdict(None, {0.25: -13, 0.39: -28, 0.41: -28, 0.57: -28, 0.97: 46}), 'labels': {'key283': 'value283'}})
# defaultdict(None, {'type': 'summary', 'sum': '25', 'count': '3', 'quantiles': defaultdict(None, {0.21: 43, 0.29: 43, 0.41: 43, 0.42: 43, 0.64: 30}), 'labels': {'key285': 'value285'}})
# defaultdict(None, {'type': 'summary', 'sum': '-50', 'count': '1', 'quantiles': defaultdict(None, {0.02: -50, 0.06: -50, 0.38: -50, 0.65: -50, 0.78: -50}), 'labels': {'key291': 'value291'}})
# defaultdict(None, {'type': 'summary', 'sum': '22', 'count': '2', 'quantiles': defaultdict(None, {0.0: -24, 0.5: 46, 0.9: 46, 0.95: 46, 0.99: 46, 1.0: 46}), 'labels': {'key296': 'value296'}})
# defaultdict(None, {'type': 'summary', 'sum': '-74', 'count': '5', 'quantiles': defaultdict(None, {0.27: -19, 0.58: -16, 0.76: -12, 0.79: -12, 0.95: -12}), 'labels': {'key301': 'value301'}})
# defaultdict(None, {'type': 'summary', 'sum': '-18', 'count': '3', 'quantiles': defaultdict(None, {0.19: -6, 0.52: 12, 0.66: 12, 0.7: 12, 0.91: 12}), 'labels': {'key304': 'value304'}})
# defaultdict(None, {'type': 'summary', 'sum': '-2', 'count': '3', 'quantiles': defaultdict(None, {0.0: 10, 0.07: -35, 0.18: -35, 0.45: -35, 0.6: 23}), 'labels': {'key308': 'value308'}})
# defaultdict(None, {'type': 'summary', 'sum': '62', 'count': '3', 'quantiles': defaultdict(None, {0.04: -14, 0.33: -14, 0.67: 28, 0.73: 28, 0.91: 28}), 'labels': {'key311': 'value311'}})
# defaultdict(None, {'type': 'summary', 'sum': '-58', 'count': '2', 'quantiles': defaultdict(None, {0.0: -47, 0.5: -11, 0.9: -11, 0.95: -11, 0.99: -11, 1.0: -11}), 'labels': {'key315': 'value315'}})
# defaultdict(None, {'type': 'summary', 'sum': '-5', 'count': '4', 'quantiles': defaultdict(None, {0.02: -12, 0.36: 13, 0.37: 13, 0.82: 30, 0.84: 30}), 'labels': {'key318': 'value318'}})
# defaultdict(None, {'type': 'summary', 'sum': '44', 'count': '1', 'quantiles': defaultdict(None, {0.0: 44, 0.5: 44, 0.9: 44, 0.95: 44, 0.99: 44, 1.0: 44}), 'labels': {'key320': 'value320'}})
# defaultdict(None, {'type': 'summary', 'sum': '-18', 'count': '3', 'quantiles': defaultdict(None, {0.05: -4, 0.07: -4, 0.16: -4, 0.58: 7, 0.87: 7}), 'labels': {'key323': 'value323'}})
# defaultdict(None, {'type': 'summary', 'sum': '-46', 'count': '1', 'quantiles': defaultdict(None, {0.14: -46, 0.32: -46, 0.35: -46, 0.46: -46, 0.59: -46}), 'labels': {'key329': 'value329'}})
# defaultdict(None, {'type': 'summary', 'sum': '-31', 'count': '4', 'quantiles': defaultdict(None, {0.01: 35, 0.4: -9, 0.76: -49, 0.86: -49, 0.99: -49}), 'labels': {'key332': 'value332'}})
# defaultdict(None, {'type': 'summary', 'sum': '58', 'count': '2', 'quantiles': defaultdict(None, {0.0: 19, 0.5: 39, 0.9: 39, 0.95: 39, 0.99: 39, 1.0: 39}), 'labels': {'key333': 'value333'}})
# defaultdict(None, {'type': 'summary', 'sum': '-36', 'count': '5', 'quantiles': defaultdict(None, {0.07: -50, 0.09: -50, 0.15: -50, 0.36: -16, 0.51: 24}), 'labels': {'key341': 'value341'}})
# defaultdict(None, {'type': 'summary', 'sum': '-40', 'count': '2', 'quantiles': defaultdict(None, {0.0: -31, 0.5: -9, 0.9: -9, 0.95: -9, 0.99: -9, 1.0: -9}), 'labels': {'key342': 'value342'}})
# defaultdict(None, {'type': 'summary', 'sum': '-25', 'count': '1', 'quantiles': defaultdict(None, {0.0: -25, 0.5: -25, 0.9: -25, 0.95: -25, 0.99: -25, 1.0: -25}), 'labels': {'key345': 'value345'}})
# defaultdict(None, {'type': 'summary', 'sum': '7', 'count': '1', 'quantiles': defaultdict(None, {0.0: 7, 0.5: 7, 0.9: 7, 0.95: 7, 0.99: 7, 1.0: 7}), 'labels': {'key349': 'value349'}})
# defaultdict(None, {'type': 'summary', 'sum': '11', 'count': '1', 'quantiles': defaultdict(None, {0.0: 11, 0.5: 11, 0.9: 11, 0.95: 11, 0.99: 11, 1.0: 11}), 'labels': {'key350': 'value350'}})
# defaultdict(None, {'type': 'summary', 'sum': '-39', 'count': '5', 'quantiles': defaultdict(None, {0.0: -30, 0.5: 21, 0.9: -38, 0.95: -38, 0.99: -38, 1.0: -38}), 'labels': {'key353': 'value353'}})
# defaultdict(None, {'type': 'summary', 'sum': '49', 'count': '4', 'quantiles': defaultdict(None, {0.0: -24, 0.5: 19, 0.9: 21, 0.95: 21, 0.99: 21, 1.0: 21}), 'labels': {'key356': 'value356'}})
# defaultdict(None, {'type': 'summary', 'sum': '33', 'count': '2', 'quantiles': defaultdict(None, {0.0: 19, 0.5: 14, 0.9: 14, 0.95: 14, 0.99: 14, 1.0: 14}), 'labels': {'key357': 'value357'}})
# defaultdict(None, {'type': 'summary', 'sum': '-44', 'count': '5', 'quantiles': defaultdict(None, {0.02: 43, 0.23: 43, 0.59: -39, 0.61: -39, 0.88: -38}), 'labels': {'key360': 'value360'}})
# defaultdict(None, {'type': 'summary', 'sum': '-43', 'count': '2', 'quantiles': defaultdict(None, {0.0: -8, 0.5: -35, 0.9: -35, 0.95: -35, 0.99: -35, 1.0: -35}), 'labels': {'key361': 'value361'}})
# defaultdict(None, {'type': 'summary', 'sum': '62', 'count': '5', 'quantiles': defaultdict(None, {0.0: 36, 0.5: 7, 0.9: 27, 0.95: 27, 0.99: 27, 1.0: 27}), 'labels': {'key367': 'value367'}})
# defaultdict(None, {'type': 'summary', 'sum': '48', 'count': '4', 'quantiles': defaultdict(None, {0.0: 48, 0.5: 5, 0.9: 31, 0.95: 31, 0.99: 31, 1.0: 31}), 'labels': {'key376': 'value376'}})
# defaultdict(None, {'type': 'summary', 'sum': '34', 'count': '2', 'quantiles': defaultdict(None, {0.3: -7, 0.36: -7, 0.58: -7, 0.67: -7, 0.75: -7}), 'labels': {'key377': 'value377'}})
# defaultdict(None, {'type': 'summary', 'sum': '-75', 'count': '4', 'quantiles': defaultdict(None, {0.04: -41, 0.28: -41, 0.71: -10, 0.8: -10, 0.99: -10}), 'labels': {'key378': 'value378'}})
# defaultdict(None, {'type': 'summary', 'sum': '28', 'count': '1', 'quantiles': defaultdict(None, {0.0: 28, 0.5: 28, 0.9: 28, 0.95: 28, 0.99: 28, 1.0: 28}), 'labels': {'key379': 'value379'}})
# defaultdict(None, {'type': 'summary', 'sum': '-32', 'count': '4', 'quantiles': defaultdict(None, {0.0: 11, 0.5: 22, 0.9: -29, 0.95: -29, 0.99: -29, 1.0: -29}), 'labels': {'key383': 'value383'}})
# defaultdict(None, {'type': 'summary', 'sum': '-58', 'count': '3', 'quantiles': defaultdict(None, {0.0: 5, 0.5: -36, 0.9: -27, 0.95: -27, 0.99: -27, 1.0: -27}), 'labels': {'key386': 'value386'}})
# defaultdict(None, {'type': 'summary', 'sum': '-3', 'count': '4', 'quantiles': defaultdict(None, {0.44: -20, 0.6: -20, 0.74: 30, 0.91: 30, 0.92: 30}), 'labels': {'key388': 'value388'}})
# defaultdict(None, {'type': 'summary', 'sum': '-20', 'count': '1', 'quantiles': defaultdict(None, {0.39: -20, 0.45: -20, 0.61: -20, 0.66: -20, 0.95: -20}), 'labels': {'key390': 'value390'}})
# defaultdict(None, {'type': 'summary', 'sum': '-8', 'count': '5', 'quantiles': defaultdict(None, {0.0: 40, 0.5: -15, 0.9: -38, 0.95: -38, 0.99: -38, 1.0: -38}), 'labels': {'key392': 'value392'}})
# defaultdict(None, {'type': 'summary', 'sum': '13', 'count': '2', 'quantiles': defaultdict(None, {0.0: -23, 0.5: 36, 0.9: 36, 0.95: 36, 0.99: 36, 1.0: 36}), 'labels': {'key393': 'value393'}})
# defaultdict(None, {'type': 'summary', 'sum': '22', 'count': '1', 'quantiles': defaultdict(None, {0.0: 22, 0.5: 22, 0.9: 22, 0.95: 22, 0.99: 22, 1.0: 22}), 'labels': {'key395': 'value395'}})
# defaultdict(None, {'type': 'summary', 'sum': '-55', 'count': '5', 'quantiles': defaultdict(None, {0.0: -30, 0.5: 10, 0.9: -1, 0.95: -1, 0.99: -1, 1.0: -1}), 'labels': {'key397': 'value397'}})
# defaultdict(None, {'type': 'summary', 'sum': '40', 'count': '3', 'quantiles': defaultdict(None, {0.0: -19, 0.5: 13, 0.9: 46, 0.95: 46, 0.99: 46, 1.0: 46}), 'labels': {'key400': 'value400'}})
# defaultdict(None, {'type': 'summary', 'sum': '24', 'count': '1', 'quantiles': defaultdict(None, {0.02: 24, 0.15: 24, 0.23: 24, 0.24: 24, 0.72: 24}), 'labels': {'key401': 'value401'}})
# defaultdict(None, {'type': 'summary', 'sum': '-105', 'count': '4', 'quantiles': defaultdict(None, {0.01: -30, 0.02: -30, 0.2: -30, 0.22: -30, 0.25: -30}), 'labels': {'key406': 'value406'}})
# defaultdict(None, {'type': 'summary', 'sum': '29', 'count': '4', 'quantiles': defaultdict(None, {0.0: 40, 0.5: 14, 0.9: 22, 0.95: 22, 0.99: 22, 1.0: 22}), 'labels': {'key409': 'value409'}})
# defaultdict(None, {'type': 'summary', 'sum': '-24', 'count': '3', 'quantiles': defaultdict(None, {0.04: 40, 0.16: 40, 0.46: 40, 0.63: -40}), 'labels': {'key410': 'value410'}})
# defaultdict(None, {'type': 'summary', 'sum': '-19', 'count': '2', 'quantiles': defaultdict(None, {0.39: -12, 0.52: -12, 0.59: -12, 0.9: -12, 0.95: -12}), 'labels': {'key411': 'value411'}})
# defaultdict(None, {'type': 'summary', 'sum': '39', 'count': '4', 'quantiles': defaultdict(None, {0.16: 7, 0.64: 23, 0.73: 39, 0.96: 39, 1.0: 39}), 'labels': {'key412': 'value412'}})
# defaultdict(None, {'type': 'summary', 'sum': '81', 'count': '5', 'quantiles': defaultdict(None, {0.34: 50, 0.54: -39, 0.71: -39, 0.84: 30, 0.96: 30}), 'labels': {'key417': 'value417'}})
# defaultdict(None, {'type': 'summary', 'sum': '34', 'count': '4', 'quantiles': defaultdict(None, {0.0: 32, 0.5: -20, 0.9: 45, 0.95: 45, 0.99: 45, 1.0: 45}), 'labels': {'key420': 'value420'}})
# defaultdict(None, {'type': 'summary', 'sum': '-50', 'count': '2', 'quantiles': defaultdict(None, {0.35: -17, 0.42: -17, 0.47: -17, 0.48: -17, 0.64: -17}), 'labels': {'key421': 'value421'}})
# defaultdict(None, {'type': 'summary', 'sum': '5', 'count': '2', 'quantiles': defaultdict(None, {0.0: -2, 0.5: 7, 0.9: 7, 0.95: 7, 0.99: 7, 1.0: 7}), 'labels': {'key425': 'value425'}})
# defaultdict(None, {'type': 'summary', 'sum': '-36', 'count': '3', 'quantiles': defaultdict(None, {0.0: 3, 0.5: 11, 0.9: -50, 0.95: -50, 0.99: -50, 1.0: -50}), 'labels': {'key429': 'value429'}})
# defaultdict(None, {'type': 'summary', 'sum': '24', 'count': '2', 'quantiles': defaultdict(None, {0.0: 26, 0.5: -2, 0.9: -2, 0.95: -2, 0.99: -2, 1.0: -2}), 'labels': {'key430': 'value430'}})
# defaultdict(None, {'type': 'summary', 'sum': '34', 'count': '3', 'quantiles': defaultdict(None, {0.0: 48, 0.5: -5, 0.9: -9, 0.95: -9, 0.99: -9, 1.0: -9}), 'labels': {'key431': 'value431'}})
# defaultdict(None, {'type': 'summary', 'sum': '-46', 'count': '2', 'quantiles': defaultdict(None, {0.18: -49, 0.23: -49, 0.47: -49, 0.85: -49, 0.98: -49}), 'labels': {'key435': 'value435'}})
# defaultdict(None, {'type': 'summary', 'sum': '-55', 'count': '4', 'quantiles': defaultdict(None, {0.0: -40, 0.37: -26, 0.66: -26, 0.8: 30, 0.84: 30}), 'labels': {'key436': 'value436'}})
# defaultdict(None, {'type': 'summary', 'sum': '32', 'count': '4', 'quantiles': defaultdict(None, {0.0: -8, 0.5: 28, 0.9: 4, 0.95: 4, 0.99: 4, 1.0: 4}), 'labels': {'key439': 'value439'}})
# defaultdict(None, {'type': 'summary', 'sum': '48', 'count': '2', 'quantiles': defaultdict(None, {0.1: 29, 0.32: 29, 0.4: 29, 0.5: 29, 0.82: 29}), 'labels': {'key441': 'value441'}})
# defaultdict(None, {'type': 'summary', 'sum': '-67', 'count': '2', 'quantiles': defaultdict(None, {0.0: -38, 0.5: -29, 0.9: -29, 0.95: -29, 0.99: -29, 1.0: -29}), 'labels': {'key443': 'value443'}})
# defaultdict(None, {'type': 'summary', 'sum': '21', 'count': '3', 'quantiles': defaultdict(None, {0.34: -26, 0.55: 39, 0.69: 39, 0.8: 39, 0.99: 39}), 'labels': {'key447': 'value447'}})
# defaultdict(None, {'type': 'summary', 'sum': '-71', 'count': '3', 'quantiles': defaultdict(None, {0.0: -7, 0.5: -23, 0.9: -41, 0.95: -41, 0.99: -41, 1.0: -41}), 'labels': {'key451': 'value451'}})
# defaultdict(None, {'type': 'summary', 'sum': '-28', 'count': '1', 'quantiles': defaultdict(None, {0.0: -28, 0.5: -28, 0.9: -28, 0.95: -28, 0.99: -28, 1.0: -28}), 'labels': {'key453': 'value453'}})
# defaultdict(None, {'type': 'summary', 'sum': '53', 'count': '3', 'quantiles': defaultdict(None, {0.0: 28, 0.5: 12, 0.9: 13, 0.95: 13, 0.99: 13, 1.0: 13}), 'labels': {'key455': 'value455'}})
# defaultdict(None, {'type': 'summary', 'sum': '49', 'count': '4', 'quantiles': defaultdict(None, {0.0: -7, 0.5: 36, 0.9: 34, 0.95: 34, 0.99: 34, 1.0: 34}), 'labels': {'key457': 'value457'}})
# defaultdict(None, {'type': 'summary', 'sum': '-13', 'count': '3', 'quantiles': defaultdict(None, {0.08: 4, 0.46: 4, 0.57: -34, 0.59: -34, 0.76: -34}), 'labels': {'key458': 'value458'}})
# defaultdict(None, {'type': 'summary', 'sum': '36', 'count': '3', 'quantiles': defaultdict(None, {0.0: 40, 0.5: 25, 0.9: -29, 0.95: -29, 0.99: -29, 1.0: -29}), 'labels': {'key459': 'value459'}})
# defaultdict(None, {'type': 'summary', 'sum': '-64', 'count': '4', 'quantiles': defaultdict(None, {0.04: -4, 0.33: -4, 0.44: -43, 0.66: -43, 0.99: 31}), 'labels': {'key460': 'value460'}})
# defaultdict(None, {'type': 'summary', 'sum': '55', 'count': '3', 'quantiles': defaultdict(None, {0.19: 1, 0.21: 1, 0.33: 1, 0.43: 1, 0.5: 1}), 'labels': {'key461': 'value461'}})
# defaultdict(None, {'type': 'summary', 'sum': '62', 'count': '5', 'quantiles': defaultdict(None, {0.29: 17, 0.57: 29, 0.67: 29, 0.69: 29, 0.88: -1}), 'labels': {'key465': 'value465'}})
# defaultdict(None, {'type': 'summary', 'sum': '20', 'count': '4', 'quantiles': defaultdict(None, {0.36: -26, 0.57: -26, 0.68: 47, 0.76: 47, 0.93: 47}), 'labels': {'key467': 'value467'}})
# defaultdict(None, {'type': 'summary', 'sum': '12', 'count': '4', 'quantiles': defaultdict(None, {0.09: -6, 0.17: -6, 0.31: -6, 0.74: -9, 0.76: -9}), 'labels': {'key468': 'value468'}})
# defaultdict(None, {'type': 'summary', 'sum': '-13', 'count': '4', 'quantiles': defaultdict(None, {0.0: 32, 0.5: -6, 0.9: -32, 0.95: -32, 0.99: -32, 1.0: -32}), 'labels': {'key469': 'value469'}})
# defaultdict(None, {'type': 'summary', 'sum': '-92', 'count': '3', 'quantiles': defaultdict(None, {0.0: -8, 0.5: -47, 0.9: -37, 0.95: -37, 0.99: -37, 1.0: -37}), 'labels': {'key477': 'value477'}})
# defaultdict(None, {'type': 'summary', 'sum': '0', 'count': '2', 'quantiles': defaultdict(None, {0.0: -8, 0.5: 8, 0.9: 8, 0.95: 8, 0.99: 8, 1.0: 8}), 'labels': {'key478': 'value478'}})
# defaultdict(None, {'type': 'summary', 'sum': '-97', 'count': '5', 'quantiles': defaultdict(None, {0.0: -30, 0.04: -45, 0.37: 21, 0.5: 21, 0.91: -33}), 'labels': {'key481': 'value481'}})
# defaultdict(None, {'type': 'summary', 'sum': '4', 'count': '2', 'quantiles': defaultdict(None, {0.0: -22, 0.5: 26, 0.9: 26, 0.95: 26, 0.99: 26, 1.0: 26}), 'labels': {'key487': 'value487'}})
# defaultdict(None, {'type': 'summary', 'sum': '30', 'count': '2', 'quantiles': defaultdict(None, {0.42: 13, 0.63: 13, 0.66: 13, 0.71: 13, 0.85: 13}), 'labels': {'key488': 'value488'}})
# defaultdict(None, {'type': 'summary', 'sum': '36', 'count': '4', 'quantiles': defaultdict(None, {0.0: 43, 0.5: -5, 0.9: 31, 0.95: 31, 0.99: 31, 1.0: 31}), 'labels': {'key489': 'value489'}})
# defaultdict(None, {'type': 'summary', 'sum': '33', 'count': '3', 'quantiles': defaultdict(None, {0.0: 44, 0.5: -18, 0.9: 7, 0.95: 7, 0.99: 7, 1.0: 7}), 'labels': {'key492': 'value492'}})
# defaultdict(None, {'type': 'summary', 'sum': '-2', 'count': '5', 'quantiles': defaultdict(None, {0.16: -13, 0.49: -9, 0.6: 23, 0.81: -39, 0.94: -39}), 'labels': {'key497': 'value497'}})
# defaultdict(None, {'type': 'summary', 'sum': '-9', 'count': '3', 'quantiles': defaultdict(None, {0.52: -25, 0.53: -25, 0.6: -25, 0.86: -25, 1.0: -25}), 'labels': {'key498': 'value498'}})
# defaultdict(None, {'type': 'summary', 'sum': '-95', 'count': '2', 'quantiles': defaultdict(None, {0.0: -48, 0.5: -47, 0.9: -47, 0.95: -47, 0.99: -47, 1.0: -47}), 'labels': {'key500': 'value500'}})
# defaultdict(None, {'type': 'summary', 'sum': '37', 'count': '5', 'quantiles': defaultdict(None, {0.0: 6, 0.5: -34, 0.9: -1, 0.95: -1, 0.99: -1, 1.0: -1}), 'labels': {'key503': 'value503'}})
# defaultdict(None, {'type': 'summary', 'sum': '-41', 'count': '4', 'quantiles': defaultdict(None, {0.0: -48, 0.5: 13, 0.9: -31, 0.95: -31, 0.99: -31, 1.0: -31}), 'labels': {'key508': 'value508'}})
# defaultdict(None, {'type': 'summary', 'sum': '-12', 'count': '2', 'quantiles': defaultdict(None, {0.0: -14, 0.32: 2, 0.34: 2, 0.58: 2, 0.81: 2}), 'labels': {'key510': 'value510'}})
# defaultdict(None, {'type': 'summary', 'sum': '30', 'count': '4', 'quantiles': defaultdict(None, {0.01: 3, 0.14: 3, 0.34: 35, 0.62: 35, 0.72: 39}), 'labels': {'key511': 'value511'}})
# defaultdict(None, {'type': 'summary', 'sum': '17', 'count': '5', 'quantiles': defaultdict(None, {0.16: 44, 0.38: -49, 0.48: -49, 0.74: -13, 0.85: 23}), 'labels': {'key521': 'value521'}})
# defaultdict(None, {'type': 'summary', 'sum': '149', 'count': '4', 'quantiles': defaultdict(None, {0.04: 37, 0.2: 37, 0.44: 39, 0.59: 39, 0.82: 47}), 'labels': {'key523': 'value523'}})
# defaultdict(None, {'type': 'summary', 'sum': '3', 'count': '3', 'quantiles': defaultdict(None, {0.01: -45, 0.02: -45, 0.06: -45, 0.14: -45, 0.3: -45}), 'labels': {'key524': 'value524'}})
# defaultdict(None, {'type': 'summary', 'sum': '29', 'count': '1', 'quantiles': defaultdict(None, {0.0: 29, 0.5: 29, 0.9: 29, 0.95: 29, 0.99: 29, 1.0: 29}), 'labels': {'key526': 'value526'}})
# defaultdict(None, {'type': 'summary', 'sum': '69', 'count': '5', 'quantiles': defaultdict(None, {0.0: -28, 0.4: -13, 0.54: 30, 0.75: 30, 0.98: 31}), 'labels': {'key527': 'value527'}})
# defaultdict(None, {'type': 'summary', 'sum': '-84', 'count': '5', 'quantiles': defaultdict(None, {0.0: -27, 0.5: -47, 0.9: -6, 0.95: -6, 0.99: -6, 1.0: -6}), 'labels': {'key528': 'value528'}})
# defaultdict(None, {'type': 'summary', 'sum': '-33', 'count': '2', 'quantiles': defaultdict(None, {0.04: -26, 0.16: -26, 0.26: -26, 0.31: -26, 0.83: -26}), 'labels': {'key530': 'value530'}})
# defaultdict(None, {'type': 'summary', 'sum': '32', 'count': '2', 'quantiles': defaultdict(None, {0.14: 44, 0.15: 44, 0.3: 44, 0.75: 44, 0.81: 44}), 'labels': {'key534': 'value534'}})
# defaultdict(None, {'type': 'summary', 'sum': '-11', 'count': '4', 'quantiles': defaultdict(None, {0.0: -46, 0.5: 34, 0.9: 22, 0.95: 22, 0.99: 22, 1.0: 22}), 'labels': {'key536': 'value536'}})
# defaultdict(None, {'type': 'summary', 'sum': '28', 'count': '2', 'quantiles': defaultdict(None, {0.05: 44, 0.12: 44, 0.22: 44, 0.41: 44, 0.96: 44}), 'labels': {'key539': 'value539'}})
# defaultdict(None, {'type': 'summary', 'sum': '-32', 'count': '2', 'quantiles': defaultdict(None, {0.3: -35, 0.38: -35, 0.46: -35, 0.62: -35, 0.87: -35}), 'labels': {'key541': 'value541'}})
# defaultdict(None, {'type': 'summary', 'sum': '19', 'count': '2', 'quantiles': defaultdict(None, {0.12: -22, 0.19: -22, 0.22: -22, 0.33: -22, 0.76: -22}), 'labels': {'key542': 'value542'}})
# defaultdict(None, {'type': 'summary', 'sum': '-17', 'count': '1', 'quantiles': defaultdict(None, {0.0: -17, 0.5: -17, 0.9: -17, 0.95: -17, 0.99: -17, 1.0: -17}), 'labels': {'key544': 'value544'}})
# defaultdict(None, {'type': 'summary', 'sum': '-46', 'count': '5', 'quantiles': defaultdict(None, {0.26: -47, 0.32: -47, 0.61: -41, 0.73: -41, 0.8: -3}), 'labels': {'key545': 'value545'}})
# defaultdict(None, {'type': 'summary', 'sum': '-49', 'count': '2', 'quantiles': defaultdict(None, {0.0: -15, 0.01: -34, 0.36: -34, 0.69: -34, 0.91: -34}), 'labels': {'key546': 'value546'}})
# defaultdict(None, {'type': 'summary', 'sum': '-2', 'count': '4', 'quantiles': defaultdict(None, {0.0: -47, 0.5: -23, 0.9: 39, 0.95: 39, 0.99: 39, 1.0: 39}), 'labels': {'key547': 'value547'}})
# defaultdict(None, {'type': 'summary', 'sum': '57', 'count': '2', 'quantiles': defaultdict(None, {0.0: 43, 0.5: 14, 0.9: 14, 0.95: 14, 0.99: 14, 1.0: 14}), 'labels': {'key551': 'value551'}})
# defaultdict(None, {'type': 'summary', 'sum': '-52', 'count': '2', 'quantiles': defaultdict(None, {0.31: -18, 0.59: -18, 0.81: -18, 0.88: -18, 0.99: -18}), 'labels': {'key556': 'value556'}})
# defaultdict(None, {'type': 'summary', 'sum': '-2', 'count': '2', 'quantiles': defaultdict(None, {0.0: -49, 0.5: 47, 0.9: 47, 0.95: 47, 0.99: 47, 1.0: 47}), 'labels': {'key558': 'value558'}})
# defaultdict(None, {'type': 'summary', 'sum': '1', 'count': '1', 'quantiles': defaultdict(None, {0.34: 1, 0.53: 1, 0.7: 1, 0.78: 1, 0.94: 1}), 'labels': {'key563': 'value563'}})
# defaultdict(None, {'type': 'summary', 'sum': '18', 'count': '5', 'quantiles': defaultdict(None, {0.0: -29, 0.5: 9, 0.9: 21, 0.95: 21, 0.99: 21, 1.0: 21}), 'labels': {'key566': 'value566'}})
# defaultdict(None, {'type': 'summary', 'sum': '8', 'count': '3', 'quantiles': defaultdict(None, {0.04: 13, 0.4: 13, 0.44: 13, 0.61: -25, 0.91: -25}), 'labels': {'key567': 'value567'}})
# defaultdict(None, {'type': 'summary', 'sum': '51', 'count': '5', 'quantiles': defaultdict(None, {0.0: 4, 0.5: -13, 0.9: -2, 0.95: -2, 0.99: -2, 1.0: -2}), 'labels': {'key569': 'value569'}})
# defaultdict(None, {'type': 'summary', 'sum': '-29', 'count': '5', 'quantiles': defaultdict(None, {0.19: -24, 0.53: 19, 0.8: -43, 0.83: -43, 0.96: -43}), 'labels': {'key573': 'value573'}})
# defaultdict(None, {'type': 'summary', 'sum': '18', 'count': '2', 'quantiles': defaultdict(None, {0.03: 46, 0.23: 46, 0.25: 46, 0.44: 46, 0.72: 46}), 'labels': {'key574': 'value574'}})
# defaultdict(None, {'type': 'summary', 'sum': '-17', 'count': '1', 'quantiles': defaultdict(None, {0.19: -17, 0.27: -17, 0.29: -17, 0.53: -17, 1.0: -17}), 'labels': {'key576': 'value576'}})
# defaultdict(None, {'type': 'summary', 'sum': '10', 'count': '1', 'quantiles': defaultdict(None, {0.22: 10, 0.59: 10, 0.61: 10, 0.79: 10, 0.89: 10}), 'labels': {'key578': 'value578'}})
# defaultdict(None, {'type': 'summary', 'sum': '15', 'count': '5', 'quantiles': defaultdict(None, {0.09: 14, 0.69: -14, 0.78: -9, 0.95: -9}), 'labels': {'key580': 'value580'}})
# defaultdict(None, {'type': 'summary', 'sum': '-53', 'count': '4', 'quantiles': defaultdict(None, {0.0: -40, 0.5: -35, 0.9: 30, 0.95: 30, 0.99: 30, 1.0: 30}), 'labels': {'key592': 'value592'}})
# defaultdict(None, {'type': 'summary', 'sum': '67', 'count': '4', 'quantiles': defaultdict(None, {0.11: 26, 0.33: 26, 0.6: 2, 0.91: 22, 0.92: 22}), 'labels': {'key593': 'value593'}})
# defaultdict(None, {'type': 'summary', 'sum': '5', 'count': '2', 'quantiles': defaultdict(None, {0.35: -44, 0.36: -44, 0.61: -44, 0.64: -44, 0.75: -44}), 'labels': {'key594': 'value594'}})
# defaultdict(None, {'type': 'summary', 'sum': '64', 'count': '3', 'quantiles': defaultdict(None, {0.11: 8, 0.19: 8, 0.46: 8, 0.48: 8, 0.59: 16}), 'labels': {'key604': 'value604'}})
# defaultdict(None, {'type': 'summary', 'sum': '45', 'count': '2', 'quantiles': defaultdict(None, {0.14: 37, 0.59: 37, 0.72: 37, 0.75: 37, 0.96: 37}), 'labels': {'key608': 'value608'}})
# defaultdict(None, {'type': 'summary', 'sum': '-9', 'count': '5', 'quantiles': defaultdict(None, {0.51: 18, 0.54: 18, 0.7: 18, 0.76: 19, 0.93: 19}), 'labels': {'key609': 'value609'}})
# defaultdict(None, {'type': 'summary', 'sum': '-61', 'count': '4', 'quantiles': defaultdict(None, {0.02: -29, 0.04: -29, 0.75: -34, 0.82: -34, 0.83: -34}), 'labels': {'key613': 'value613'}})
# defaultdict(None, {'type': 'summary', 'sum': '-17', 'count': '5', 'quantiles': defaultdict(None, {0.42: 9, 0.47: 9, 0.68: -50, 0.8: -48, 0.98: -48}), 'labels': {'key615': 'value615'}})
# defaultdict(None, {'type': 'summary', 'sum': '-42', 'count': '4', 'quantiles': defaultdict(None, {0.14: 19, 0.26: 19, 0.57: -9, 0.66: -9, 0.75: -21}), 'labels': {'key616': 'value616'}})
# defaultdict(None, {'type': 'summary', 'sum': '57', 'count': '5', 'quantiles': defaultdict(None, {0.48: -23, 0.51: 49, 0.54: 49, 0.73: 49, 1.0: -38}), 'labels': {'key617': 'value617'}})
# defaultdict(None, {'type': 'summary', 'sum': '32', 'count': '2', 'quantiles': defaultdict(None, {0.0: -15, 0.5: 47, 0.9: 47, 0.95: 47, 0.99: 47, 1.0: 47}), 'labels': {'key618': 'value618'}})
# defaultdict(None, {'type': 'summary', 'sum': '48', 'count': '5', 'quantiles': defaultdict(None, {0.0: 2, 0.5: 50, 0.9: 24, 0.95: 24, 0.99: 24, 1.0: 24}), 'labels': {'key619': 'value619'}})
# defaultdict(None, {'type': 'summary', 'sum': '-50', 'count': '1', 'quantiles': defaultdict(None, {0.06: -50, 0.59: -50, 0.6: -50, 0.63: -50, 0.91: -50}), 'labels': {'key620': 'value620'}})
# defaultdict(None, {'type': 'summary', 'sum': '-124', 'count': '5', 'quantiles': defaultdict(None, {0.0: -32, 0.5: 17, 0.9: -42, 0.95: -42, 0.99: -42, 1.0: -42}), 'labels': {'key621': 'value621'}})
# defaultdict(None, {'type': 'summary', 'sum': '-4', 'count': '3', 'quantiles': defaultdict(None, {0.0: 0, 0.5: 13, 0.9: -17, 0.95: -17, 0.99: -17, 1.0: -17}), 'labels': {'key622': 'value622'}})
# defaultdict(None, {'type': 'summary', 'sum': '14', 'count': '2', 'quantiles': defaultdict(None, {0.18: 21, 0.47: 21, 0.6: 21, 0.88: 21, 0.99: 21}), 'labels': {'key623': 'value623'}})
# defaultdict(None, {'type': 'summary', 'sum': '16', 'count': '2', 'quantiles': defaultdict(None, {0.0: -4, 0.5: 20, 0.9: 20, 0.95: 20, 0.99: 20, 1.0: 20}), 'labels': {'key626': 'value626'}})
# defaultdict(None, {'type': 'summary', 'sum': '-37', 'count': '3', 'quantiles': defaultdict(None, {0.45: 28, 0.56: -28, 0.57: -28, 0.99: -28}), 'labels': {'key627': 'value627'}})
# defaultdict(None, {'type': 'summary', 'sum': '35', 'count': '1', 'quantiles': defaultdict(None, {0.19: 35, 0.51: 35, 0.58: 35, 0.65: 35, 0.8: 35}), 'labels': {'key628': 'value628'}})
# ...
# defaultdict(None, {'type': 'summary', 'sum': '84', 'count': '5', 'quantiles': defaultdict(None, {0.0: 32, 0.5: -27, 0.9: -1, 0.95: -1, 0.99: -1, 1.0: -1}), 'labels': {'key1853': 'value1853'}})
# defaultdict(None, {'type': 'summary', 'sum': '41', 'count': '4', 'quantiles': defaultdict(None, {0.0: 2, 0.5: -29, 0.9: 42, 0.95: 42, 0.99: 42, 1.0: 42}), 'labels': {'key1854': 'value1854'}})
# defaultdict(None, {'type': 'summary', 'sum': '-22', 'count': '4', 'quantiles': defaultdict(None, {0.05: 50, 0.11: 50, 0.16: 50, 0.22: 50, 0.54: -30}), 'labels': {'key1855': 'value1855'}})
# defaultdict(None, {'type': 'summary', 'sum': '-48', 'count': '1', 'quantiles': defaultdict(None, {0.0: -48, 0.5: -48, 0.9: -48, 0.95: -48, 0.99: -48, 1.0: -48}), 'labels': {'key1861': 'value1861'}})
# defaultdict(None, {'type': 'summary', 'sum': '18', 'count': '2', 'quantiles': defaultdict(None, {0.0: -7, 0.5: 25, 0.9: 25, 0.95: 25, 0.99: 25, 1.0: 25}), 'labels': {'key1862': 'value1862'}})
# defaultdict(None, {'type': 'summary', 'sum': '55', 'count': '3', 'quantiles': defaultdict(None, {0.12: -5, 0.35: -5, 0.55: 12, 0.58: 12, 0.94: 12}), 'labels': {'key1863': 'value1863'}})
# defaultdict(None, {'type': 'summary', 'sum': '8', 'count': '2', 'quantiles': defaultdict(None, {0.0: 0, 0.5: 8, 0.9: 8, 0.95: 8, 0.99: 8, 1.0: 8}), 'labels': {'key1865': 'value1865'}})
# defaultdict(None, {'type': 'summary', 'sum': '21', 'count': '1', 'quantiles': defaultdict(None, {0.0: 21, 0.5: 21, 0.9: 21, 0.95: 21, 0.99: 21, 1.0: 21}), 'labels': {'key1866': 'value1866'}})
# defaultdict(None, {'type': 'summary', 'sum': '3', 'count': '1', 'quantiles': defaultdict(None, {0.08: 3, 0.09: 3, 0.22: 3, 0.79: 3, 0.92: 3}), 'labels': {'key1868': 'value1868'}})
# defaultdict(None, {'type': 'summary', 'sum': '156', 'count': '4', 'quantiles': defaultdict(None, {0.0: 48, 0.5: 43, 0.9: 24, 0.95: 24, 0.99: 24, 1.0: 24}), 'labels': {'key1870': 'value1870'}})
# defaultdict(None, {'type': 'summary', 'sum': '16', 'count': '3', 'quantiles': defaultdict(None, {0.29: -13, 0.32: -13, 0.93: 44, 0.95: 44, 0.99: 44}), 'labels': {'key1871': 'value1871'}})
# defaultdict(None, {'type': 'summary', 'sum': '-36', 'count': '1', 'quantiles': defaultdict(None, {0.01: -36, 0.51: -36, 0.61: -36, 0.65: -36, 0.68: -36}), 'labels': {'key1872': 'value1872'}})
# defaultdict(None, {'type': 'summary', 'sum': '1', 'count': '1', 'quantiles': defaultdict(None, {0.47: 1, 0.7: 1, 0.73: 1, 0.77: 1, 0.94: 1}), 'labels': {'key1873': 'value1873'}})
# defaultdict(None, {'type': 'summary', 'sum': '8', 'count': '1', 'quantiles': defaultdict(None, {0.0: 8, 0.5: 8, 0.9: 8, 0.95: 8, 0.99: 8, 1.0: 8}), 'labels': {'key1875': 'value1875'}})
# defaultdict(None, {'type': 'summary', 'sum': '-80', 'count': '4', 'quantiles': defaultdict(None, {0.01: -44, 0.41: -2, 0.64: -2, 0.68: -37, 0.77: -37}), 'labels': {'key1888': 'value1888'}})
# defaultdict(None, {'type': 'summary', 'sum': '21', 'count': '3', 'quantiles': defaultdict(None, {0.07: 49, 0.28: 49, 0.4: 49, 0.43: 49, 0.46: 49}), 'labels': {'key1889': 'value1889'}})
# defaultdict(None, {'type': 'summary', 'sum': '4', 'count': '2', 'quantiles': defaultdict(None, {0.21: 28, 0.51: 28, 0.52: 28, 0.54: 28, 0.62: 28}), 'labels': {'key1893': 'value1893'}})
# defaultdict(None, {'type': 'summary', 'sum': '-67', 'count': '5', 'quantiles': defaultdict(None, {0.17: 5, 0.44: 17, 0.65: -14, 0.7: -14, 0.82: -43}), 'labels': {'key1895': 'value1895'}})
# defaultdict(None, {'type': 'summary', 'sum': '94', 'count': '3', 'quantiles': defaultdict(None, {0.0: 33, 0.5: 30, 0.9: 31, 0.95: 31, 0.99: 31, 1.0: 31}), 'labels': {'key1900': 'value1900'}})
# defaultdict(None, {'type': 'summary', 'sum': '-67', 'count': '4', 'quantiles': defaultdict(None, {0.0: 32, 0.5: -34, 0.9: -49, 0.95: -49, 0.99: -49, 1.0: -49}), 'labels': {'key1901': 'value1901'}})
# defaultdict(None, {'type': 'summary', 'sum': '-53', 'count': '3', 'quantiles': defaultdict(None, {0.0: -24, 0.5: -19, 0.9: -10, 0.95: -10, 0.99: -10, 1.0: -10}), 'labels': {'key1902': 'value1902'}})
# defaultdict(None, {'type': 'summary', 'sum': '0', 'count': '2', 'quantiles': defaultdict(None, {0.0: -46, 0.5: 46, 0.9: 46, 0.95: 46, 0.99: 46, 1.0: 46}), 'labels': {'key1904': 'value1904'}})
# defaultdict(None, {'type': 'summary', 'sum': '-21', 'count': '4', 'quantiles': defaultdict(None, {0.45: -35, 0.49: -35, 0.52: -35, 0.61: -35, 0.76: -23}), 'labels': {'key1909': 'value1909'}})
# defaultdict(None, {'type': 'summary', 'sum': '-93', 'count': '5', 'quantiles': defaultdict(None, {0.17: -49, 0.27: -16, 0.45: -16, 0.57: -47, 0.69: -47}), 'labels': {'key1913': 'value1913'}})
# defaultdict(None, {'type': 'summary', 'sum': '-54', 'count': '4', 'quantiles': defaultdict(None, {0.0: -16, 0.5: -45, 0.9: -27, 0.95: -27, 0.99: -27, 1.0: -27}), 'labels': {'key1915': 'value1915'}})
# defaultdict(None, {'type': 'summary', 'sum': '-2', 'count': '3', 'quantiles': defaultdict(None, {0.23: -14, 0.76: -28, 0.78: -28, 0.92: -28}), 'labels': {'key1916': 'value1916'}})
# defaultdict(None, {'type': 'summary', 'sum': '35', 'count': '3', 'quantiles': defaultdict(None, {0.0: 42, 0.5: -36, 0.9: 29, 0.95: 29, 0.99: 29, 1.0: 29}), 'labels': {'key1917': 'value1917'}})
# defaultdict(None, {'type': 'summary', 'sum': '89', 'count': '5', 'quantiles': defaultdict(None, {0.0: 1, 0.5: 18, 0.9: 28, 0.95: 28, 0.99: 28, 1.0: 28}), 'labels': {'key1919': 'value1919'}})
# defaultdict(None, {'type': 'summary', 'sum': '2', 'count': '5', 'quantiles': defaultdict(None, {0.15: 34, 0.45: 40, 0.52: -21, 0.61: -21, 0.63: -21}), 'labels': {'key1923': 'value1923'}})
# defaultdict(None, {'type': 'summary', 'sum': '6', 'count': '2', 'quantiles': defaultdict(None, {0.0: -24, 0.5: 30, 0.9: 30, 0.95: 30, 0.99: 30, 1.0: 30}), 'labels': {'key1924': 'value1924'}})
# defaultdict(None, {'type': 'summary', 'sum': '-11', 'count': '2', 'quantiles': defaultdict(None, {0.1: 3, 0.32: 3, 0.41: 3, 0.62: 3}), 'labels': {'key1926': 'value1926'}})
# defaultdict(None, {'type': 'summary', 'sum': '-58', 'count': '3', 'quantiles': defaultdict(None, {0.0: -31, 0.5: -22, 0.9: -5, 0.95: -5, 0.99: -5, 1.0: -5}), 'labels': {'key1932': 'value1932'}})
# defaultdict(None, {'type': 'summary', 'sum': '-4', 'count': '5', 'quantiles': defaultdict(None, {0.0: -27, 0.5: 11, 0.9: -38, 0.95: -38, 0.99: -38, 1.0: -38}), 'labels': {'key1937': 'value1937'}})
# defaultdict(None, {'type': 'summary', 'sum': '1', 'count': '4', 'quantiles': defaultdict(None, {0.0: 40, 0.5: 31, 0.9: -33, 0.95: -33, 0.99: -33, 1.0: -33}), 'labels': {'key1938': 'value1938'}})
# defaultdict(None, {'type': 'summary', 'sum': '-11', 'count': '5', 'quantiles': defaultdict(None, {0.0: 1, 0.5: -10, 0.9: -5, 0.95: -5, 0.99: -5, 1.0: -5}), 'labels': {'key1939': 'value1939'}})
# defaultdict(None, {'type': 'summary', 'sum': '-29', 'count': '5', 'quantiles': defaultdict(None, {0.0: 44, 0.5: -13, 0.9: 28, 0.95: 28, 0.99: 28, 1.0: 28}), 'labels': {'key1942': 'value1942'}})
# defaultdict(None, {'type': 'summary', 'sum': '-11', 'count': '4', 'quantiles': defaultdict(None, {0.0: 32, 0.5: -12, 0.9: -18, 0.95: -18, 0.99: -18, 1.0: -18}), 'labels': {'key1944': 'value1944'}})
# defaultdict(None, {'type': 'summary', 'sum': '-42', 'count': '5', 'quantiles': defaultdict(None, {0.0: -28, 0.5: -21, 0.9: -11, 0.95: -11, 0.99: -11, 1.0: -11}), 'labels': {'key1954': 'value1954'}})
# defaultdict(None, {'type': 'summary', 'sum': '85', 'count': '4', 'quantiles': defaultdict(None, {0.3: 33, 0.58: 50, 0.74: 18, 0.75: 18, 0.81: 18}), 'labels': {'key1958': 'value1958'}})
# defaultdict(None, {'type': 'summary', 'sum': '45', 'count': '4', 'quantiles': defaultdict(None, {0.1: 20, 0.56: 23, 0.6: 23, 0.61: 23, 0.88: 47}), 'labels': {'key1960': 'value1960'}})
# defaultdict(None, {'type': 'summary', 'sum': '-33', 'count': '5', 'quantiles': defaultdict(None, {0.07: 44, 0.3: -12, 0.48: -12, 0.64: -35, 0.71: -35}), 'labels': {'key1964': 'value1964'}})
# defaultdict(None, {'type': 'summary', 'sum': '29', 'count': '3', 'quantiles': defaultdict(None, {0.0: -22, 0.5: 36, 0.9: 15, 0.95: 15, 0.99: 15, 1.0: 15}), 'labels': {'key1966': 'value1966'}})
# defaultdict(None, {'type': 'summary', 'sum': '-119', 'count': '4', 'quantiles': defaultdict(None, {0.05: -39, 0.1: -39, 0.2: -39, 0.8: -27, 0.81: -27}), 'labels': {'key1967': 'value1967'}})
# defaultdict(None, {'type': 'summary', 'sum': '14', 'count': '2', 'quantiles': defaultdict(None, {0.0: -1, 0.5: 15, 0.9: 15, 0.95: 15, 0.99: 15, 1.0: 15}), 'labels': {'key1968': 'value1968'}})
# defaultdict(None, {'type': 'summary', 'sum': '-77', 'count': '4', 'quantiles': defaultdict(None, {0.0: -40, 0.5: 18, 0.9: -41, 0.95: -41, 0.99: -41, 1.0: -41}), 'labels': {'key1970': 'value1970'}})
# defaultdict(None, {'type': 'summary', 'sum': '31', 'count': '2', 'quantiles': defaultdict(None, {0.04: -1, 0.2: -1, 0.59: -1, 0.81: -1, 0.84: -1}), 'labels': {'key1971': 'value1971'}})
# defaultdict(None, {'type': 'summary', 'sum': '-9', 'count': '5', 'quantiles': defaultdict(None, {0.47: 18, 0.58: -9, 0.72: -9, 0.78: -3, 0.79: -3}), 'labels': {'key1973': 'value1973'}})
# defaultdict(None, {'type': 'summary', 'sum': '-34', 'count': '4', 'quantiles': defaultdict(None, {0.0: -30, 0.5: -4, 0.9: -28, 0.95: -28, 0.99: -28, 1.0: -28}), 'labels': {'key1975': 'value1975'}})
# defaultdict(None, {'type': 'summary', 'sum': '50', 'count': '1', 'quantiles': defaultdict(None, {0.31: 50, 0.38: 50, 0.39: 50, 0.56: 50, 0.65: 50}), 'labels': {'key1977': 'value1977'}})
# defaultdict(None, {'type': 'summary', 'sum': '-34', 'count': '1', 'quantiles': defaultdict(None, {0.01: -34, 0.16: -34, 0.54: -34, 1.0: -34}), 'labels': {'key1980': 'value1980'}})
# defaultdict(None, {'type': 'summary', 'sum': '67', 'count': '4', 'quantiles': defaultdict(None, {0.23: 8, 0.24: 8, 0.31: 8, 0.48: 45, 0.8: -10}), 'labels': {'key1981': 'value1981'}})
# defaultdict(None, {'type': 'summary', 'sum': '31', 'count': '2', 'quantiles': defaultdict(None, {0.0: 50, 0.5: -19, 0.9: -19, 0.95: -19, 0.99: -19, 1.0: -19}), 'labels': {'key1982': 'value1982'}})
# defaultdict(None, {'type': 'summary', 'sum': '-5', 'count': '1', 'quantiles': defaultdict(None, {0.0: -5, 0.5: -5, 0.9: -5, 0.95: -5, 0.99: -5, 1.0: -5}), 'labels': {'key1984': 'value1984'}})
# defaultdict(None, {'type': 'summary', 'sum': '23', 'count': '2', 'quantiles': defaultdict(None, {0.12: 14, 0.14: 14, 0.2: 14, 0.58: 14, 1.0: 14}), 'labels': {'key1988': 'value1988'}})
# defaultdict(None, {'type': 'summary', 'sum': '27', 'count': '5', 'quantiles': defaultdict(None, {0.0: -28, 0.5: 46, 0.9: -42, 0.95: -42, 0.99: -42, 1.0: -42}), 'labels': {'key1990': 'value1990'}})
# defaultdict(None, {'type': 'summary', 'sum': '-58', 'count': '5', 'quantiles': defaultdict(None, {0.42: 7, 0.59: 9, 0.68: 9, 0.84: -49, 0.98: -49}), 'labels': {'key1991': 'value1991'}})
# defaultdict(None, {'type': 'summary', 'sum': '28', 'count': '1', 'quantiles': defaultdict(None, {0.03: 28, 0.36: 28, 0.58: 28, 0.71: 28, 0.8: 28}), 'labels': {'key1993': 'value1993'}})
# defaultdict(None, {'type': 'summary', 'sum': '40', 'count': '2', 'quantiles': defaultdict(None, {0.2: 46, 0.34: 46, 0.64: 46, 0.8: 46, 0.95: 46}), 'labels': {'key1995': 'value1995'}})
# defaultdict(None, {'type': 'summary', 'sum': '36', 'count': '4', 'quantiles': defaultdict(None, {0.05: 18, 0.52: -28, 0.53: -28, 0.69: 30, 0.82: 30}), 'labels': {'key1996': 'value1996'}})
# defaultdict(None, {'type': 'summary', 'sum': '-2', 'count': '5', 'quantiles': defaultdict(None, {0.0: 35, 0.5: -27, 0.9: -21, 0.95: -21, 0.99: -21, 1.0: -21}), 'labels': {'key1998': 'value1998'}})
# defaultdict(None, {'type': 'summary', 'sum': '-12', 'count': '2', 'quantiles': defaultdict(None, {0.0: 17, 0.17: -29, 0.43: -29, 0.97: -29}), 'labels': {'key1999': 'value1999'}})
# defaultdict(None, {'type': 'summary', 'sum': '-41', 'count': '1', 'quantiles': defaultdict(None, {0.0: -41, 0.5: -41, 0.9: -41, 0.95: -41, 0.99: -41, 1.0: -41}), 'labels': {'key2002': 'value2002'}})
# defaultdict(None, {'type': 'summary', 'sum': '35', 'count': '1', 'quantiles': defaultdict(None, {0.0: 35, 0.24: 35, 0.57: 35, 0.84: 35, 0.87: 35}), 'labels': {'key2007': 'value2007'}})
# defaultdict(None, {'type': 'summary', 'sum': '-15', 'count': '4', 'quantiles': defaultdict(None, {0.0: -6, 0.5: 37, 0.9: -9, 0.95: -9, 0.99: -9, 1.0: -9}), 'labels': {'key2009': 'value2009'}})
# defaultdict(None, {'type': 'summary', 'sum': '29', 'count': '3', 'quantiles': defaultdict(None, {0.0: -19, 0.5: 27, 0.9: 21, 0.95: 21, 0.99: 21, 1.0: 21}), 'labels': {'key2011': 'value2011'}})
# defaultdict(None, {'type': 'summary', 'sum': '-83', 'count': '4', 'quantiles': defaultdict(None, {0.05: 3, 0.28: 3, 0.52: -43, 0.78: -45, 0.79: -45}), 'labels': {'key2014': 'value2014'}})
# defaultdict(None, {'type': 'summary', 'sum': '4', 'count': '2', 'quantiles': defaultdict(None, {0.26: 39, 0.27: 39, 0.82: 39, 0.91: 39, 0.99: 39}), 'labels': {'key2015': 'value2015'}})
# defaultdict(None, {'type': 'summary', 'sum': '-62', 'count': '4', 'quantiles': defaultdict(None, {0.26: 33, 0.33: 33, 0.86: -27, 0.89: -27, 0.94: -27}), 'labels': {'key2023': 'value2023'}})
# defaultdict(None, {'type': 'summary', 'sum': '-56', 'count': '5', 'quantiles': defaultdict(None, {0.0: -27, 0.5: -17, 0.9: -42, 0.95: -42, 0.99: -42, 1.0: -42}), 'labels': {'key2025': 'value2025'}})
# defaultdict(None, {'type': 'summary', 'sum': '111', 'count': '3', 'quantiles': defaultdict(None, {0.0: 41, 0.5: 34, 0.9: 36, 0.95: 36, 0.99: 36, 1.0: 36}), 'labels': {'key2027': 'value2027'}})
# defaultdict(None, {'type': 'summary', 'sum': '-15', 'count': '2', 'quantiles': defaultdict(None, {0.02: 1, 0.14: 1, 0.19: 1, 0.76: 1, 0.86: 1}), 'labels': {'key2028': 'value2028'}})
# defaultdict(None, {'type': 'summary', 'sum': '-102', 'count': '4', 'quantiles': defaultdict(None, {0.26: -20, 0.3: -20, 0.31: -20, 0.4: -34, 0.77: -17}), 'labels': {'key2029': 'value2029'}})
# defaultdict(None, {'type': 'summary', 'sum': '10', 'count': '2', 'quantiles': defaultdict(None, {0.12: -7, 0.56: -7, 0.82: -7, 0.93: -7, 1.0: -7}), 'labels': {'key2030': 'value2030'}})
# defaultdict(None, {'type': 'summary', 'sum': '8', 'count': '3', 'quantiles': defaultdict(None, {0.0: 18, 0.5: -1, 0.9: -9, 0.95: -9, 0.99: -9, 1.0: -9}), 'labels': {'key2032': 'value2032'}})
# defaultdict(None, {'type': 'summary', 'sum': '-41', 'count': '1', 'quantiles': defaultdict(None, {0.34: -41, 0.56: -41, 0.57: -41, 0.74: -41, 0.85: -41}), 'labels': {'key2033': 'value2033'}})
# defaultdict(None, {'type': 'summary', 'sum': '-82', 'count': '4', 'quantiles': defaultdict(None, {0.0: -49, 0.47: -19, 0.48: -19, 0.49: -19, 0.5: -19}), 'labels': {'key2036': 'value2036'}})
# defaultdict(None, {'type': 'summary', 'sum': '-35', 'count': '1', 'quantiles': defaultdict(None, {0.0: -35, 0.5: -35, 0.9: -35, 0.95: -35, 0.99: -35, 1.0: -35}), 'labels': {'key2037': 'value2037'}})
# defaultdict(None, {'type': 'summary', 'sum': '7', 'count': '5', 'quantiles': defaultdict(None, {0.1: 5, 0.25: 5, 0.35: -20, 0.48: -20, 0.72: -7}), 'labels': {'key2038': 'value2038'}})
# defaultdict(None, {'type': 'summary', 'sum': '-16', 'count': '2', 'quantiles': defaultdict(None, {0.0: -28, 0.12: 12, 0.3: 12, 0.8: 12, 0.94: 12}), 'labels': {'key2039': 'value2039'}})
# defaultdict(None, {'type': 'summary', 'sum': '38', 'count': '2', 'quantiles': defaultdict(None, {0.08: 4, 0.11: 4, 0.14: 4, 0.36: 4, 0.62: 4}), 'labels': {'key2040': 'value2040'}})
# defaultdict(None, {'type': 'summary', 'sum': '45', 'count': '5', 'quantiles': defaultdict(None, {0.01: -28, 0.15: -28, 0.24: -28, 0.29: 14, 0.52: 28}), 'labels': {'key2041': 'value2041'}})
# defaultdict(None, {'type': 'summary', 'sum': '52', 'count': '2', 'quantiles': defaultdict(None, {0.0: 38, 0.5: 14, 0.9: 14, 0.95: 14, 0.99: 14, 1.0: 14}), 'labels': {'key2043': 'value2043'}})
# defaultdict(None, {'type': 'summary', 'sum': '23', 'count': '4', 'quantiles': defaultdict(None, {0.05: 39, 0.08: 39, 0.25: 39, 0.35: -26, 0.6: -26}), 'labels': {'key2044': 'value2044'}})
# defaultdict(None, {'type': 'summary', 'sum': '8', 'count': '3', 'quantiles': defaultdict(None, {0.0: 40, 0.5: -31, 0.9: -1, 0.95: -1, 0.99: -1, 1.0: -1}), 'labels': {'key2046': 'value2046'}})

# %%
for metric_entry in entries:
    name = list(metric_entry.keys())[0]
    type = metric_entry[name]

    # [{'metric': {'__name__': 'name2010_counter', 'instance': 'docker.for.mac.localhost:8080', 'job': 'test_prom_exporter', 'key2010': 'value2010'}, 'value': [1598204478.776, '-2']}]
    if type == "counter":
        # send http request to Prometheus server
        if request_and_check_single_value(name, type) and request_and_check_label(name, type):
            COUNTER_PASS += 1
    elif type == "gauge":
        # TODO
        GAUGE_PASS += 1
    elif type == "histogram":
        count_name = name + "_count"
        sum_name = name + "_sum"
        bucket_name = name + "_bucket"
        if request_and_check_single_value(count_name, type) and request_and_check_single_value(sum_name, type) \
                and request_and_check_label(name, type) and request_and_check_bucket(bucket_name):
            HISTOGRAM_PASS += 1
    elif type == "summary":
        summary_name = name
        sum_name = name + "_sum"
        count_name = name + "_count"
        if request_and_check_single_value(count_name, type) and request_and_check_single_value(sum_name, type) \
                and request_and_check_label(name, type) and request_and_check_quantile(summary_name):
            SUMMARY_PASS += 1

print("Total number of Counter: " + str(COUNTER_COUNT))
print("Test passed Counter: " + str(COUNTER_PASS))
print("Counter test pass rate: " + str(COUNTER_PASS / COUNTER_COUNT * 100) + "%")

print("Total number of Gauge: " + str(COUNTER_COUNT))
print("Test passed Gauge: " + str(COUNTER_PASS))
print("Gauge test pass rate: " + str(COUNTER_PASS / COUNTER_COUNT * 100) + "%")

print("Total number of Histogram: " + str(HISTOGRAM_COUNT))
print("Test passed Histogram: " + str(HISTOGRAM_PASS))
print("Histogram test pass rate: " + str(HISTOGRAM_PASS / HISTOGRAM_COUNT * 100) + "%")

print("Total number of Summary: " + str(SUMMARY_COUNT))
print("Test passed Summary: " + str(SUMMARY_PASS))
print("Summary test pass rate: " + str(SUMMARY_PASS / SUMMARY_COUNT * 100) + "%")
