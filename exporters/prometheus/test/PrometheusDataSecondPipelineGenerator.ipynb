# %%
import random
from collections import defaultdict

# %%
aggregators = ["counter", "gauge", "sketch", "exact", "histogram"]
records = []

# %%
f = open("PrometheusDataSecond.csv", "w")

for i in range(2048):
    agg = random.choice(aggregators)

    nam = "name" + str(i) + "_" + agg
    des = "description" + str(i)
    lab = "{key" + str(i) + ":value" + str(i) + "}"
    ndl = str(nam) + ", " + str(des) + ", " + str(lab)
#     print(ndl)


    if (agg == "counter" or agg == "gauge"):
        # Last value
        val = random.randint(-50,50)
        
        record = (agg, ndl, val)
        records.append(record)
        
        f.write(agg+'|'+str(val)+'|'+ndl+'\n')
#         print(agg+'|'+str(val)+'|'+ndl+'\n')


    elif (agg == "sketch" or agg == "exact"):
        # Array of update values - extract sum/count from this array
        count = random.randint(1, 5)
        update_values = []
        for i in range(count):
            update_values.append(random.randint(-50, 50))
        update_values = list(set(update_values))
        
        # Array of quantiles
        # This array actually isn't used when testing the C++ PrometheusExporter, since 
        # Sketch and Exact Aggregators have preset quantile values when translated to
        # a Prometheus summary. These randomly generated quantiles reflect the possibility
        # of a future enhancement to make quantiles configurable.
        quantiles = []
        
        # Randomly generated "user specified" quantiles for sketch
        if agg == "sketch":
            for _ in range(5):
                quantiles.append(random.randint(0, 100)/100)
            quantiles = list(set(quantiles))
            quantiles.sort()

        # Pre defined quantiles for exact
        # Same note above applies to this array of quantiles as well. This preset 
        # array of quantiles reflects the current preset vector of quantiles that
        # the PrometheusExporterUtils class has chosen to use when exporting.
        elif agg == "exact":
            quantiles = [0, 0.5, 0.9, 0.95, 0.99, 1]

        record = (agg, ndl, update_values, quantiles)
        records.append(record)
        
        update_val_str = "[" + str(update_values[0])
        for v in update_values[1:]:
            update_val_str = update_val_str + "," + str(v)
        update_val_str += "]"
        
        quantiles_str = "[" + str(quantiles[0])
        for v in quantiles[1:]:
            quantiles_str = quantiles_str + "," + str(v)
        quantiles_str += "]"
        
        f.write(agg+'|'+update_val_str + '|' + quantiles_str+'|'+ndl+'\n')
#         print(agg+'|'+update_val_str + '|' + quantiles_str+'|'+ndl+'\n')
        
    elif (agg == "histogram"):
        # Array of update values - extract sum/count from this array
        count = random.randint(1, 5)
        update_values = []
        for i in range(count):
            update_values.append(random.randint(1, 100))
        update_values = list(set(update_values))
        
        # Array of boundaries
        boundaries = []
        for _ in range(5):
            boundaries.append(random.randint(0, 100))
        boundaries = list(set(boundaries))
        boundaries.sort()
        
        record = (agg, ndl, update_values, boundaries)
        records.append(record)
        
        update_val_str = "[" + str(update_values[0])
        for v in update_values[1:]:
            update_val_str = update_val_str + "," + str(v)
        update_val_str += "]"
        
        boundaries_str = "[" + str(boundaries[0])
        for v in boundaries[1:]:
            boundaries_str = boundaries_str + "," + str(v)
        boundaries_str += "]"

        f.write(agg+'|'+update_val_str + '|' + boundaries_str+'|'+ndl+'\n')
#         print(agg+'|'+update_val_str + '|' + boundaries_str+'|'+ndl+'\n')
    
    
f.close()
# Out:
# name0_gauge, description0, {key0:value0}
# name1_counter, description1, {key1:value1}
# name2_counter, description2, {key2:value2}
# name3_gauge, description3, {key3:value3}
# name4_exact, description4, {key4:value4}
# name5_counter, description5, {key5:value5}
# name6_gauge, description6, {key6:value6}
# name7_exact, description7, {key7:value7}
# name8_gauge, description8, {key8:value8}
# name9_counter, description9, {key9:value9}
# name10_sketch, description10, {key10:value10}
# name11_counter, description11, {key11:value11}
# name12_histogram, description12, {key12:value12}
# name13_counter, description13, {key13:value13}
# name14_counter, description14, {key14:value14}
# name15_counter, description15, {key15:value15}
# name16_sketch, description16, {key16:value16}
# name17_sketch, description17, {key17:value17}
# name18_counter, description18, {key18:value18}
# name19_exact, description19, {key19:value19}
# name20_exact, description20, {key20:value20}
# name21_histogram, description21, {key21:value21}
# name22_gauge, description22, {key22:value22}
# name23_sketch, description23, {key23:value23}
# name24_counter, description24, {key24:value24}
# name25_sketch, description25, {key25:value25}
# name26_gauge, description26, {key26:value26}
# name27_histogram, description27, {key27:value27}
# name28_exact, description28, {key28:value28}
# name29_counter, description29, {key29:value29}
# name30_exact, description30, {key30:value30}
# name31_exact, description31, {key31:value31}
# name32_counter, description32, {key32:value32}
# name33_gauge, description33, {key33:value33}
# name34_gauge, description34, {key34:value34}
# name35_counter, description35, {key35:value35}
# name36_exact, description36, {key36:value36}
# name37_sketch, description37, {key37:value37}
# name38_histogram, description38, {key38:value38}
# name39_sketch, description39, {key39:value39}
# name40_exact, description40, {key40:value40}
# name41_exact, description41, {key41:value41}
# name42_gauge, description42, {key42:value42}
# name43_counter, description43, {key43:value43}
# name44_histogram, description44, {key44:value44}
# name45_sketch, description45, {key45:value45}
# name46_exact, description46, {key46:value46}
# name47_gauge, description47, {key47:value47}
# name48_gauge, description48, {key48:value48}
# name49_histogram, description49, {key49:value49}
# name50_exact, description50, {key50:value50}
# name51_gauge, description51, {key51:value51}
# name52_counter, description52, {key52:value52}
# name53_gauge, description53, {key53:value53}
# name54_counter, description54, {key54:value54}
# name55_exact, description55, {key55:value55}
# name56_histogram, description56, {key56:value56}
# name57_exact, description57, {key57:value57}
# name58_sketch, description58, {key58:value58}
# name59_counter, description59, {key59:value59}
# name60_counter, description60, {key60:value60}
# name61_exact, description61, {key61:value61}
# name62_gauge, description62, {key62:value62}
# name63_sketch, description63, {key63:value63}
# name64_exact, description64, {key64:value64}
# name65_histogram, description65, {key65:value65}
# name66_gauge, description66, {key66:value66}
# name67_gauge, description67, {key67:value67}
# name68_counter, description68, {key68:value68}
# name69_exact, description69, {key69:value69}
# name70_exact, description70, {key70:value70}
# name71_exact, description71, {key71:value71}
# name72_histogram, description72, {key72:value72}
# name73_exact, description73, {key73:value73}
# name74_gauge, description74, {key74:value74}
# name75_exact, description75, {key75:value75}
# name76_histogram, description76, {key76:value76}
# name77_gauge, description77, {key77:value77}
# name78_gauge, description78, {key78:value78}
# name79_histogram, description79, {key79:value79}
# name80_gauge, description80, {key80:value80}
# name81_gauge, description81, {key81:value81}
# name82_exact, description82, {key82:value82}
# name83_sketch, description83, {key83:value83}
# name84_histogram, description84, {key84:value84}
# name85_exact, description85, {key85:value85}
# name86_sketch, description86, {key86:value86}
# name87_gauge, description87, {key87:value87}
# name88_histogram, description88, {key88:value88}
# name89_sketch, description89, {key89:value89}
# name90_sketch, description90, {key90:value90}
# name91_counter, description91, {key91:value91}
# name92_histogram, description92, {key92:value92}
# name93_histogram, description93, {key93:value93}
# name94_histogram, description94, {key94:value94}
# name95_exact, description95, {key95:value95}
# name96_gauge, description96, {key96:value96}
# name97_histogram, description97, {key97:value97}
# name98_exact, description98, {key98:value98}
# name99_counter, description99, {key99:value99}
# name100_histogram, description100, {key100:value100}
# name101_sketch, description101, {key101:value101}
# name102_histogram, description102, {key102:value102}
# name103_sketch, description103, {key103:value103}
# name104_histogram, description104, {key104:value104}
# name105_counter, description105, {key105:value105}
# name106_exact, description106, {key106:value106}
# name107_gauge, description107, {key107:value107}
# name108_counter, description108, {key108:value108}
# name109_counter, description109, {key109:value109}
# name110_gauge, description110, {key110:value110}
# name111_histogram, description111, {key111:value111}
# name112_histogram, description112, {key112:value112}
# name113_gauge, description113, {key113:value113}
# name114_sketch, description114, {key114:value114}
# name115_gauge, description115, {key115:value115}
# name116_counter, description116, {key116:value116}
# name117_histogram, description117, {key117:value117}
# name118_sketch, description118, {key118:value118}
# name119_sketch, description119, {key119:value119}
# name120_exact, description120, {key120:value120}
# name121_sketch, description121, {key121:value121}
# name122_histogram, description122, {key122:value122}
# name123_histogram, description123, {key123:value123}
# name124_counter, description124, {key124:value124}
# name125_histogram, description125, {key125:value125}
# name126_sketch, description126, {key126:value126}
# name127_counter, description127, {key127:value127}
# name128_counter, description128, {key128:value128}
# name129_gauge, description129, {key129:value129}
# name130_gauge, description130, {key130:value130}
# name131_gauge, description131, {key131:value131}
# name132_exact, description132, {key132:value132}
# name133_gauge, description133, {key133:value133}
# name134_histogram, description134, {key134:value134}
# name135_sketch, description135, {key135:value135}
# name136_sketch, description136, {key136:value136}
# name137_exact, description137, {key137:value137}
# name138_counter, description138, {key138:value138}
# name139_counter, description139, {key139:value139}
# name140_counter, description140, {key140:value140}
# name141_histogram, description141, {key141:value141}
# name142_gauge, description142, {key142:value142}
# name143_sketch, description143, {key143:value143}
# name144_counter, description144, {key144:value144}
# name145_gauge, description145, {key145:value145}
# name146_exact, description146, {key146:value146}
# name147_histogram, description147, {key147:value147}
# name148_exact, description148, {key148:value148}
# name149_exact, description149, {key149:value149}
# name150_counter, description150, {key150:value150}
# name151_sketch, description151, {key151:value151}
# name152_gauge, description152, {key152:value152}
# name153_counter, description153, {key153:value153}
# name154_exact, description154, {key154:value154}
# name155_counter, description155, {key155:value155}
# name156_counter, description156, {key156:value156}
# name157_exact, description157, {key157:value157}
# name158_sketch, description158, {key158:value158}
# name159_histogram, description159, {key159:value159}
# name160_sketch, description160, {key160:value160}
# name161_gauge, description161, {key161:value161}
# name162_exact, description162, {key162:value162}
# name163_gauge, description163, {key163:value163}
# name164_exact, description164, {key164:value164}
# name165_exact, description165, {key165:value165}
# name166_gauge, description166, {key166:value166}
# name167_counter, description167, {key167:value167}
# name168_sketch, description168, {key168:value168}
# name169_histogram, description169, {key169:value169}
# name170_counter, description170, {key170:value170}
# name171_gauge, description171, {key171:value171}
# name172_sketch, description172, {key172:value172}
# name173_sketch, description173, {key173:value173}
# name174_sketch, description174, {key174:value174}
# name175_counter, description175, {key175:value175}
# name176_gauge, description176, {key176:value176}
# name177_histogram, description177, {key177:value177}
# name178_histogram, description178, {key178:value178}
# name179_counter, description179, {key179:value179}
# name180_gauge, description180, {key180:value180}
# name181_exact, description181, {key181:value181}
# name182_counter, description182, {key182:value182}
# name183_gauge, description183, {key183:value183}
# name184_exact, description184, {key184:value184}
# name185_sketch, description185, {key185:value185}
# name186_histogram, description186, {key186:value186}
# name187_counter, description187, {key187:value187}
# name188_sketch, description188, {key188:value188}
# name189_sketch, description189, {key189:value189}
# name190_histogram, description190, {key190:value190}
# name191_counter, description191, {key191:value191}
# name192_exact, description192, {key192:value192}
# name193_histogram, description193, {key193:value193}
# name194_histogram, description194, {key194:value194}
# name195_sketch, description195, {key195:value195}
# name196_histogram, description196, {key196:value196}
# name197_counter, description197, {key197:value197}
# name198_exact, description198, {key198:value198}
# name199_sketch, description199, {key199:value199}
# name200_gauge, description200, {key200:value200}
# name201_gauge, description201, {key201:value201}
# name202_gauge, description202, {key202:value202}
# name203_gauge, description203, {key203:value203}
# name204_gauge, description204, {key204:value204}
# name205_gauge, description205, {key205:value205}
# name206_gauge, description206, {key206:value206}
# name207_sketch, description207, {key207:value207}
# name208_counter, description208, {key208:value208}
# name209_gauge, description209, {key209:value209}
# name210_sketch, description210, {key210:value210}
# name211_sketch, description211, {key211:value211}
# name212_counter, description212, {key212:value212}
# name213_gauge, description213, {key213:value213}
# name214_exact, description214, {key214:value214}
# name215_counter, description215, {key215:value215}
# name216_counter, description216, {key216:value216}
# name217_exact, description217, {key217:value217}
# name218_gauge, description218, {key218:value218}
# name219_sketch, description219, {key219:value219}
# name220_counter, description220, {key220:value220}
# name221_gauge, description221, {key221:value221}
# name222_gauge, description222, {key222:value222}
# name223_exact, description223, {key223:value223}
# name224_histogram, description224, {key224:value224}
# name225_counter, description225, {key225:value225}
# name226_histogram, description226, {key226:value226}
# name227_exact, description227, {key227:value227}
# name228_sketch, description228, {key228:value228}
# name229_gauge, description229, {key229:value229}
# name230_sketch, description230, {key230:value230}
# name231_histogram, description231, {key231:value231}
# name232_counter, description232, {key232:value232}
# name233_gauge, description233, {key233:value233}
# name234_gauge, description234, {key234:value234}
# name235_gauge, description235, {key235:value235}
# name236_exact, description236, {key236:value236}
# name237_gauge, description237, {key237:value237}
# name238_histogram, description238, {key238:value238}
# name239_gauge, description239, {key239:value239}
# name240_gauge, description240, {key240:value240}
# name241_sketch, description241, {key241:value241}
# name242_counter, description242, {key242:value242}
# name243_histogram, description243, {key243:value243}
# name244_counter, description244, {key244:value244}
# name245_gauge, description245, {key245:value245}
# name246_sketch, description246, {key246:value246}
# name247_exact, description247, {key247:value247}
# name248_sketch, description248, {key248:value248}
# name249_gauge, description249, {key249:value249}
# name250_counter, description250, {key250:value250}
# name251_sketch, description251, {key251:value251}
# name252_counter, description252, {key252:value252}
# name253_sketch, description253, {key253:value253}
# name254_gauge, description254, {key254:value254}
# name255_histogram, description255, {key255:value255}
# name256_sketch, description256, {key256:value256}
# name257_histogram, description257, {key257:value257}
# name258_exact, description258, {key258:value258}
# name259_exact, description259, {key259:value259}
# name260_exact, description260, {key260:value260}
# name261_histogram, description261, {key261:value261}
# name262_gauge, description262, {key262:value262}
# name263_exact, description263, {key263:value263}
# name264_histogram, description264, {key264:value264}
# name265_sketch, description265, {key265:value265}
# name266_counter, description266, {key266:value266}
# name267_counter, description267, {key267:value267}
# name268_sketch, description268, {key268:value268}
# name269_counter, description269, {key269:value269}
# name270_histogram, description270, {key270:value270}
# name271_sketch, description271, {key271:value271}
# name272_counter, description272, {key272:value272}
# name273_exact, description273, {key273:value273}
# name274_histogram, description274, {key274:value274}
# name275_exact, description275, {key275:value275}
# name276_counter, description276, {key276:value276}
# name277_histogram, description277, {key277:value277}
# name278_sketch, description278, {key278:value278}
# name279_histogram, description279, {key279:value279}
# name280_counter, description280, {key280:value280}
# name281_exact, description281, {key281:value281}
# name282_exact, description282, {key282:value282}
# name283_sketch, description283, {key283:value283}
# name284_gauge, description284, {key284:value284}
# name285_histogram, description285, {key285:value285}
# name286_counter, description286, {key286:value286}
# name287_exact, description287, {key287:value287}
# name288_sketch, description288, {key288:value288}
# name289_gauge, description289, {key289:value289}
# name290_histogram, description290, {key290:value290}
# name291_histogram, description291, {key291:value291}
# name292_histogram, description292, {key292:value292}
# name293_gauge, description293, {key293:value293}
# name294_counter, description294, {key294:value294}
# name295_exact, description295, {key295:value295}
# name296_counter, description296, {key296:value296}
# name297_gauge, description297, {key297:value297}
# name298_counter, description298, {key298:value298}
# name299_histogram, description299, {key299:value299}
# name300_exact, description300, {key300:value300}
# name301_counter, description301, {key301:value301}
# name302_histogram, description302, {key302:value302}
# name303_gauge, description303, {key303:value303}
# name304_exact, description304, {key304:value304}
# name305_histogram, description305, {key305:value305}
# name306_exact, description306, {key306:value306}
# name307_counter, description307, {key307:value307}
# name308_gauge, description308, {key308:value308}
# name309_sketch, description309, {key309:value309}
# name310_histogram, description310, {key310:value310}
# name311_sketch, description311, {key311:value311}
# name312_histogram, description312, {key312:value312}
# name313_exact, description313, {key313:value313}
# name314_counter, description314, {key314:value314}
# name315_counter, description315, {key315:value315}
# name316_sketch, description316, {key316:value316}
# name317_sketch, description317, {key317:value317}
# name318_histogram, description318, {key318:value318}
# name319_exact, description319, {key319:value319}
# name320_histogram, description320, {key320:value320}
# name321_gauge, description321, {key321:value321}
# name322_exact, description322, {key322:value322}
# name323_sketch, description323, {key323:value323}
# name324_counter, description324, {key324:value324}
# name325_gauge, description325, {key325:value325}
# name326_counter, description326, {key326:value326}
# name327_counter, description327, {key327:value327}
# name328_counter, description328, {key328:value328}
# name329_gauge, description329, {key329:value329}
# name330_sketch, description330, {key330:value330}
# name331_gauge, description331, {key331:value331}
# name332_gauge, description332, {key332:value332}
# name333_counter, description333, {key333:value333}
# name334_sketch, description334, {key334:value334}
# name335_sketch, description335, {key335:value335}
# name336_counter, description336, {key336:value336}
# name337_sketch, description337, {key337:value337}
# name338_gauge, description338, {key338:value338}
# name339_gauge, description339, {key339:value339}
# name340_counter, description340, {key340:value340}
# name341_sketch, description341, {key341:value341}
# name342_counter, description342, {key342:value342}
# name343_counter, description343, {key343:value343}
# name344_histogram, description344, {key344:value344}
# name345_histogram, description345, {key345:value345}
# name346_exact, description346, {key346:value346}
# name347_histogram, description347, {key347:value347}
# name348_exact, description348, {key348:value348}
# name349_gauge, description349, {key349:value349}
# name350_gauge, description350, {key350:value350}
# name351_exact, description351, {key351:value351}
# name352_exact, description352, {key352:value352}
# name353_counter, description353, {key353:value353}
# name354_sketch, description354, {key354:value354}
# name355_gauge, description355, {key355:value355}
# name356_histogram, description356, {key356:value356}
# name357_counter, description357, {key357:value357}
# name358_gauge, description358, {key358:value358}
# name359_gauge, description359, {key359:value359}
# name360_histogram, description360, {key360:value360}
# name361_gauge, description361, {key361:value361}
# name362_gauge, description362, {key362:value362}
# name363_exact, description363, {key363:value363}
# name364_exact, description364, {key364:value364}
# name365_gauge, description365, {key365:value365}
# name366_histogram, description366, {key366:value366}
# name367_exact, description367, {key367:value367}
# name368_exact, description368, {key368:value368}
# name369_exact, description369, {key369:value369}
# name370_counter, description370, {key370:value370}
# name371_histogram, description371, {key371:value371}
# name372_sketch, description372, {key372:value372}
# name373_exact, description373, {key373:value373}
# name374_histogram, description374, {key374:value374}
# name375_exact, description375, {key375:value375}
# name376_gauge, description376, {key376:value376}
# name377_gauge, description377, {key377:value377}
# name378_sketch, description378, {key378:value378}
# name379_exact, description379, {key379:value379}
# name380_gauge, description380, {key380:value380}
# name381_histogram, description381, {key381:value381}
# name382_histogram, description382, {key382:value382}
# name383_gauge, description383, {key383:value383}
# name384_histogram, description384, {key384:value384}
# name385_histogram, description385, {key385:value385}
# name386_sketch, description386, {key386:value386}
# name387_gauge, description387, {key387:value387}
# name388_gauge, description388, {key388:value388}
# name389_counter, description389, {key389:value389}
# name390_counter, description390, {key390:value390}
# name391_gauge, description391, {key391:value391}
# name392_sketch, description392, {key392:value392}
# name393_histogram, description393, {key393:value393}
# name394_gauge, description394, {key394:value394}
# name395_gauge, description395, {key395:value395}
# name396_sketch, description396, {key396:value396}
# name397_gauge, description397, {key397:value397}
# name398_counter, description398, {key398:value398}
# name399_histogram, description399, {key399:value399}
# name400_counter, description400, {key400:value400}
# name401_sketch, description401, {key401:value401}
# name402_exact, description402, {key402:value402}
# name403_sketch, description403, {key403:value403}
# name404_sketch, description404, {key404:value404}
# name405_sketch, description405, {key405:value405}
# name406_counter, description406, {key406:value406}
# name407_counter, description407, {key407:value407}
# name408_counter, description408, {key408:value408}
# name409_counter, description409, {key409:value409}
# name410_gauge, description410, {key410:value410}
# name411_histogram, description411, {key411:value411}
# name412_sketch, description412, {key412:value412}
# name413_exact, description413, {key413:value413}
# name414_histogram, description414, {key414:value414}
# name415_exact, description415, {key415:value415}
# name416_histogram, description416, {key416:value416}
# name417_gauge, description417, {key417:value417}
# name418_gauge, description418, {key418:value418}
# name419_histogram, description419, {key419:value419}
# name420_sketch, description420, {key420:value420}
# name421_sketch, description421, {key421:value421}
# name422_counter, description422, {key422:value422}
# name423_sketch, description423, {key423:value423}
# name424_gauge, description424, {key424:value424}
# name425_sketch, description425, {key425:value425}
# name426_histogram, description426, {key426:value426}
# name427_histogram, description427, {key427:value427}
# name428_exact, description428, {key428:value428}
# name429_histogram, description429, {key429:value429}
# name430_gauge, description430, {key430:value430}
# name431_counter, description431, {key431:value431}
# name432_gauge, description432, {key432:value432}
# name433_counter, description433, {key433:value433}
# name434_exact, description434, {key434:value434}
# name435_exact, description435, {key435:value435}
# name436_gauge, description436, {key436:value436}
# name437_exact, description437, {key437:value437}
# name438_gauge, description438, {key438:value438}
# name439_histogram, description439, {key439:value439}
# name440_counter, description440, {key440:value440}
# name441_histogram, description441, {key441:value441}
# name442_histogram, description442, {key442:value442}
# name443_gauge, description443, {key443:value443}
# name444_counter, description444, {key444:value444}
# name445_histogram, description445, {key445:value445}
# name446_gauge, description446, {key446:value446}
# name447_exact, description447, {key447:value447}
# name448_histogram, description448, {key448:value448}
# name449_histogram, description449, {key449:value449}
# name450_sketch, description450, {key450:value450}
# name451_exact, description451, {key451:value451}
# name452_sketch, description452, {key452:value452}
# name453_exact, description453, {key453:value453}
# name454_sketch, description454, {key454:value454}
# name455_histogram, description455, {key455:value455}
# name456_histogram, description456, {key456:value456}
# name457_gauge, description457, {key457:value457}
# name458_exact, description458, {key458:value458}
# name459_exact, description459, {key459:value459}
# name460_gauge, description460, {key460:value460}
# name461_histogram, description461, {key461:value461}
# name462_histogram, description462, {key462:value462}
# name463_sketch, description463, {key463:value463}
# name464_gauge, description464, {key464:value464}
# name465_sketch, description465, {key465:value465}
# name466_exact, description466, {key466:value466}
# name467_sketch, description467, {key467:value467}
# name468_gauge, description468, {key468:value468}
# name469_counter, description469, {key469:value469}
# name470_histogram, description470, {key470:value470}
# name471_counter, description471, {key471:value471}
# name472_counter, description472, {key472:value472}
# name473_gauge, description473, {key473:value473}
# name474_counter, description474, {key474:value474}
# name475_exact, description475, {key475:value475}
# name476_counter, description476, {key476:value476}
# name477_sketch, description477, {key477:value477}
# name478_histogram, description478, {key478:value478}
# name479_counter, description479, {key479:value479}
# name480_sketch, description480, {key480:value480}
# name481_exact, description481, {key481:value481}
# name482_gauge, description482, {key482:value482}
# name483_exact, description483, {key483:value483}
# name484_histogram, description484, {key484:value484}
# name485_counter, description485, {key485:value485}
# name486_sketch, description486, {key486:value486}
# name487_sketch, description487, {key487:value487}
# name488_exact, description488, {key488:value488}
# name489_sketch, description489, {key489:value489}
# name490_exact, description490, {key490:value490}
# name491_histogram, description491, {key491:value491}
# name492_exact, description492, {key492:value492}
# name493_counter, description493, {key493:value493}
# name494_counter, description494, {key494:value494}
# name495_gauge, description495, {key495:value495}
# name496_histogram, description496, {key496:value496}
# name497_exact, description497, {key497:value497}
# name498_gauge, description498, {key498:value498}
# name499_gauge, description499, {key499:value499}
# name500_gauge, description500, {key500:value500}
# name501_counter, description501, {key501:value501}
# name502_counter, description502, {key502:value502}
# name503_exact, description503, {key503:value503}
# name504_counter, description504, {key504:value504}
# name505_sketch, description505, {key505:value505}
# name506_gauge, description506, {key506:value506}
# name507_counter, description507, {key507:value507}
# name508_sketch, description508, {key508:value508}
# name509_counter, description509, {key509:value509}
# name510_histogram, description510, {key510:value510}
# name511_sketch, description511, {key511:value511}
# name512_histogram, description512, {key512:value512}
# name513_exact, description513, {key513:value513}
# name514_sketch, description514, {key514:value514}
# name515_gauge, description515, {key515:value515}
# name516_exact, description516, {key516:value516}
# name517_exact, description517, {key517:value517}
# name518_counter, description518, {key518:value518}
# name519_counter, description519, {key519:value519}
# name520_histogram, description520, {key520:value520}
# name521_gauge, description521, {key521:value521}
# name522_histogram, description522, {key522:value522}
# name523_histogram, description523, {key523:value523}
# name524_sketch, description524, {key524:value524}
# name525_gauge, description525, {key525:value525}
# name526_sketch, description526, {key526:value526}
# name527_gauge, description527, {key527:value527}
# name528_sketch, description528, {key528:value528}
# name529_histogram, description529, {key529:value529}
# name530_counter, description530, {key530:value530}
# name531_histogram, description531, {key531:value531}
# name532_gauge, description532, {key532:value532}
# name533_exact, description533, {key533:value533}
# name534_gauge, description534, {key534:value534}
# name535_sketch, description535, {key535:value535}
# name536_exact, description536, {key536:value536}
# name537_exact, description537, {key537:value537}
# name538_exact, description538, {key538:value538}
# name539_histogram, description539, {key539:value539}
# name540_exact, description540, {key540:value540}
# name541_gauge, description541, {key541:value541}
# name542_gauge, description542, {key542:value542}
# name543_sketch, description543, {key543:value543}
# name544_counter, description544, {key544:value544}
# name545_sketch, description545, {key545:value545}
# name546_histogram, description546, {key546:value546}
# name547_gauge, description547, {key547:value547}
# name548_histogram, description548, {key548:value548}
# name549_gauge, description549, {key549:value549}
# name550_counter, description550, {key550:value550}
# name551_sketch, description551, {key551:value551}
# name552_gauge, description552, {key552:value552}
# name553_gauge, description553, {key553:value553}
# name554_sketch, description554, {key554:value554}
# name555_counter, description555, {key555:value555}
# name556_sketch, description556, {key556:value556}
# name557_exact, description557, {key557:value557}
# name558_histogram, description558, {key558:value558}
# name559_gauge, description559, {key559:value559}
# name560_sketch, description560, {key560:value560}
# name561_sketch, description561, {key561:value561}
# name562_histogram, description562, {key562:value562}
# name563_exact, description563, {key563:value563}
# name564_histogram, description564, {key564:value564}
# name565_counter, description565, {key565:value565}
# name566_gauge, description566, {key566:value566}
# name567_counter, description567, {key567:value567}
# name568_counter, description568, {key568:value568}
# name569_counter, description569, {key569:value569}
# name570_histogram, description570, {key570:value570}
# name571_exact, description571, {key571:value571}
# name572_counter, description572, {key572:value572}
# name573_histogram, description573, {key573:value573}
# name574_counter, description574, {key574:value574}
# name575_sketch, description575, {key575:value575}
# name576_exact, description576, {key576:value576}
# name577_sketch, description577, {key577:value577}
# name578_histogram, description578, {key578:value578}
# name579_gauge, description579, {key579:value579}
# name580_histogram, description580, {key580:value580}
# name581_sketch, description581, {key581:value581}
# name582_sketch, description582, {key582:value582}
# name583_counter, description583, {key583:value583}
# name584_counter, description584, {key584:value584}
# name585_gauge, description585, {key585:value585}
# name586_sketch, description586, {key586:value586}
# name587_sketch, description587, {key587:value587}
# name588_sketch, description588, {key588:value588}
# name589_sketch, description589, {key589:value589}
# name590_sketch, description590, {key590:value590}
# name591_counter, description591, {key591:value591}
# name592_sketch, description592, {key592:value592}
# name593_counter, description593, {key593:value593}
# name594_exact, description594, {key594:value594}
# name595_exact, description595, {key595:value595}
# name596_histogram, description596, {key596:value596}
# name597_gauge, description597, {key597:value597}
# name598_gauge, description598, {key598:value598}
# name599_sketch, description599, {key599:value599}
# name600_histogram, description600, {key600:value600}
# name601_sketch, description601, {key601:value601}
# name602_exact, description602, {key602:value602}
# name603_sketch, description603, {key603:value603}
# name604_sketch, description604, {key604:value604}
# name605_gauge, description605, {key605:value605}
# name606_exact, description606, {key606:value606}
# name607_sketch, description607, {key607:value607}
# name608_histogram, description608, {key608:value608}
# name609_histogram, description609, {key609:value609}
# name610_exact, description610, {key610:value610}
# name611_gauge, description611, {key611:value611}
# name612_exact, description612, {key612:value612}
# name613_sketch, description613, {key613:value613}
# name614_sketch, description614, {key614:value614}
# name615_histogram, description615, {key615:value615}
# name616_gauge, description616, {key616:value616}
# name617_counter, description617, {key617:value617}
# name618_exact, description618, {key618:value618}
# name619_gauge, description619, {key619:value619}
# name620_exact, description620, {key620:value620}
# name621_gauge, description621, {key621:value621}
# name622_gauge, description622, {key622:value622}
# name623_exact, description623, {key623:value623}
# name624_gauge, description624, {key624:value624}
# name625_sketch, description625, {key625:value625}
# name626_gauge, description626, {key626:value626}
# name627_gauge, description627, {key627:value627}
# name628_gauge, description628, {key628:value628}
# name629_exact, description629, {key629:value629}
# name630_sketch, description630, {key630:value630}
# name631_counter, description631, {key631:value631}
# name632_exact, description632, {key632:value632}
# name633_counter, description633, {key633:value633}
# name634_histogram, description634, {key634:value634}
# name635_exact, description635, {key635:value635}
# name636_sketch, description636, {key636:value636}
# name637_sketch, description637, {key637:value637}
# name638_gauge, description638, {key638:value638}
# name639_gauge, description639, {key639:value639}
# name640_sketch, description640, {key640:value640}
# name641_counter, description641, {key641:value641}
# name642_gauge, description642, {key642:value642}
# name643_histogram, description643, {key643:value643}
# name644_gauge, description644, {key644:value644}
# name645_exact, description645, {key645:value645}
# name646_counter, description646, {key646:value646}
# name647_histogram, description647, {key647:value647}
# name648_sketch, description648, {key648:value648}
# name649_gauge, description649, {key649:value649}
# name650_gauge, description650, {key650:value650}
# name651_histogram, description651, {key651:value651}
# name652_sketch, description652, {key652:value652}
# name653_gauge, description653, {key653:value653}
# name654_exact, description654, {key654:value654}
# name655_counter, description655, {key655:value655}
# name656_counter, description656, {key656:value656}
# name657_gauge, description657, {key657:value657}
# name658_sketch, description658, {key658:value658}
# name659_histogram, description659, {key659:value659}
# name660_counter, description660, {key660:value660}
# name661_sketch, description661, {key661:value661}
# name662_sketch, description662, {key662:value662}
# name663_counter, description663, {key663:value663}
# name664_counter, description664, {key664:value664}
# name665_exact, description665, {key665:value665}
# name666_sketch, description666, {key666:value666}
# name667_exact, description667, {key667:value667}
# name668_counter, description668, {key668:value668}
# name669_histogram, description669, {key669:value669}
# name670_counter, description670, {key670:value670}
# name671_sketch, description671, {key671:value671}
# name672_histogram, description672, {key672:value672}
# name673_sketch, description673, {key673:value673}
# name674_counter, description674, {key674:value674}
# name675_sketch, description675, {key675:value675}
# name676_histogram, description676, {key676:value676}
# name677_exact, description677, {key677:value677}
# name678_gauge, description678, {key678:value678}
# name679_sketch, description679, {key679:value679}
# name680_gauge, description680, {key680:value680}
# name681_counter, description681, {key681:value681}
# name682_histogram, description682, {key682:value682}
# name683_sketch, description683, {key683:value683}
# name684_exact, description684, {key684:value684}
# name685_gauge, description685, {key685:value685}
# name686_histogram, description686, {key686:value686}
# name687_gauge, description687, {key687:value687}
# name688_counter, description688, {key688:value688}
# name689_gauge, description689, {key689:value689}
# name690_histogram, description690, {key690:value690}
# name691_exact, description691, {key691:value691}
# name692_histogram, description692, {key692:value692}
# name693_exact, description693, {key693:value693}
# name694_sketch, description694, {key694:value694}
# name695_exact, description695, {key695:value695}
# name696_counter, description696, {key696:value696}
# name697_exact, description697, {key697:value697}
# name698_gauge, description698, {key698:value698}
# name699_sketch, description699, {key699:value699}
# name700_counter, description700, {key700:value700}
# name701_exact, description701, {key701:value701}
# name702_counter, description702, {key702:value702}
# name703_exact, description703, {key703:value703}
# name704_gauge, description704, {key704:value704}
# name705_gauge, description705, {key705:value705}
# name706_sketch, description706, {key706:value706}
# name707_counter, description707, {key707:value707}
# name708_gauge, description708, {key708:value708}
# name709_histogram, description709, {key709:value709}
# name710_gauge, description710, {key710:value710}
# name711_histogram, description711, {key711:value711}
# name712_exact, description712, {key712:value712}
# name713_exact, description713, {key713:value713}
# name714_gauge, description714, {key714:value714}
# name715_gauge, description715, {key715:value715}
# name716_histogram, description716, {key716:value716}
# name717_histogram, description717, {key717:value717}
# name718_exact, description718, {key718:value718}
# name719_histogram, description719, {key719:value719}
# name720_sketch, description720, {key720:value720}
# name721_histogram, description721, {key721:value721}
# name722_sketch, description722, {key722:value722}
# name723_counter, description723, {key723:value723}
# name724_exact, description724, {key724:value724}
# name725_sketch, description725, {key725:value725}
# name726_gauge, description726, {key726:value726}
# name727_counter, description727, {key727:value727}
# name728_exact, description728, {key728:value728}
# name729_counter, description729, {key729:value729}
# name730_sketch, description730, {key730:value730}
# name731_gauge, description731, {key731:value731}
# name732_gauge, description732, {key732:value732}
# name733_gauge, description733, {key733:value733}
# name734_histogram, description734, {key734:value734}
# name735_exact, description735, {key735:value735}
# name736_gauge, description736, {key736:value736}
# name737_histogram, description737, {key737:value737}
# name738_histogram, description738, {key738:value738}
# name739_counter, description739, {key739:value739}
# name740_sketch, description740, {key740:value740}
# name741_counter, description741, {key741:value741}
# name742_counter, description742, {key742:value742}
# name743_sketch, description743, {key743:value743}
# name744_sketch, description744, {key744:value744}
# name745_exact, description745, {key745:value745}
# name746_counter, description746, {key746:value746}
# name747_histogram, description747, {key747:value747}
# name748_gauge, description748, {key748:value748}
# name749_exact, description749, {key749:value749}
# name750_counter, description750, {key750:value750}
# name751_histogram, description751, {key751:value751}
# name752_sketch, description752, {key752:value752}
# name753_histogram, description753, {key753:value753}
# name754_sketch, description754, {key754:value754}
# name755_histogram, description755, {key755:value755}
# name756_counter, description756, {key756:value756}
# name757_gauge, description757, {key757:value757}
# name758_exact, description758, {key758:value758}
# name759_gauge, description759, {key759:value759}
# name760_sketch, description760, {key760:value760}
# name761_gauge, description761, {key761:value761}
# name762_counter, description762, {key762:value762}
# name763_histogram, description763, {key763:value763}
# name764_gauge, description764, {key764:value764}
# name765_histogram, description765, {key765:value765}
# name766_gauge, description766, {key766:value766}
# name767_counter, description767, {key767:value767}
# name768_exact, description768, {key768:value768}
# name769_counter, description769, {key769:value769}
# name770_sketch, description770, {key770:value770}
# name771_gauge, description771, {key771:value771}
# name772_counter, description772, {key772:value772}
# name773_counter, description773, {key773:value773}
# name774_gauge, description774, {key774:value774}
# name775_sketch, description775, {key775:value775}
# name776_sketch, description776, {key776:value776}
# name777_exact, description777, {key777:value777}
# name778_exact, description778, {key778:value778}
# name779_sketch, description779, {key779:value779}
# name780_counter, description780, {key780:value780}
# name781_sketch, description781, {key781:value781}
# name782_sketch, description782, {key782:value782}
# name783_histogram, description783, {key783:value783}
# name784_histogram, description784, {key784:value784}
# name785_sketch, description785, {key785:value785}
# name786_gauge, description786, {key786:value786}
# name787_gauge, description787, {key787:value787}
# name788_counter, description788, {key788:value788}
# name789_histogram, description789, {key789:value789}
# name790_histogram, description790, {key790:value790}
# name791_gauge, description791, {key791:value791}
# name792_exact, description792, {key792:value792}
# name793_gauge, description793, {key793:value793}
# name794_histogram, description794, {key794:value794}
# name795_histogram, description795, {key795:value795}
# name796_sketch, description796, {key796:value796}
# name797_sketch, description797, {key797:value797}
# name798_exact, description798, {key798:value798}
# name799_gauge, description799, {key799:value799}
# name800_counter, description800, {key800:value800}
# name801_gauge, description801, {key801:value801}
# name802_exact, description802, {key802:value802}
# name803_exact, description803, {key803:value803}
# name804_histogram, description804, {key804:value804}
# name805_histogram, description805, {key805:value805}
# name806_counter, description806, {key806:value806}
# name807_histogram, description807, {key807:value807}
# name808_counter, description808, {key808:value808}
# name809_sketch, description809, {key809:value809}
# name810_histogram, description810, {key810:value810}
# name811_exact, description811, {key811:value811}
# name812_counter, description812, {key812:value812}
# name813_counter, description813, {key813:value813}
# name814_histogram, description814, {key814:value814}
# name815_histogram, description815, {key815:value815}
# name816_gauge, description816, {key816:value816}
# name817_counter, description817, {key817:value817}
# name818_counter, description818, {key818:value818}
# name819_sketch, description819, {key819:value819}
# name820_histogram, description820, {key820:value820}
# name821_counter, description821, {key821:value821}
# name822_gauge, description822, {key822:value822}
# name823_sketch, description823, {key823:value823}
# name824_gauge, description824, {key824:value824}
# name825_gauge, description825, {key825:value825}
# name826_exact, description826, {key826:value826}
# name827_counter, description827, {key827:value827}
# name828_counter, description828, {key828:value828}
# name829_counter, description829, {key829:value829}
# name830_sketch, description830, {key830:value830}
# name831_sketch, description831, {key831:value831}
# name832_gauge, description832, {key832:value832}
# name833_counter, description833, {key833:value833}
# name834_histogram, description834, {key834:value834}
# name835_histogram, description835, {key835:value835}
# name836_histogram, description836, {key836:value836}
# name837_counter, description837, {key837:value837}
# name838_exact, description838, {key838:value838}
# name839_gauge, description839, {key839:value839}
# name840_sketch, description840, {key840:value840}
# name841_exact, description841, {key841:value841}
# name842_counter, description842, {key842:value842}
# name843_gauge, description843, {key843:value843}
# name844_counter, description844, {key844:value844}
# name845_exact, description845, {key845:value845}
# name846_histogram, description846, {key846:value846}
# name847_counter, description847, {key847:value847}
# name848_exact, description848, {key848:value848}
# name849_sketch, description849, {key849:value849}
# name850_gauge, description850, {key850:value850}
# name851_gauge, description851, {key851:value851}
# name852_gauge, description852, {key852:value852}
# name853_exact, description853, {key853:value853}
# name854_gauge, description854, {key854:value854}
# name855_sketch, description855, {key855:value855}
# name856_gauge, description856, {key856:value856}
# name857_exact, description857, {key857:value857}
# name858_exact, description858, {key858:value858}
# name859_sketch, description859, {key859:value859}
# name860_sketch, description860, {key860:value860}
# name861_gauge, description861, {key861:value861}
# name862_counter, description862, {key862:value862}
# name863_exact, description863, {key863:value863}
# name864_exact, description864, {key864:value864}
# name865_exact, description865, {key865:value865}
# name866_histogram, description866, {key866:value866}
# name867_exact, description867, {key867:value867}
# name868_histogram, description868, {key868:value868}
# name869_gauge, description869, {key869:value869}
# name870_gauge, description870, {key870:value870}
# name871_counter, description871, {key871:value871}
# name872_histogram, description872, {key872:value872}
# name873_exact, description873, {key873:value873}
# name874_exact, description874, {key874:value874}
# name875_sketch, description875, {key875:value875}
# name876_sketch, description876, {key876:value876}
# name877_exact, description877, {key877:value877}
# name878_histogram, description878, {key878:value878}
# name879_gauge, description879, {key879:value879}
# name880_sketch, description880, {key880:value880}
# name881_histogram, description881, {key881:value881}
# name882_counter, description882, {key882:value882}
# name883_histogram, description883, {key883:value883}
# name884_histogram, description884, {key884:value884}
# name885_gauge, description885, {key885:value885}
# name886_gauge, description886, {key886:value886}
# name887_gauge, description887, {key887:value887}
# name888_counter, description888, {key888:value888}
# name889_exact, description889, {key889:value889}
# name890_counter, description890, {key890:value890}
# name891_sketch, description891, {key891:value891}
# name892_sketch, description892, {key892:value892}
# name893_sketch, description893, {key893:value893}
# name894_gauge, description894, {key894:value894}
# name895_counter, description895, {key895:value895}
# name896_histogram, description896, {key896:value896}
# name897_sketch, description897, {key897:value897}
# name898_counter, description898, {key898:value898}
# name899_sketch, description899, {key899:value899}
# name900_exact, description900, {key900:value900}
# name901_sketch, description901, {key901:value901}
# name902_counter, description902, {key902:value902}
# name903_sketch, description903, {key903:value903}
# name904_histogram, description904, {key904:value904}
# name905_counter, description905, {key905:value905}
# name906_sketch, description906, {key906:value906}
# name907_sketch, description907, {key907:value907}
# name908_exact, description908, {key908:value908}
# name909_gauge, description909, {key909:value909}
# name910_sketch, description910, {key910:value910}
# name911_gauge, description911, {key911:value911}
# name912_sketch, description912, {key912:value912}
# name913_exact, description913, {key913:value913}
# name914_gauge, description914, {key914:value914}
# name915_counter, description915, {key915:value915}
# name916_histogram, description916, {key916:value916}
# name917_sketch, description917, {key917:value917}
# name918_exact, description918, {key918:value918}
# name919_sketch, description919, {key919:value919}
# name920_sketch, description920, {key920:value920}
# name921_histogram, description921, {key921:value921}
# name922_sketch, description922, {key922:value922}
# name923_gauge, description923, {key923:value923}
# name924_counter, description924, {key924:value924}
# name925_sketch, description925, {key925:value925}
# name926_gauge, description926, {key926:value926}
# name927_counter, description927, {key927:value927}
# name928_histogram, description928, {key928:value928}
# name929_sketch, description929, {key929:value929}
# name930_histogram, description930, {key930:value930}
# name931_counter, description931, {key931:value931}
# name932_counter, description932, {key932:value932}
# name933_counter, description933, {key933:value933}
# name934_exact, description934, {key934:value934}
# name935_sketch, description935, {key935:value935}
# name936_sketch, description936, {key936:value936}
# name937_histogram, description937, {key937:value937}
# name938_gauge, description938, {key938:value938}
# name939_sketch, description939, {key939:value939}
# name940_counter, description940, {key940:value940}
# name941_sketch, description941, {key941:value941}
# name942_gauge, description942, {key942:value942}
# name943_gauge, description943, {key943:value943}
# name944_counter, description944, {key944:value944}
# name945_gauge, description945, {key945:value945}
# name946_counter, description946, {key946:value946}
# name947_gauge, description947, {key947:value947}
# name948_sketch, description948, {key948:value948}
# name949_counter, description949, {key949:value949}
# name950_counter, description950, {key950:value950}
# name951_sketch, description951, {key951:value951}
# name952_exact, description952, {key952:value952}
# name953_counter, description953, {key953:value953}
# name954_histogram, description954, {key954:value954}
# name955_counter, description955, {key955:value955}
# name956_exact, description956, {key956:value956}
# name957_sketch, description957, {key957:value957}
# name958_counter, description958, {key958:value958}
# name959_histogram, description959, {key959:value959}
# name960_histogram, description960, {key960:value960}
# ...
# name1755_gauge, description1755, {key1755:value1755}
# name1756_histogram, description1756, {key1756:value1756}
# name1757_gauge, description1757, {key1757:value1757}
# name1758_gauge, description1758, {key1758:value1758}
# name1759_sketch, description1759, {key1759:value1759}
# name1760_counter, description1760, {key1760:value1760}
# name1761_gauge, description1761, {key1761:value1761}
# name1762_counter, description1762, {key1762:value1762}
# name1763_counter, description1763, {key1763:value1763}
# name1764_exact, description1764, {key1764:value1764}
# name1765_histogram, description1765, {key1765:value1765}
# name1766_gauge, description1766, {key1766:value1766}
# name1767_exact, description1767, {key1767:value1767}
# name1768_sketch, description1768, {key1768:value1768}
# name1769_sketch, description1769, {key1769:value1769}
# name1770_sketch, description1770, {key1770:value1770}
# name1771_gauge, description1771, {key1771:value1771}
# name1772_sketch, description1772, {key1772:value1772}
# name1773_sketch, description1773, {key1773:value1773}
# name1774_sketch, description1774, {key1774:value1774}
# name1775_histogram, description1775, {key1775:value1775}
# name1776_exact, description1776, {key1776:value1776}
# name1777_gauge, description1777, {key1777:value1777}
# name1778_counter, description1778, {key1778:value1778}
# name1779_counter, description1779, {key1779:value1779}
# name1780_sketch, description1780, {key1780:value1780}
# name1781_counter, description1781, {key1781:value1781}
# name1782_exact, description1782, {key1782:value1782}
# name1783_sketch, description1783, {key1783:value1783}
# name1784_histogram, description1784, {key1784:value1784}
# name1785_counter, description1785, {key1785:value1785}
# name1786_sketch, description1786, {key1786:value1786}
# name1787_sketch, description1787, {key1787:value1787}
# name1788_sketch, description1788, {key1788:value1788}
# name1789_gauge, description1789, {key1789:value1789}
# name1790_exact, description1790, {key1790:value1790}
# name1791_gauge, description1791, {key1791:value1791}
# name1792_sketch, description1792, {key1792:value1792}
# name1793_counter, description1793, {key1793:value1793}
# name1794_sketch, description1794, {key1794:value1794}
# name1795_exact, description1795, {key1795:value1795}
# name1796_histogram, description1796, {key1796:value1796}
# name1797_histogram, description1797, {key1797:value1797}
# name1798_sketch, description1798, {key1798:value1798}
# name1799_histogram, description1799, {key1799:value1799}
# name1800_histogram, description1800, {key1800:value1800}
# name1801_exact, description1801, {key1801:value1801}
# name1802_counter, description1802, {key1802:value1802}
# name1803_sketch, description1803, {key1803:value1803}
# name1804_histogram, description1804, {key1804:value1804}
# name1805_histogram, description1805, {key1805:value1805}
# name1806_histogram, description1806, {key1806:value1806}
# name1807_histogram, description1807, {key1807:value1807}
# name1808_sketch, description1808, {key1808:value1808}
# name1809_gauge, description1809, {key1809:value1809}
# name1810_sketch, description1810, {key1810:value1810}
# name1811_gauge, description1811, {key1811:value1811}
# name1812_counter, description1812, {key1812:value1812}
# name1813_sketch, description1813, {key1813:value1813}
# name1814_histogram, description1814, {key1814:value1814}
# name1815_gauge, description1815, {key1815:value1815}
# name1816_exact, description1816, {key1816:value1816}
# name1817_gauge, description1817, {key1817:value1817}
# name1818_exact, description1818, {key1818:value1818}
# name1819_gauge, description1819, {key1819:value1819}
# name1820_counter, description1820, {key1820:value1820}
# name1821_histogram, description1821, {key1821:value1821}
# name1822_counter, description1822, {key1822:value1822}
# name1823_gauge, description1823, {key1823:value1823}
# name1824_gauge, description1824, {key1824:value1824}
# name1825_histogram, description1825, {key1825:value1825}
# name1826_counter, description1826, {key1826:value1826}
# name1827_histogram, description1827, {key1827:value1827}
# name1828_exact, description1828, {key1828:value1828}
# name1829_counter, description1829, {key1829:value1829}
# name1830_exact, description1830, {key1830:value1830}
# name1831_counter, description1831, {key1831:value1831}
# name1832_gauge, description1832, {key1832:value1832}
# name1833_histogram, description1833, {key1833:value1833}
# name1834_exact, description1834, {key1834:value1834}
# name1835_counter, description1835, {key1835:value1835}
# name1836_gauge, description1836, {key1836:value1836}
# name1837_sketch, description1837, {key1837:value1837}
# name1838_counter, description1838, {key1838:value1838}
# name1839_counter, description1839, {key1839:value1839}
# name1840_counter, description1840, {key1840:value1840}
# name1841_counter, description1841, {key1841:value1841}
# name1842_exact, description1842, {key1842:value1842}
# name1843_sketch, description1843, {key1843:value1843}
# name1844_exact, description1844, {key1844:value1844}
# name1845_exact, description1845, {key1845:value1845}
# name1846_histogram, description1846, {key1846:value1846}
# name1847_histogram, description1847, {key1847:value1847}
# name1848_histogram, description1848, {key1848:value1848}
# name1849_gauge, description1849, {key1849:value1849}
# name1850_gauge, description1850, {key1850:value1850}
# name1851_histogram, description1851, {key1851:value1851}
# name1852_histogram, description1852, {key1852:value1852}
# name1853_gauge, description1853, {key1853:value1853}
# name1854_sketch, description1854, {key1854:value1854}
# name1855_exact, description1855, {key1855:value1855}
# name1856_sketch, description1856, {key1856:value1856}
# name1857_gauge, description1857, {key1857:value1857}
# name1858_gauge, description1858, {key1858:value1858}
# name1859_sketch, description1859, {key1859:value1859}
# name1860_gauge, description1860, {key1860:value1860}
# name1861_sketch, description1861, {key1861:value1861}
# name1862_sketch, description1862, {key1862:value1862}
# name1863_sketch, description1863, {key1863:value1863}
# name1864_exact, description1864, {key1864:value1864}
# name1865_counter, description1865, {key1865:value1865}
# name1866_gauge, description1866, {key1866:value1866}
# name1867_counter, description1867, {key1867:value1867}
# name1868_counter, description1868, {key1868:value1868}
# name1869_gauge, description1869, {key1869:value1869}
# name1870_gauge, description1870, {key1870:value1870}
# name1871_sketch, description1871, {key1871:value1871}
# name1872_counter, description1872, {key1872:value1872}
# name1873_histogram, description1873, {key1873:value1873}
# name1874_sketch, description1874, {key1874:value1874}
# name1875_histogram, description1875, {key1875:value1875}
# name1876_counter, description1876, {key1876:value1876}
# name1877_counter, description1877, {key1877:value1877}
# name1878_counter, description1878, {key1878:value1878}
# name1879_gauge, description1879, {key1879:value1879}
# name1880_histogram, description1880, {key1880:value1880}
# name1881_exact, description1881, {key1881:value1881}
# name1882_histogram, description1882, {key1882:value1882}
# name1883_counter, description1883, {key1883:value1883}
# name1884_sketch, description1884, {key1884:value1884}
# name1885_sketch, description1885, {key1885:value1885}
# name1886_gauge, description1886, {key1886:value1886}
# name1887_gauge, description1887, {key1887:value1887}
# name1888_sketch, description1888, {key1888:value1888}
# name1889_sketch, description1889, {key1889:value1889}
# name1890_histogram, description1890, {key1890:value1890}
# name1891_sketch, description1891, {key1891:value1891}
# name1892_histogram, description1892, {key1892:value1892}
# name1893_histogram, description1893, {key1893:value1893}
# name1894_exact, description1894, {key1894:value1894}
# name1895_gauge, description1895, {key1895:value1895}
# name1896_sketch, description1896, {key1896:value1896}
# name1897_histogram, description1897, {key1897:value1897}
# name1898_histogram, description1898, {key1898:value1898}
# name1899_exact, description1899, {key1899:value1899}
# name1900_histogram, description1900, {key1900:value1900}
# name1901_exact, description1901, {key1901:value1901}
# name1902_sketch, description1902, {key1902:value1902}
# name1903_exact, description1903, {key1903:value1903}
# name1904_counter, description1904, {key1904:value1904}
# name1905_histogram, description1905, {key1905:value1905}
# name1906_sketch, description1906, {key1906:value1906}
# name1907_gauge, description1907, {key1907:value1907}
# name1908_counter, description1908, {key1908:value1908}
# name1909_gauge, description1909, {key1909:value1909}
# name1910_counter, description1910, {key1910:value1910}
# name1911_gauge, description1911, {key1911:value1911}
# name1912_counter, description1912, {key1912:value1912}
# name1913_counter, description1913, {key1913:value1913}
# name1914_gauge, description1914, {key1914:value1914}
# name1915_counter, description1915, {key1915:value1915}
# name1916_counter, description1916, {key1916:value1916}
# name1917_sketch, description1917, {key1917:value1917}
# name1918_gauge, description1918, {key1918:value1918}
# name1919_gauge, description1919, {key1919:value1919}
# name1920_sketch, description1920, {key1920:value1920}
# name1921_gauge, description1921, {key1921:value1921}
# name1922_counter, description1922, {key1922:value1922}
# name1923_gauge, description1923, {key1923:value1923}
# name1924_exact, description1924, {key1924:value1924}
# name1925_histogram, description1925, {key1925:value1925}
# name1926_gauge, description1926, {key1926:value1926}
# name1927_histogram, description1927, {key1927:value1927}
# name1928_counter, description1928, {key1928:value1928}
# name1929_histogram, description1929, {key1929:value1929}
# name1930_histogram, description1930, {key1930:value1930}
# name1931_sketch, description1931, {key1931:value1931}
# name1932_sketch, description1932, {key1932:value1932}
# name1933_sketch, description1933, {key1933:value1933}
# name1934_histogram, description1934, {key1934:value1934}
# name1935_sketch, description1935, {key1935:value1935}
# name1936_histogram, description1936, {key1936:value1936}
# name1937_sketch, description1937, {key1937:value1937}
# name1938_sketch, description1938, {key1938:value1938}
# name1939_sketch, description1939, {key1939:value1939}
# name1940_gauge, description1940, {key1940:value1940}
# name1941_exact, description1941, {key1941:value1941}
# name1942_counter, description1942, {key1942:value1942}
# name1943_sketch, description1943, {key1943:value1943}
# name1944_histogram, description1944, {key1944:value1944}
# name1945_sketch, description1945, {key1945:value1945}
# name1946_gauge, description1946, {key1946:value1946}
# name1947_counter, description1947, {key1947:value1947}
# name1948_gauge, description1948, {key1948:value1948}
# name1949_counter, description1949, {key1949:value1949}
# name1950_histogram, description1950, {key1950:value1950}
# name1951_histogram, description1951, {key1951:value1951}
# name1952_sketch, description1952, {key1952:value1952}
# name1953_counter, description1953, {key1953:value1953}
# name1954_sketch, description1954, {key1954:value1954}
# name1955_gauge, description1955, {key1955:value1955}
# name1956_exact, description1956, {key1956:value1956}
# name1957_sketch, description1957, {key1957:value1957}
# name1958_counter, description1958, {key1958:value1958}
# name1959_gauge, description1959, {key1959:value1959}
# name1960_counter, description1960, {key1960:value1960}
# name1961_sketch, description1961, {key1961:value1961}
# name1962_counter, description1962, {key1962:value1962}
# name1963_exact, description1963, {key1963:value1963}
# name1964_counter, description1964, {key1964:value1964}
# name1965_gauge, description1965, {key1965:value1965}
# name1966_exact, description1966, {key1966:value1966}
# name1967_counter, description1967, {key1967:value1967}
# name1968_gauge, description1968, {key1968:value1968}
# name1969_sketch, description1969, {key1969:value1969}
# name1970_gauge, description1970, {key1970:value1970}
# name1971_sketch, description1971, {key1971:value1971}
# name1972_counter, description1972, {key1972:value1972}
# name1973_counter, description1973, {key1973:value1973}
# name1974_histogram, description1974, {key1974:value1974}
# name1975_sketch, description1975, {key1975:value1975}
# name1976_counter, description1976, {key1976:value1976}
# name1977_gauge, description1977, {key1977:value1977}
# name1978_sketch, description1978, {key1978:value1978}
# name1979_sketch, description1979, {key1979:value1979}
# name1980_histogram, description1980, {key1980:value1980}
# name1981_gauge, description1981, {key1981:value1981}
# name1982_exact, description1982, {key1982:value1982}
# name1983_histogram, description1983, {key1983:value1983}
# name1984_gauge, description1984, {key1984:value1984}
# name1985_gauge, description1985, {key1985:value1985}
# name1986_counter, description1986, {key1986:value1986}
# name1987_histogram, description1987, {key1987:value1987}
# name1988_gauge, description1988, {key1988:value1988}
# name1989_gauge, description1989, {key1989:value1989}
# name1990_histogram, description1990, {key1990:value1990}
# name1991_histogram, description1991, {key1991:value1991}
# name1992_sketch, description1992, {key1992:value1992}
# name1993_exact, description1993, {key1993:value1993}
# name1994_gauge, description1994, {key1994:value1994}
# name1995_histogram, description1995, {key1995:value1995}
# name1996_histogram, description1996, {key1996:value1996}
# name1997_counter, description1997, {key1997:value1997}
# name1998_histogram, description1998, {key1998:value1998}
# name1999_counter, description1999, {key1999:value1999}
# name2000_counter, description2000, {key2000:value2000}
# name2001_exact, description2001, {key2001:value2001}
# name2002_counter, description2002, {key2002:value2002}
# name2003_counter, description2003, {key2003:value2003}
# name2004_exact, description2004, {key2004:value2004}
# name2005_sketch, description2005, {key2005:value2005}
# name2006_histogram, description2006, {key2006:value2006}
# name2007_counter, description2007, {key2007:value2007}
# name2008_exact, description2008, {key2008:value2008}
# name2009_exact, description2009, {key2009:value2009}
# name2010_gauge, description2010, {key2010:value2010}
# name2011_sketch, description2011, {key2011:value2011}
# name2012_histogram, description2012, {key2012:value2012}
# name2013_histogram, description2013, {key2013:value2013}
# name2014_histogram, description2014, {key2014:value2014}
# name2015_sketch, description2015, {key2015:value2015}
# name2016_histogram, description2016, {key2016:value2016}
# name2017_exact, description2017, {key2017:value2017}
# name2018_gauge, description2018, {key2018:value2018}
# name2019_counter, description2019, {key2019:value2019}
# name2020_counter, description2020, {key2020:value2020}
# name2021_histogram, description2021, {key2021:value2021}
# name2022_gauge, description2022, {key2022:value2022}
# name2023_exact, description2023, {key2023:value2023}
# name2024_histogram, description2024, {key2024:value2024}
# name2025_sketch, description2025, {key2025:value2025}
# name2026_histogram, description2026, {key2026:value2026}
# name2027_counter, description2027, {key2027:value2027}
# name2028_counter, description2028, {key2028:value2028}
# name2029_histogram, description2029, {key2029:value2029}
# name2030_histogram, description2030, {key2030:value2030}
# name2031_sketch, description2031, {key2031:value2031}
# name2032_counter, description2032, {key2032:value2032}
# name2033_counter, description2033, {key2033:value2033}
# name2034_counter, description2034, {key2034:value2034}
# name2035_histogram, description2035, {key2035:value2035}
# name2036_gauge, description2036, {key2036:value2036}
# name2037_gauge, description2037, {key2037:value2037}
# name2038_sketch, description2038, {key2038:value2038}
# name2039_histogram, description2039, {key2039:value2039}
# name2040_histogram, description2040, {key2040:value2040}
# name2041_gauge, description2041, {key2041:value2041}
# name2042_gauge, description2042, {key2042:value2042}
# name2043_sketch, description2043, {key2043:value2043}
# name2044_histogram, description2044, {key2044:value2044}
# name2045_sketch, description2045, {key2045:value2045}
# name2046_gauge, description2046, {key2046:value2046}
# name2047_gauge, description2047, {key2047:value2047}

# %%
import math

fa = open("PrometheusAnswersSecond.csv", "w")

for record in records:
    agg = record[0]    
    
    # record = (agg, ndl, val)
    if (agg == "counter" or agg == "gauge"):
        fa.write(agg + '|' + str(record[2]) + '|' + record[1] + '\n')
#         print("{}|{}|{}".format(agg, str(record[2]), record[1]))
        
    
    # record = (agg, ndl, update_values, quantiles)
    elif (agg == "sketch" or agg == "exact"):
        s = sum(record[2])
        c = len(record[2])
        quantile_values = []
        
        for quantile in record[3]:
            pos = (len(record[2])-1) * quantile
            ceiling = math.ceil(pos)
            quantile_values.append(record[2][ceiling])
        
        quantile_pairs = "[(" + str(record[3][0]) + "," + str(quantile_values[0]) + ")"
        for q, v in zip(record[3][1:], quantile_values[1:]):
            quantile_pairs = quantile_pairs + ",(" + str(q) + "," + str(v) + ")"
        quantile_pairs += "]"
        
        fa.write("summary|" + str(s) + "|" + str(c) + "|" + quantile_pairs + "|" + record[1] + '\n')
#         print("summary|{}|{}|{}|{}".format(s, c, quantile_pairs, record[1]))


    #record = (agg, ndl, update_values, boundaries)
    elif (agg == "histogram"):
        s = sum(record[2])
        c = len(record[2])
        
        
        # buckets is a dict of that correspond to pairs of (buckets, bucket_count)
        buckets = defaultdict(int)
        
        update_values_sorted = sorted(record[2])
        curr_boundary = -1
        values_within_bound = 0
        for boundary in record[3]:
            if(values_within_bound != len(update_values_sorted)):
                for v in update_values_sorted:
                    if v < boundary and v > curr_boundary:
                        buckets[str(boundary)] += 1
                        values_within_bound += 1
                    elif v < boundary and v <= curr_boundary:
                        continue
                    else:
                        curr_boundary = boundary
                        break
        if(len(update_values_sorted) - values_within_bound != 0):
            buckets["inf"] += len(update_values_sorted) - values_within_bound

        buckets_str = "["
        for k, v in buckets.items():
            buckets_str = buckets_str + "(" + k + "," + str(v) + "),"
        buckets_str += "]"
        
        # extra comma will be present at the end of bucket_str; no functional impact
        fa.write("histogram|" + str(s) + "|" + str(c) + "|" + buckets_str + "|" + record[1] + '\n')
#         print("histogram|{}|{}|{}|{}".format(s, c, buckets_str, record[1]))
            
fa.close()
