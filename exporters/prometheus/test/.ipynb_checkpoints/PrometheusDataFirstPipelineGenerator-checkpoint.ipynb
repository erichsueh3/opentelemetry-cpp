# %%
import random
from collections import defaultdict

# %%
names = ["name1", "name2", "name3", "name4", "name5"]
descr = ["descr1", "descr2", "descr3", "descr4"]
labels = ["key1, value1", "key2, value2", "key3, value3", "key4, value4"]
instruments = ["ictr", "iudctr","ivrec","isobs","iudobs","ivobs","fctr", "fudctr","fvrec","fsobs","fudobs","fvobs","dctr", "dudctr","dvrec","dsobs","dudobs","dvobs","sctr", "sudctr","svrec","ssobs","sudobs","svobs"]

answers = defaultdict(lambda: defaultdict(lambda: [0,0,0,0]))

# %%
f = open("PrometheusDataFirst.csv", "w")

for _ in range(100000):
    instr = random.choice(instruments)
    val = random.randint(-50,50)
    if (instr == "ictr" or instr == "isobs" or instr == "sctr" or instr == "ssobs" or instr == "dctr" or instr == "dsobs" or instr == "fctr" or instr == "fsobs"):
        val = abs(val)

   # TODO: might not need names + descriptions, will circle back after making load generator
    nam = names[random.randint(0, 3)]
    des = descr[random.randint(0, 3)]
    lab = random.sample(labels,random.randint(1,4))
    ndl = str(nam) + ", " + str(des) + ", " + str(lab)
    ndl = ndl.replace("[","").replace("]","").replace("'","")
    ndl_srt = str(nam) + ", " + str(des) + ", " + str(sorted(lab))
    ndl_srt = ndl_srt.replace("[","").replace("]","").replace("'","")
    
#     print(ndl)
#     print(ndl_srt)
    
    # mmsc aggregations
    if (instr == "ivrec" or instr == "ivobs" or instr == "svrec" or instr == "svobs" or instr == "dvrec" or instr == "dvobs" or instr == "fvrec" or instr == "fvobs"):
        answers[instr][ndl_srt][0] = val if val < answers[instr][ndl_srt][0] else answers[instr][ndl_srt][0]
        answers[instr][ndl_srt][1] = val if val > answers[instr][ndl_srt][1] else answers[instr][ndl_srt][1]
        answers[instr][ndl_srt][2] += val
        answers[instr][ndl_srt][3] += 1
    
    # counter aggregations
    else:
        answers[instr][ndl_srt][0] += val
        answers[instr][ndl_srt][1] += 1
#     print("{:<6}  {:>6}  {:}".format(instr,val,ndl_srt))
    f.write(instr+','+str(val)+','+"\""+ndl+"\"\n")
    
f.close()

# %%
fa = open("PrometheusAnswersFirst.csv", "w")

for instr in answers:
    for ndl in answers[instr]:
        # these instruments map to a MinMaxSumCount Aggregator in OTel, which map to a Gauge in Prometheus
        # the average value, sum/count, is used as the "last" value a Gauge in Prometheus keeps track of
        if (instr == "ivrec" or instr == "ivobs" or instr == "svrec" or instr == "svobs" or instr == "dvrec" or instr == "dvobs" or instr == "fvrec" or instr == "fvobs"):
            avg = answers[instr][ndl][2]/answers[instr][ndl][3]
            print("gauge {:<30}  {:}".format(str(avg),ndl))
            fa.write('gauge '+str(avg)+' '+ndl+'\n')
        # these instruments map to a Counter Aggregator in OTel, which map to a Counter in Prometheus
        # the sum is tracked by the Prometheus Counter so we validate only the sum, not count of updates, here
        else:
            print("ctr   {:<30}  {:}".format(str(answers[instr][ndl][0]),ndl))
            fa.write('ctr   '+str(answers[instr][ndl][0])+' '+ndl+'\n')
            
fa.close()
# Out:
# ctr   382                             name3, descr2, key1, value1, key4, value4
# ctr   369                             name4, descr2, key2, value2
# ctr   451                             name1, descr1, key1, value1, key3, value3, key4, value4
# ctr   385                             name3, descr3, key1, value1
# ctr   471                             name3, descr4, key2, value2, key3, value3
# ctr   556                             name1, descr4, key1, value1, key2, value2, key4, value4
# ctr   400                             name1, descr2, key1, value1, key3, value3, key4, value4
# ctr   492                             name1, descr1, key1, value1, key2, value2, key4, value4
# ctr   289                             name1, descr4, key2, value2, key3, value3, key4, value4
# ctr   552                             name1, descr3, key3, value3
# ctr   411                             name2, descr2, key1, value1, key4, value4
# ctr   2244                            name4, descr2, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   412                             name2, descr1, key2, value2, key4, value4
# ctr   1753                            name4, descr4, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   392                             name1, descr1, key3, value3, key4, value4
# ctr   462                             name3, descr2, key1, value1, key2, value2
# ctr   613                             name2, descr1, key1, value1, key3, value3, key4, value4
# ctr   1449                            name4, descr3, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   354                             name3, descr1, key2, value2, key3, value3
# ctr   448                             name2, descr2, key1, value1, key2, value2, key3, value3
# ctr   326                             name1, descr1, key2, value2
# ctr   579                             name4, descr1, key1, value1
# ctr   470                             name4, descr1, key2, value2, key3, value3, key4, value4
# ctr   272                             name2, descr4, key1, value1, key3, value3
# ctr   361                             name3, descr4, key2, value2, key3, value3, key4, value4
# ctr   346                             name2, descr2, key1, value1
# ctr   2131                            name1, descr3, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   346                             name3, descr3, key1, value1, key2, value2
# ctr   1650                            name3, descr4, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   410                             name2, descr3, key4, value4
# ctr   1545                            name3, descr3, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   1457                            name1, descr4, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   391                             name2, descr4, key2, value2, key3, value3
# ctr   555                             name1, descr2, key3, value3
# ctr   204                             name2, descr2, key1, value1, key3, value3
# ctr   477                             name4, descr3, key2, value2, key3, value3, key4, value4
# ctr   341                             name4, descr4, key1, value1, key2, value2, key4, value4
# ctr   239                             name1, descr3, key2, value2, key3, value3
# ctr   360                             name3, descr2, key1, value1, key3, value3
# ctr   477                             name1, descr4, key2, value2
# ctr   154                             name3, descr4, key3, value3, key4, value4
# ctr   273                             name4, descr4, key2, value2
# ctr   373                             name4, descr2, key1, value1, key2, value2, key3, value3
# ctr   271                             name4, descr4, key1, value1, key4, value4
# ctr   289                             name4, descr3, key1, value1, key3, value3
# ctr   282                             name1, descr2, key2, value2, key4, value4
# ctr   433                             name1, descr2, key2, value2
# ctr   183                             name1, descr3, key2, value2, key4, value4
# ctr   414                             name4, descr2, key2, value2, key3, value3, key4, value4
# ctr   405                             name3, descr2, key1, value1, key2, value2, key3, value3
# ctr   1562                            name3, descr1, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   181                             name3, descr1, key1, value1, key4, value4
# ctr   301                             name3, descr1, key2, value2, key3, value3, key4, value4
# ctr   465                             name2, descr2, key2, value2, key3, value3, key4, value4
# ctr   1725                            name3, descr2, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   379                             name4, descr1, key1, value1, key4, value4
# ctr   1459                            name2, descr1, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   387                             name1, descr4, key1, value1
# ctr   508                             name3, descr4, key3, value3
# ctr   474                             name4, descr3, key4, value4
# ctr   454                             name2, descr3, key1, value1, key2, value2, key4, value4
# ctr   461                             name1, descr2, key1, value1, key2, value2, key3, value3
# ctr   612                             name4, descr2, key4, value4
# ctr   475                             name4, descr1, key4, value4
# ctr   165                             name2, descr1, key1, value1
# ctr   513                             name2, descr1, key1, value1, key2, value2, key4, value4
# ctr   545                             name2, descr2, key1, value1, key2, value2, key4, value4
# ctr   480                             name2, descr1, key2, value2, key3, value3, key4, value4
# ctr   269                             name4, descr3, key3, value3, key4, value4
# ctr   497                             name4, descr1, key2, value2
# ctr   458                             name2, descr3, key3, value3, key4, value4
# ctr   401                             name3, descr4, key2, value2, key4, value4
# ctr   237                             name4, descr1, key2, value2, key4, value4
# ctr   2268                            name1, descr1, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   350                             name1, descr4, key1, value1, key4, value4
# ctr   576                             name3, descr3, key4, value4
# ctr   187                             name4, descr4, key1, value1, key2, value2
# ctr   284                             name1, descr4, key3, value3
# ctr   337                             name4, descr4, key2, value2, key3, value3, key4, value4
# ctr   345                             name2, descr3, key1, value1, key3, value3, key4, value4
# ctr   433                             name4, descr1, key1, value1, key2, value2, key4, value4
# ctr   307                             name3, descr2, key2, value2
# ctr   153                             name1, descr2, key1, value1, key2, value2
# ctr   259                             name3, descr1, key1, value1, key3, value3
# ctr   494                             name4, descr3, key1, value1, key2, value2, key3, value3
# ctr   330                             name2, descr4, key2, value2, key4, value4
# ctr   362                             name1, descr3, key1, value1, key3, value3, key4, value4
# ctr   467                             name2, descr1, key1, value1, key2, value2, key3, value3
# ctr   1985                            name1, descr2, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   382                             name3, descr4, key1, value1, key2, value2, key3, value3
# ctr   1122                            name2, descr2, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   310                             name2, descr3, key3, value3
# ctr   375                             name4, descr1, key1, value1, key2, value2, key3, value3
# ctr   430                             name2, descr2, key1, value1, key3, value3, key4, value4
# ctr   1504                            name4, descr1, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   397                             name1, descr1, key2, value2, key3, value3, key4, value4
# ctr   122                             name4, descr2, key3, value3, key4, value4
# ctr   368                             name1, descr3, key2, value2, key3, value3, key4, value4
# ctr   206                             name3, descr3, key3, value3, key4, value4
# ctr   859                             name4, descr1, key1, value1, key3, value3, key4, value4
# ctr   510                             name2, descr3, key1, value1, key2, value2, key3, value3
# ctr   392                             name4, descr3, key1, value1, key2, value2
# ctr   1767                            name2, descr3, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   450                             name3, descr3, key1, value1, key2, value2, key4, value4
# ctr   344                             name4, descr4, key1, value1, key2, value2, key3, value3
# ctr   431                             name3, descr3, key1, value1, key3, value3, key4, value4
# ctr   276                             name1, descr1, key2, value2, key3, value3
# ctr   208                             name4, descr4, key2, value2, key4, value4
# ctr   577                             name4, descr2, key3, value3
# ctr   703                             name2, descr4, key4, value4
# ctr   511                             name1, descr1, key1, value1
# ctr   360                             name1, descr1, key1, value1, key2, value2, key3, value3
# ctr   1406                            name2, descr4, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   223                             name3, descr1, key2, value2, key4, value4
# ctr   401                             name3, descr4, key1, value1
# ctr   434                             name3, descr3, key2, value2
# ctr   400                             name4, descr2, key1, value1, key2, value2, key4, value4
# ctr   481                             name1, descr3, key2, value2
# ctr   492                             name3, descr1, key4, value4
# ctr   627                             name3, descr3, key3, value3
# ctr   524                             name2, descr1, key4, value4
# ctr   307                             name4, descr2, key2, value2, key3, value3
# ctr   306                             name3, descr3, key1, value1, key2, value2, key3, value3
# ctr   374                             name4, descr1, key1, value1, key2, value2
# ctr   449                             name4, descr4, key1, value1
# ctr   519                             name2, descr4, key2, value2, key3, value3, key4, value4
# ctr   249                             name3, descr3, key2, value2, key4, value4
# ctr   297                             name4, descr2, key1, value1
# ctr   395                             name2, descr3, key1, value1, key3, value3
# ctr   210                             name1, descr1, key1, value1, key4, value4
# ctr   563                             name3, descr4, key1, value1, key3, value3, key4, value4
# ctr   379                             name2, descr3, key2, value2
# ctr   304                             name3, descr3, key1, value1, key4, value4
# ctr   345                             name3, descr2, key3, value3
# ctr   417                             name4, descr3, key2, value2
# ctr   299                             name1, descr4, key2, value2, key4, value4
# ctr   548                             name3, descr2, key2, value2, key3, value3, key4, value4
# ctr   176                             name4, descr1, key1, value1, key3, value3
# ctr   138                             name4, descr1, key3, value3, key4, value4
# ctr   234                             name4, descr2, key1, value1, key4, value4
# ctr   380                             name1, descr1, key4, value4
# ctr   315                             name3, descr3, key2, value2, key3, value3, key4, value4
# ctr   399                             name3, descr1, key3, value3
# ctr   300                             name4, descr4, key2, value2, key3, value3
# ctr   261                             name1, descr2, key1, value1
# ctr   363                             name1, descr4, key1, value1, key2, value2
# ctr   277                             name2, descr4, key1, value1, key2, value2, key4, value4
# ctr   570                             name3, descr4, key4, value4
# ctr   418                             name4, descr2, key1, value1, key3, value3, key4, value4
# ctr   299                             name2, descr4, key1, value1, key2, value2, key3, value3
# ctr   256                             name3, descr2, key3, value3, key4, value4
# ctr   254                             name4, descr3, key1, value1
# ctr   365                             name2, descr1, key1, value1, key3, value3
# ctr   423                             name4, descr3, key3, value3
# ctr   231                             name3, descr2, key2, value2, key4, value4
# ctr   278                             name1, descr2, key1, value1, key4, value4
# ctr   282                             name3, descr4, key1, value1, key2, value2, key4, value4
# ctr   250                             name2, descr2, key2, value2, key3, value3
# ctr   210                             name4, descr2, key1, value1, key2, value2
# ctr   236                             name1, descr4, key1, value1, key3, value3
# ctr   239                             name1, descr2, key1, value1, key3, value3
# ctr   438                             name3, descr4, key1, value1, key2, value2
# ctr   589                             name2, descr4, key3, value3
# ctr   303                             name3, descr1, key3, value3, key4, value4
# ctr   327                             name4, descr1, key3, value3
# ctr   253                             name2, descr1, key2, value2
# ctr   170                             name2, descr1, key3, value3, key4, value4
# ctr   521                             name4, descr4, key4, value4
# ctr   488                             name3, descr1, key1, value1, key2, value2, key3, value3
# ctr   380                             name1, descr4, key1, value1, key2, value2, key3, value3
# ctr   275                             name2, descr4, key1, value1
# ctr   654                             name3, descr2, key1, value1, key2, value2, key4, value4
# ctr   334                             name1, descr3, key1, value1, key2, value2, key3, value3
# ctr   331                             name3, descr1, key2, value2
# ctr   400                             name2, descr3, key1, value1
# ctr   174                             name2, descr4, key1, value1, key4, value4
# ctr   312                             name3, descr4, key2, value2
# ctr   436                             name4, descr3, key1, value1, key4, value4
# ctr   221                             name2, descr2, key2, value2, key4, value4
# ctr   370                             name1, descr2, key4, value4
# ctr   492                             name4, descr3, key1, value1, key3, value3, key4, value4
# ctr   378                             name1, descr3, key1, value1
# ctr   313                             name1, descr4, key1, value1, key3, value3, key4, value4
# ctr   331                             name1, descr3, key3, value3, key4, value4
# ctr   198                             name3, descr1, key1, value1, key3, value3, key4, value4
# ctr   449                             name2, descr1, key3, value3
# ctr   359                             name1, descr3, key1, value1, key2, value2, key4, value4
# ctr   359                             name1, descr2, key3, value3, key4, value4
# ctr   381                             name3, descr3, key1, value1, key3, value3
# ctr   412                             name1, descr1, key3, value3
# ctr   510                             name2, descr2, key4, value4
# ctr   219                             name1, descr2, key1, value1, key2, value2, key4, value4
# ctr   370                             name4, descr3, key1, value1, key2, value2, key4, value4
# ctr   366                             name2, descr1, key2, value2, key3, value3
# ctr   439                             name2, descr2, key3, value3
# ctr   277                             name2, descr3, key1, value1, key4, value4
# ctr   295                             name3, descr4, key1, value1, key3, value3
# ctr   400                             name2, descr4, key3, value3, key4, value4
# ctr   298                             name3, descr2, key1, value1
# ctr   251                             name3, descr2, key4, value4
# ctr   354                             name1, descr4, key3, value3, key4, value4
# ctr   290                             name1, descr3, key1, value1, key2, value2
# ctr   312                             name2, descr3, key2, value2, key3, value3, key4, value4
# ctr   408                             name1, descr3, key4, value4
# ctr   301                             name3, descr1, key1, value1, key2, value2
# ctr   193                             name2, descr2, key1, value1, key2, value2
# ctr   238                             name4, descr1, key2, value2, key3, value3
# ctr   195                             name1, descr4, key2, value2, key3, value3
# ctr   208                             name2, descr3, key2, value2, key4, value4
# ctr   321                             name2, descr4, key1, value1, key2, value2
# ctr   401                             name3, descr1, key1, value1, key2, value2, key4, value4
# ctr   323                             name2, descr1, key1, value1, key2, value2
# ctr   378                             name2, descr3, key2, value2, key3, value3
# ctr   281                             name4, descr4, key3, value3, key4, value4
# ctr   515                             name4, descr4, key3, value3
# ctr   341                             name3, descr1, key1, value1
# ctr   373                             name3, descr4, key1, value1, key4, value4
# ctr   183                             name4, descr2, key1, value1, key3, value3
# ctr   374                             name1, descr1, key2, value2, key4, value4
# ctr   301                             name2, descr4, key2, value2
# ctr   372                             name4, descr4, key1, value1, key3, value3
# ctr   338                             name4, descr2, key2, value2, key4, value4
# ctr   324                             name1, descr3, key1, value1, key4, value4
# ctr   310                             name1, descr1, key1, value1, key2, value2
# ctr   327                             name1, descr3, key1, value1, key3, value3
# ctr   382                             name1, descr4, key4, value4
# ctr   328                             name2, descr4, key1, value1, key3, value3, key4, value4
# ctr   288                             name4, descr3, key2, value2, key4, value4
# ctr   147                             name1, descr1, key1, value1, key3, value3
# ctr   465                             name2, descr2, key2, value2
# ctr   209                             name4, descr4, key1, value1, key3, value3, key4, value4
# ctr   235                             name2, descr2, key3, value3, key4, value4
# ctr   194                             name4, descr3, key2, value2, key3, value3
# ctr   177                             name2, descr1, key1, value1, key4, value4
# ctr   326                             name3, descr2, key1, value1, key3, value3, key4, value4
# ctr   249                             name2, descr3, key1, value1, key2, value2
# ctr   305                             name1, descr2, key2, value2, key3, value3, key4, value4
# ctr   201                             name3, descr2, key2, value2, key3, value3
# ctr   45                              name1, descr2, key2, value2, key3, value3
# ctr   129                             name3, descr3, key2, value2, key3, value3
# gauge -5.733333333333333              name3, descr4, key1, value1, key2, value2, key4, value4
# gauge 6.076923076923077               name2, descr1, key3, value3, key4, value4
# gauge -5.8                            name2, descr1, key1, value1, key3, value3, key4, value4
# gauge 0.5                             name3, descr4, key1, value1, key2, value2
# gauge -6.278688524590164              name2, descr3, key1, value1, key2, value2, key3, value3, key4, value4
# gauge -11.142857142857142             name2, descr3, key2, value2, key3, value3, key4, value4
# gauge 2.0952380952380953              name1, descr2, key1, value1, key2, value2, key3, value3
# gauge 1.9795918367346939              name4, descr2, key1, value1, key2, value2, key3, value3, key4, value4
# gauge -0.9090909090909091             name4, descr4, key3, value3
# gauge 0.5                             name2, descr1, key1, value1
# gauge -4.6                            name2, descr1, key1, value1, key3, value3
# gauge 3.4166666666666665              name2, descr2, key1, value1, key4, value4
# gauge -3.466666666666667              name1, descr4, key2, value2
# gauge 2.75                            name4, descr2, key1, value1, key4, value4
# gauge 2.927536231884058               name3, descr3, key1, value1, key2, value2, key3, value3, key4, value4
# gauge -8.628571428571428              name4, descr4, key1, value1, key2, value2, key3, value3, key4, value4
# gauge -1.4848484848484849             name3, descr1, key1, value1, key2, value2, key3, value3, key4, value4
# gauge 12.545454545454545              name3, descr4, key2, value2, key3, value3
# gauge -2.4285714285714284             name4, descr2, key1, value1, key2, value2
# gauge -0.5                            name3, descr2, key1, value1, key2, value2, key3, value3, key4, value4
# gauge -1.4210526315789473             name4, descr4, key1, value1, key3, value3
# gauge -10.545454545454545             name1, descr4, key2, value2, key4, value4
# gauge 2.823529411764706               name2, descr2, key1, value1, key2, value2, key4, value4
# gauge 0.75                            name3, descr2, key2, value2, key3, value3, key4, value4
# gauge -3.111111111111111              name3, descr3, key1, value1, key2, value2, key3, value3
# gauge 4.833333333333333               name4, descr2, key1, value1
# gauge 10.666666666666666              name2, descr3, key4, value4
# gauge 3.1578947368421053              name1, descr2, key1, value1
# gauge 2.76                            name3, descr3, key4, value4
# gauge 4.947368421052632               name4, descr3, key1, value1, key2, value2, key4, value4
# gauge 7.363636363636363               name2, descr3, key1, value1
# gauge -5.421052631578948              name2, descr2, key1, value1, key2, value2, key3, value3
# gauge 5.125                           name3, descr2, key1, value1, key3, value3
# gauge 3.4761904761904763              name2, descr4, key3, value3
# gauge -10.153846153846153             name1, descr1, key1, value1, key2, value2
# gauge 2.5555555555555554              name2, descr1, key2, value2, key3, value3, key4, value4
# gauge 8.052631578947368               name3, descr2, key2, value2
# gauge 2.3846153846153846              name2, descr2, key2, value2, key3, value3, key4, value4
# gauge -5.32                           name4, descr1, key1, value1, key2, value2, key3, value3, key4, value4
# gauge 6.066666666666666               name4, descr2, key2, value2, key3, value3, key4, value4
# gauge -10.368421052631579             name3, descr4, key3, value3, key4, value4
# gauge 6.090909090909091               name1, descr3, key4, value4
# gauge -1.5662650602409638             name1, descr3, key1, value1, key2, value2, key3, value3, key4, value4
# gauge -1.75                           name2, descr4, key1, value1, key2, value2
# gauge -6.75                           name2, descr1, key2, value2, key3, value3
# gauge -11.1875                        name4, descr2, key4, value4
# gauge 15.846153846153847              name4, descr4, key3, value3, key4, value4
# gauge -2.9444444444444446             name4, descr4, key1, value1, key3, value3, key4, value4
# gauge 6.818181818181818               name1, descr4, key1, value1, key2, value2, key4, value4
# gauge -2.402439024390244              name1, descr2, key1, value1, key2, value2, key3, value3, key4, value4
# gauge -0.625                          name2, descr2, key3, value3
# gauge -12.235294117647058             name3, descr1, key1, value1, key2, value2, key3, value3
# gauge -16.166666666666668             name4, descr1, key3, value3
# gauge 5.042857142857143               name1, descr1, key1, value1, key2, value2, key3, value3, key4, value4
# gauge -4.583333333333333              name4, descr2, key2, value2, key4, value4
# gauge 5.571428571428571               name2, descr1, key2, value2, key4, value4
# gauge 1.65                            name1, descr4, key3, value3
# gauge 5.454545454545454               name1, descr4, key1, value1, key3, value3, key4, value4
# gauge -1.0                            name2, descr4, key2, value2, key3, value3, key4, value4
# gauge -0.8823529411764706             name2, descr1, key3, value3
# gauge 7.133333333333334               name1, descr1, key2, value2
# gauge -2.0                            name1, descr2, key1, value1, key4, value4
# gauge 10.4                            name4, descr2, key3, value3, key4, value4
# gauge 3.2                             name3, descr1, key1, value1, key3, value3, key4, value4
# gauge -5.571428571428571              name4, descr4, key2, value2, key4, value4
# gauge 5.526315789473684               name1, descr3, key1, value1, key3, value3, key4, value4
# gauge -0.28169014084507044            name2, descr4, key1, value1, key2, value2, key3, value3, key4, value4
# gauge 0.375                           name3, descr2, key3, value3
# gauge 4.904761904761905               name2, descr4, key1, value1, key2, value2, key4, value4
# gauge -2.235294117647059              name4, descr1, key1, value1, key4, value4
# gauge -4.818181818181818              name3, descr1, key4, value4
# gauge 10.846153846153847              name3, descr2, key1, value1, key2, value2, key4, value4
# gauge 6.833333333333333               name1, descr3, key1, value1, key2, value2, key4, value4
# gauge -1.8235294117647058             name3, descr1, key1, value1
# gauge -1.0714285714285714             name1, descr3, key1, value1, key2, value2, key3, value3
# gauge 11.625                          name2, descr1, key2, value2
# gauge -0.25                           name1, descr1, key1, value1, key3, value3, key4, value4
# gauge -5.3076923076923075             name3, descr2, key1, value1, key2, value2
# gauge 2.2698412698412698              name4, descr3, key1, value1, key2, value2, key3, value3, key4, value4
# gauge -8.117647058823529              name1, descr2, key1, value1, key3, value3, key4, value4
# gauge 2.0526315789473686              name2, descr4, key2, value2
# gauge 6.083333333333333               name3, descr3, key2, value2, key4, value4
# gauge -1.5                            name1, descr1, key1, value1, key2, value2, key4, value4
# gauge 2.6153846153846154              name1, descr4, key1, value1, key2, value2, key3, value3, key4, value4
# gauge -2.3333333333333335             name2, descr2, key1, value1
# gauge -4.8                            name1, descr4, key1, value1, key4, value4
# gauge 5.714285714285714               name4, descr2, key2, value2
# gauge -0.5909090909090909             name2, descr2, key4, value4
# gauge 4.190476190476191               name1, descr1, key2, value2, key3, value3, key4, value4
# gauge -3.3846153846153846             name3, descr3, key2, value2, key3, value3
# gauge 0.2903225806451613              name2, descr2, key1, value1, key2, value2, key3, value3, key4, value4
# gauge -2.125                          name4, descr3, key2, value2, key3, value3
# gauge 0.21212121212121213             name2, descr1, key1, value1, key2, value2, key3, value3, key4, value4
# gauge 0.7894736842105263              name4, descr4, key1, value1
# gauge -4.75                           name4, descr4, key2, value2, key3, value3, key4, value4
# gauge -1.3888888888888888             name1, descr4, key2, value2, key3, value3, key4, value4
# gauge 15.071428571428571              name2, descr4, key1, value1, key4, value4
# gauge -9.461538461538462              name1, descr2, key2, value2, key4, value4
# gauge 21.25                           name1, descr1, key3, value3, key4, value4
# gauge 2.0                             name4, descr2, key2, value2, key3, value3
# gauge -4.866666666666666              name3, descr1, key1, value1, key2, value2
# gauge 7.333333333333333               name4, descr4, key4, value4
# gauge 2.5555555555555554              name1, descr4, key3, value3, key4, value4
# gauge 9.333333333333334               name3, descr1, key3, value3, key4, value4
# gauge 7.238095238095238               name1, descr3, key1, value1
# gauge -7.733333333333333              name3, descr2, key4, value4
# gauge 3.0588235294117645              name2, descr4, key1, value1, key2, value2, key3, value3
# gauge 21.0                            name4, descr4, key2, value2
# gauge 0.29411764705882354             name4, descr2, key1, value1, key2, value2, key4, value4
# gauge 10.5                            name1, descr2, key4, value4
# gauge 7.357142857142857               name3, descr1, key3, value3
# gauge -18.5                           name2, descr2, key2, value2, key4, value4
# gauge -10.5625                        name1, descr4, key1, value1
# gauge -14.333333333333334             name4, descr3, key4, value4
# gauge -2.5238095238095237             name1, descr3, key3, value3
# gauge -14.0                           name2, descr1, key1, value1, key2, value2
# gauge -0.4126984126984127             name3, descr4, key1, value1, key2, value2, key3, value3, key4, value4
# gauge -3.619047619047619              name1, descr2, key2, value2
# gauge 7.181818181818182               name4, descr4, key1, value1, key2, value2, key4, value4
# gauge -3.7058823529411766             name1, descr2, key2, value2, key3, value3, key4, value4
# gauge -9.533333333333333              name2, descr1, key4, value4
# gauge -7.35                           name4, descr2, key1, value1, key2, value2, key3, value3
# gauge -4.454545454545454              name1, descr3, key2, value2, key4, value4
# gauge 4.0                             name3, descr1, key2, value2, key3, value3, key4, value4
# gauge 7.166666666666667               name1, descr3, key3, value3, key4, value4
# gauge -4.523809523809524              name1, descr2, key3, value3
# gauge -3.6666666666666665             name3, descr3, key1, value1, key3, value3
# gauge 3.380952380952381               name4, descr1, key1, value1, key2, value2, key4, value4
# gauge -2.5                            name2, descr2, key2, value2
# gauge -9.333333333333334              name1, descr4, key1, value1, key3, value3
# gauge 8.526315789473685               name1, descr1, key1, value1
# gauge -1.2307692307692308             name4, descr2, key3, value3
# gauge 1.05                            name3, descr4, key3, value3
# gauge -3.4545454545454546             name3, descr3, key1, value1, key2, value2, key4, value4
# gauge -14.058823529411764             name1, descr4, key4, value4
# gauge -13.777777777777779             name3, descr3, key2, value2, key3, value3, key4, value4
# gauge -11.4                           name2, descr1, key1, value1, key2, value2, key3, value3
# gauge 6.7272727272727275              name4, descr3, key1, value1, key4, value4
# gauge 5.277777777777778               name2, descr3, key2, value2, key3, value3
# gauge -0.35714285714285715            name3, descr2, key1, value1, key3, value3, key4, value4
# gauge 13.636363636363637              name4, descr1, key2, value2, key3, value3
# gauge 3.0625                          name1, descr3, key2, value2, key3, value3, key4, value4
# gauge -2.3                            name1, descr1, key1, value1, key4, value4
# gauge -8.357142857142858              name2, descr2, key1, value1, key3, value3, key4, value4
# gauge 4.285714285714286               name3, descr4, key1, value1, key3, value3, key4, value4
# gauge -6.944444444444445              name3, descr4, key1, value1
# gauge -17.0                           name2, descr2, key1, value1, key3, value3
# gauge 3.5454545454545454              name3, descr1, key1, value1, key2, value2, key4, value4
# gauge 0.9230769230769231              name1, descr2, key1, value1, key3, value3
# gauge -10.0                           name2, descr4, key4, value4
# gauge -0.7272727272727273             name4, descr3, key1, value1, key2, value2
# gauge -4.090909090909091              name1, descr1, key1, value1, key2, value2, key3, value3
# gauge 8.875                           name2, descr3, key1, value1, key4, value4
# gauge -1.375                          name3, descr4, key1, value1, key2, value2, key3, value3
# gauge 16.375                          name4, descr3, key2, value2, key4, value4
# gauge -4.7894736842105265             name3, descr3, key1, value1
# gauge -3.8125                         name4, descr1, key4, value4
# gauge -2.9166666666666665             name3, descr1, key2, value2, key4, value4
# gauge 6.25                            name3, descr2, key1, value1
# gauge -5.090909090909091              name3, descr2, key2, value2, key3, value3
# gauge 5.8                             name2, descr3, key1, value1, key2, value2, key4, value4
# gauge -15.277777777777779             name2, descr3, key1, value1, key2, value2, key3, value3
# gauge -8.3                            name3, descr1, key2, value2, key3, value3
# gauge 15.285714285714286              name4, descr4, key1, value1, key4, value4
# gauge 1.25                            name4, descr1, key1, value1, key3, value3
# gauge 2.727272727272727               name1, descr2, key1, value1, key2, value2
# gauge 3.823529411764706               name4, descr1, key1, value1, key3, value3, key4, value4
# gauge -2.3333333333333335             name3, descr1, key1, value1, key4, value4
# gauge -3.4545454545454546             name4, descr4, key2, value2, key3, value3
# gauge -4.25                           name1, descr3, key1, value1, key4, value4
# gauge -3.4444444444444446             name2, descr4, key2, value2, key4, value4
# gauge -6.0                            name3, descr4, key2, value2
# gauge -0.9285714285714286             name4, descr3, key1, value1, key3, value3, key4, value4
# gauge -4.4                            name2, descr1, key1, value1, key2, value2, key4, value4
# gauge 15.928571428571429              name2, descr3, key1, value1, key3, value3, key4, value4
# gauge 7.833333333333333               name4, descr3, key2, value2
# gauge -3.0588235294117645             name1, descr2, key1, value1, key2, value2, key4, value4
# gauge -8.181818181818182              name2, descr1, key1, value1, key4, value4
# gauge 4.571428571428571               name4, descr3, key1, value1
# gauge 1.0555555555555556              name1, descr4, key1, value1, key2, value2, key3, value3
# gauge 25.166666666666668              name1, descr1, key2, value2, key4, value4
# gauge -3.5833333333333335             name3, descr1, key1, value1, key3, value3
# gauge -8.166666666666666              name1, descr3, key1, value1, key2, value2
# gauge -15.0                           name1, descr4, key2, value2, key3, value3
# gauge -6.75                           name2, descr3, key2, value2
# gauge 6.5                             name4, descr3, key2, value2, key3, value3, key4, value4
# gauge 4.277777777777778               name4, descr1, key1, value1, key2, value2, key3, value3
# gauge -2.1739130434782608             name4, descr1, key1, value1
# gauge -7.571428571428571              name2, descr4, key3, value3, key4, value4
# gauge 2.2941176470588234              name4, descr1, key2, value2
# gauge -6.615384615384615              name1, descr1, key4, value4
# gauge 17.77777777777778               name1, descr2, key2, value2, key3, value3
# gauge -5.615384615384615              name3, descr3, key1, value1, key2, value2
# gauge -3.4705882352941178             name4, descr1, key2, value2, key3, value3, key4, value4
# gauge -4.0588235294117645             name4, descr3, key3, value3
# gauge 3.5294117647058822              name1, descr3, key2, value2
# gauge -12.727272727272727             name4, descr3, key1, value1, key2, value2, key3, value3
# gauge -3.2                            name3, descr4, key1, value1, key4, value4
# gauge 3.5                             name1, descr1, key3, value3
# gauge -20.142857142857142             name1, descr2, key3, value3, key4, value4
# gauge 6.4                             name4, descr1, key3, value3, key4, value4
# gauge 3.5                             name3, descr2, key1, value1, key2, value2, key3, value3
# gauge -7.5                            name2, descr3, key1, value1, key2, value2
# gauge -7.785714285714286              name1, descr4, key1, value1, key2, value2
# gauge 0.6923076923076923              name3, descr3, key2, value2
# gauge -10.0                           name3, descr3, key3, value3, key4, value4
# gauge 10.909090909090908              name2, descr2, key2, value2, key3, value3
# gauge 8.0                             name3, descr2, key3, value3, key4, value4
# gauge -5.285714285714286              name3, descr3, key3, value3
# gauge 8.307692307692308               name3, descr2, key1, value1, key4, value4
# gauge -1.2857142857142858             name3, descr3, key1, value1, key3, value3, key4, value4
# gauge 10.071428571428571              name4, descr4, key1, value1, key2, value2, key3, value3
# gauge 5.777777777777778               name2, descr3, key3, value3, key4, value4
# gauge 5.3                             name1, descr1, key2, value2, key3, value3
# gauge 0.36363636363636365             name2, descr4, key2, value2, key3, value3
# gauge 5.25                            name1, descr3, key2, value2, key3, value3
# gauge 5.944444444444445               name2, descr4, key1, value1
# gauge 2.6923076923076925              name3, descr1, key2, value2
# gauge -1.1666666666666667             name3, descr3, key1, value1, key4, value4
# gauge -0.3                            name4, descr4, key1, value1, key2, value2
# gauge -2.235294117647059              name3, descr2, key2, value2, key4, value4
# gauge 2.375                           name2, descr2, key1, value1, key2, value2
# gauge 1.6363636363636365              name4, descr2, key1, value1, key3, value3
# gauge -8.8                            name3, descr4, key2, value2, key4, value4
# gauge 11.0                            name2, descr3, key1, value1, key3, value3
# gauge -6.666666666666667              name2, descr4, key1, value1, key3, value3, key4, value4
# gauge 2.6153846153846154              name2, descr3, key3, value3
# gauge 1.9                             name4, descr1, key1, value1, key2, value2
# gauge 13.166666666666666              name4, descr3, key3, value3, key4, value4
# gauge 3.7777777777777777              name3, descr4, key2, value2, key3, value3, key4, value4
# gauge -7.625                          name2, descr4, key1, value1, key3, value3
# gauge 0.6                             name4, descr1, key2, value2, key4, value4
# gauge -6.75                           name1, descr1, key1, value1, key3, value3
# gauge 5.538461538461538               name4, descr3, key1, value1, key3, value3
# gauge 16.833333333333332              name3, descr4, key1, value1, key3, value3
# gauge -1.2                            name1, descr3, key1, value1, key3, value3
# gauge 9.333333333333334               name4, descr2, key1, value1, key3, value3, key4, value4
# gauge 7.333333333333333               name3, descr4, key4, value4
# gauge 14.25                           name2, descr2, key3, value3, key4, value4
# gauge -31.25                          name2, descr3, key2, value2, key4, value4
# ctr   197                             name3, descr4, key1, value1, key3, value3
# ctr   475                             name4, descr3, key2, value2
# ctr   647                             name1, descr1, key3, value3
# ctr   317                             name3, descr3, key2, value2, key3, value3
# ctr   244                             name4, descr4, key2, value2, key3, value3
# ctr   401                             name2, descr1, key1, value1, key2, value2, key4, value4
# ctr   130                             name4, descr1, key2, value2, key4, value4
# ctr   398                             name3, descr4, key1, value1
# ctr   403                             name2, descr4, key1, value1
# ctr   225                             name1, descr1, key3, value3, key4, value4
# ctr   418                             name1, descr3, key1, value1, key2, value2, key3, value3
# ctr   303                             name3, descr3, key2, value2, key3, value3, key4, value4
# ctr   615                             name3, descr2, key1, value1, key2, value2
# ctr   663                             name3, descr4, key3, value3
# ctr   325                             name3, descr4, key1, value1, key2, value2, key4, value4
# ctr   1555                            name3, descr2, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   514                             name2, descr1, key4, value4
# ctr   2095                            name1, descr2, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   529                             name1, descr2, key1, value1, key3, value3, key4, value4
# ctr   324                             name3, descr2, key3, value3
# ctr   332                             name3, descr1, key3, value3
# ctr   1720                            name4, descr1, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   467                             name4, descr2, key2, value2, key3, value3, key4, value4
# ctr   1876                            name4, descr3, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   469                             name4, descr3, key4, value4
# ctr   240                             name3, descr3, key2, value2, key4, value4
# ctr   200                             name3, descr2, key3, value3, key4, value4
# ctr   1543                            name3, descr1, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   487                             name2, descr3, key1, value1, key3, value3, key4, value4
# ctr   527                             name1, descr2, key2, value2, key3, value3, key4, value4
# ctr   248                             name2, descr1, key1, value1, key4, value4
# ctr   509                             name4, descr3, key1, value1, key2, value2
# ctr   383                             name4, descr3, key1, value1, key3, value3
# ctr   456                             name4, descr1, key3, value3
# ctr   557                             name2, descr2, key1, value1
# ctr   231                             name2, descr1, key2, value2, key3, value3
# ctr   1605                            name1, descr4, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   372                             name4, descr2, key3, value3, key4, value4
# ctr   497                             name3, descr2, key1, value1, key2, value2, key4, value4
# ctr   264                             name2, descr2, key1, value1, key2, value2
# ctr   306                             name2, descr2, key1, value1, key3, value3, key4, value4
# ctr   218                             name3, descr3, key1, value1
# ctr   485                             name4, descr3, key1, value1, key2, value2, key4, value4
# ctr   2008                            name2, descr2, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   382                             name1, descr2, key3, value3
# ctr   1795                            name3, descr3, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   543                             name4, descr2, key1, value1, key2, value2, key3, value3
# ctr   364                             name1, descr3, key4, value4
# ctr   421                             name1, descr4, key2, value2
# ctr   394                             name3, descr2, key1, value1
# ctr   1894                            name3, descr4, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   287                             name4, descr3, key1, value1, key3, value3, key4, value4
# ctr   328                             name4, descr4, key1, value1, key2, value2, key4, value4
# ctr   363                             name2, descr4, key1, value1, key2, value2, key3, value3
# ctr   592                             name4, descr3, key3, value3
# ctr   543                             name1, descr4, key2, value2, key3, value3, key4, value4
# ctr   173                             name1, descr1, key1, value1, key2, value2, key3, value3
# ctr   400                             name4, descr1, key1, value1, key4, value4
# ctr   339                             name1, descr1, key1, value1, key2, value2
# ctr   385                             name2, descr2, key2, value2, key3, value3
# ctr   203                             name1, descr2, key1, value1, key3, value3
# ctr   210                             name1, descr4, key1, value1, key2, value2
# ctr   1856                            name4, descr4, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   578                             name2, descr1, key1, value1, key2, value2, key3, value3
# ctr   317                             name1, descr3, key2, value2, key3, value3, key4, value4
# ctr   599                             name1, descr2, key1, value1, key2, value2, key4, value4
# ctr   317                             name4, descr1, key3, value3, key4, value4
# ctr   631                             name4, descr3, key1, value1, key2, value2, key3, value3
# ctr   696                             name2, descr4, key2, value2, key3, value3, key4, value4
# ctr   289                             name2, descr4, key2, value2
# ctr   253                             name2, descr2, key3, value3
# ctr   292                             name1, descr2, key2, value2, key4, value4
# ctr   664                             name3, descr1, key1, value1, key2, value2, key3, value3
# ctr   619                             name3, descr3, key3, value3
# ctr   276                             name4, descr1, key1, value1, key2, value2, key4, value4
# ctr   275                             name4, descr2, key1, value1, key3, value3
# ctr   516                             name3, descr1, key1, value1, key2, value2, key4, value4
# ctr   318                             name3, descr2, key1, value1, key2, value2, key3, value3
# ctr   270                             name2, descr4, key2, value2, key4, value4
# ctr   416                             name3, descr1, key1, value1, key3, value3, key4, value4
# ctr   303                             name3, descr4, key2, value2, key3, value3, key4, value4
# ctr   290                             name2, descr3, key3, value3
# ctr   576                             name3, descr2, key2, value2
# ctr   589                             name3, descr2, key1, value1, key3, value3, key4, value4
# ctr   388                             name3, descr2, key1, value1, key4, value4
# ctr   1578                            name2, descr4, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   715                             name1, descr2, key1, value1, key2, value2, key3, value3
# ctr   247                             name1, descr2, key2, value2
# ctr   1565                            name1, descr3, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   402                             name3, descr1, key2, value2, key3, value3, key4, value4
# ctr   206                             name4, descr2, key1, value1, key2, value2
# ctr   399                             name1, descr3, key3, value3, key4, value4
# ctr   313                             name2, descr3, key2, value2, key3, value3, key4, value4
# ctr   363                             name2, descr3, key1, value1, key2, value2, key3, value3
# ctr   258                             name3, descr4, key1, value1, key4, value4
# ctr   361                             name3, descr2, key4, value4
# ctr   528                             name3, descr4, key1, value1, key2, value2, key3, value3
# ctr   521                             name4, descr1, key4, value4
# ctr   411                             name1, descr1, key1, value1, key3, value3, key4, value4
# ctr   323                             name2, descr4, key4, value4
# ctr   416                             name4, descr4, key4, value4
# ctr   1631                            name2, descr1, key1, value1, key2, value2, key3, value3, key4, value4
# ...
# ctr   387                             name4, descr1, key1, value1, key2, value2, key4, value4
# ctr   1478                            name3, descr3, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   400                             name4, descr3, key1, value1, key2, value2, key3, value3
# ctr   470                             name3, descr3, key2, value2
# ctr   480                             name2, descr2, key4, value4
# ctr   2185                            name3, descr4, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   223                             name2, descr3, key2, value2, key3, value3
# ctr   546                             name2, descr3, key3, value3
# ctr   423                             name4, descr4, key4, value4
# ctr   1877                            name1, descr2, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   402                             name4, descr4, key1, value1
# ctr   95                              name3, descr4, key1, value1, key4, value4
# ctr   460                             name4, descr1, key4, value4
# ctr   551                             name1, descr4, key1, value1, key2, value2, key4, value4
# ctr   285                             name3, descr2, key1, value1, key3, value3
# ctr   464                             name2, descr4, key2, value2, key3, value3, key4, value4
# ctr   769                             name1, descr2, key3, value3
# ctr   234                             name3, descr4, key2, value2, key3, value3
# ctr   326                             name4, descr2, key2, value2, key4, value4
# ctr   197                             name1, descr3, key1, value1, key3, value3
# ctr   1673                            name3, descr1, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   273                             name3, descr3, key1, value1, key2, value2
# ctr   188                             name4, descr4, key1, value1, key2, value2, key3, value3
# ctr   1154                            name4, descr2, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   197                             name4, descr1, key1, value1, key4, value4
# ctr   350                             name3, descr2, key1, value1
# ctr   729                             name3, descr3, key4, value4
# ctr   548                             name2, descr3, key1, value1, key3, value3
# ctr   399                             name2, descr1, key1, value1, key2, value2
# ctr   464                             name1, descr3, key2, value2, key3, value3, key4, value4
# ctr   1553                            name4, descr1, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   451                             name3, descr4, key2, value2, key3, value3, key4, value4
# ctr   454                             name1, descr1, key4, value4
# ctr   595                             name1, descr3, key2, value2, key3, value3
# ctr   380                             name2, descr1, key1, value1, key2, value2, key3, value3
# ctr   257                             name2, descr1, key1, value1, key4, value4
# ctr   212                             name3, descr1, key3, value3, key4, value4
# ctr   459                             name3, descr4, key1, value1, key2, value2, key3, value3
# ctr   595                             name1, descr1, key1, value1, key3, value3, key4, value4
# ctr   1262                            name1, descr1, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   549                             name2, descr1, key3, value3
# ctr   389                             name1, descr2, key2, value2, key3, value3, key4, value4
# ctr   223                             name2, descr1, key4, value4
# ctr   338                             name4, descr3, key2, value2
# ctr   732                             name4, descr1, key2, value2
# ctr   437                             name3, descr2, key1, value1, key2, value2
# ctr   547                             name2, descr3, key2, value2, key3, value3, key4, value4
# ctr   379                             name3, descr1, key2, value2, key3, value3, key4, value4
# ctr   404                             name3, descr4, key2, value2, key4, value4
# ctr   448                             name3, descr2, key4, value4
# ctr   502                             name3, descr3, key2, value2, key3, value3, key4, value4
# ctr   191                             name1, descr1, key1, value1, key4, value4
# ctr   532                             name2, descr2, key1, value1
# ctr   345                             name4, descr1, key1, value1, key3, value3, key4, value4
# ctr   1512                            name1, descr3, key1, value1, key2, value2, key3, value3, key4, value4
# ctr   349                             name4, descr2, key1, value1, key2, value2
# ctr   509                             name3, descr1, key2, value2
# ctr   383                             name2, descr2, key2, value2, key3, value3, key4, value4
# ctr   355                             name4, descr4, key1, value1, key3, value3
# ctr   418                             name1, descr1, key2, value2, key4, value4
# ctr   403                             name3, descr2, key3, value3
# ctr   343                             name4, descr2, key1, value1, key3, value3, key4, value4
# ctr   264                             name3, descr2, key1, value1, key3, value3, key4, value4
# ctr   227                             name4, descr2, key3, value3
# ctr   461                             name1, descr4, key1, value1, key2, value2, key3, value3
# ctr   589                             name2, descr4, key1, value1, key2, value2
# ctr   337                             name1, descr3, key1, value1, key2, value2, key3, value3
# ctr   543                             name3, descr2, key1, value1, key2, value2, key3, value3
# ctr   432                             name1, descr4, key1, value1, key2, value2
# ctr   327                             name4, descr3, key1, value1, key3, value3, key4, value4
# ctr   237                             name1, descr2, key1, value1, key2, value2
# ctr   490                             name2, descr3, key1, value1, key3, value3, key4, value4
# ctr   475                             name2, descr1, key1, value1
# ctr   402                             name3, descr3, key1, value1, key2, value2, key4, value4
# ctr   350                             name1, descr1, key1, value1, key2, value2, key3, value3
# ctr   496                             name2, descr1, key1, value1, key2, value2, key4, value4
# ctr   253                             name4, descr4, key1, value1, key2, value2, key4, value4
# ctr   447                             name2, descr4, key2, value2
# ctr   475                             name3, descr4, key3, value3
# ctr   209                             name4, descr3, key1, value1, key2, value2, key4, value4
# ctr   258                             name2, descr4, key1, value1, key2, value2, key3, value3
# ctr   477                             name3, descr3, key1, value1, key3, value3, key4, value4
# ctr   230                             name1, descr2, key1, value1, key3, value3, key4, value4
# ctr   292                             name3, descr1, key1, value1, key4, value4
# ctr   465                             name1, descr4, key3, value3
# ctr   496                             name4, descr3, key2, value2, key3, value3
# ctr   385                             name2, descr3, key4, value4
# ctr   175                             name3, descr1, key2, value2, key4, value4
# ctr   299                             name2, descr4, key1, value1, key4, value4
# ctr   568                             name3, descr4, key1, value1, key3, value3
# ctr   316                             name1, descr2, key2, value2, key3, value3
# ctr   358                             name2, descr4, key1, value1
# ctr   304                             name1, descr2, key2, value2, key4, value4
# ctr   302                             name1, descr3, key1, value1, key3, value3, key4, value4
# ctr   206                             name1, descr3, key1, value1, key4, value4
# ctr   298                             name1, descr2, key1, value1, key3, value3
# ctr   311                             name4, descr2, key1, value1, key2, value2, key4, value4
# ctr   535                             name2, descr1, key2, value2, key3, value3, key4, value4
# ctr   369                             name3, descr1, key1, value1, key2, value2, key4, value4
# ctr   359                             name4, descr2, key4, value4
# ctr   310                             name2, descr2, key1, value1, key2, value2, key3, value3
# ctr   186                             name2, descr4, key1, value1, key3, value3
# ctr   215                             name2, descr4, key2, value2, key3, value3
# ctr   378                             name4, descr1, key2, value2, key3, value3
# ctr   345                             name4, descr2, key2, value2, key3, value3, key4, value4
# ctr   89                              name2, descr2, key1, value1, key4, value4
# ctr   290                             name1, descr3, key2, value2
# ctr   343                             name1, descr1, key1, value1, key2, value2
# ctr   608                             name4, descr3, key1, value1
# ctr   477                             name4, descr1, key2, value2, key3, value3, key4, value4
# ctr   239                             name2, descr3, key1, value1, key4, value4
# ctr   329                             name4, descr4, key1, value1, key2, value2
# ctr   356                             name2, descr3, key2, value2, key4, value4
# ctr   345                             name2, descr4, key1, value1, key2, value2, key4, value4
# ctr   341                             name4, descr3, key1, value1, key2, value2
# ctr   136                             name4, descr4, key1, value1, key4, value4
# ctr   532                             name1, descr3, key3, value3
# ctr   286                             name1, descr1, key1, value1
# ctr   513                             name4, descr3, key2, value2, key3, value3, key4, value4
# ctr   210                             name1, descr3, key4, value4
# ctr   239                             name4, descr3, key1, value1, key3, value3
# ctr   270                             name1, descr4, key2, value2, key4, value4
# ctr   193                             name3, descr4, key3, value3, key4, value4
# ctr   99                              name4, descr2, key2, value2
# ctr   366                             name4, descr4, key2, value2, key3, value3, key4, value4
# ctr   420                             name2, descr2, key1, value1, key2, value2, key4, value4
# ctr   198                             name4, descr3, key1, value1, key4, value4
# ctr   403                             name4, descr4, key1, value1, key3, value3, key4, value4
# ctr   320                             name4, descr2, key1, value1, key2, value2, key3, value3
# ctr   493                             name2, descr4, key3, value3
# ctr   446                             name1, descr1, key2, value2, key3, value3, key4, value4
# ctr   289                             name1, descr3, key1, value1, key2, value2
# ctr   364                             name1, descr3, key1, value1
# ctr   236                             name3, descr2, key3, value3, key4, value4
# ctr   325                             name2, descr3, key1, value1
# ctr   397                             name4, descr1, key2, value2, key4, value4
# ctr   392                             name3, descr3, key3, value3, key4, value4
# ctr   496                             name3, descr4, key4, value4
# ctr   350                             name4, descr1, key3, value3
# ctr   318                             name1, descr3, key1, value1, key2, value2, key4, value4
# ctr   409                             name4, descr4, key2, value2
# ctr   375                             name4, descr2, key1, value1, key3, value3
# ctr   269                             name2, descr3, key2, value2
# ctr   449                             name4, descr1, key1, value1
# ctr   122                             name2, descr4, key2, value2, key4, value4
# ctr   295                             name4, descr1, key1, value1, key2, value2
# ctr   301                             name2, descr3, key1, value1, key2, value2
# ctr   229                             name1, descr1, key3, value3, key4, value4
# ctr   591                             name3, descr4, key1, value1
# ctr   381                             name1, descr2, key2, value2
# ctr   402                             name1, descr4, key2, value2, key3, value3, key4, value4
# ctr   321                             name2, descr1, key2, value2, key3, value3
# ctr   346                             name1, descr4, key3, value3, key4, value4
# ctr   349                             name4, descr1, key3, value3, key4, value4
# ctr   388                             name2, descr2, key2, value2
# ctr   305                             name4, descr2, key3, value3, key4, value4
# ctr   433                             name2, descr2, key2, value2, key3, value3
# ctr   490                             name3, descr1, key1, value1, key3, value3, key4, value4
# ctr   206                             name2, descr2, key3, value3
# ctr   377                             name2, descr4, key3, value3, key4, value4
# ctr   242                             name1, descr3, key3, value3, key4, value4
# ctr   92                              name3, descr1, key1, value1, key2, value2
# ctr   440                             name3, descr4, key1, value1, key3, value3, key4, value4
# ctr   424                             name3, descr2, key2, value2
# ctr   261                             name1, descr2, key4, value4
# ctr   471                             name1, descr4, key1, value1
# ctr   297                             name2, descr4, key4, value4
# ctr   178                             name4, descr4, key2, value2, key3, value3
# ctr   481                             name3, descr3, key1, value1
# ctr   205                             name4, descr4, key3, value3, key4, value4
# ctr   260                             name2, descr2, key3, value3, key4, value4
# ctr   248                             name3, descr2, key2, value2, key4, value4
# ctr   249                             name1, descr2, key3, value3, key4, value4
# ctr   92                              name2, descr2, key1, value1, key2, value2
# ctr   276                             name1, descr3, key2, value2, key4, value4
# ctr   392                             name2, descr1, key2, value2
# ctr   136                             name3, descr3, key1, value1, key3, value3
# ctr   249                             name1, descr2, key1, value1, key2, value2, key3, value3
# ctr   378                             name4, descr3, key2, value2, key4, value4
# ctr   262                             name1, descr4, key1, value1, key4, value4
# ctr   395                             name4, descr2, key1, value1
# ctr   176                             name2, descr2, key1, value1, key3, value3
# ctr   172                             name3, descr3, key1, value1, key4, value4
# ctr   172                             name1, descr1, key1, value1, key3, value3
# ctr   172                             name2, descr3, key3, value3, key4, value4
# ctr   52                              name2, descr1, key2, value2, key4, value4
# ctr   335                             name1, descr1, key3, value3
# ctr   223                             name3, descr2, key2, value2, key3, value3
# ctr   154                             name3, descr3, key2, value2, key3, value3
# ctr   253                             name4, descr2, key1, value1, key4, value4
# ctr   280                             name4, descr4, key2, value2, key4, value4
# ctr   269                             name1, descr4, key2, value2, key3, value3
# ctr   197                             name3, descr4, key1, value1, key2, value2
# ctr   151                             name2, descr2, key2, value2, key4, value4
# ctr   430                             name1, descr2, key1, value1, key4, value4
# ctr   202                             name3, descr1, key1, value1, key3, value3
# ctr   111                             name2, descr1, key1, value1, key3, value3
